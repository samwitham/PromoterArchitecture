# %%
pip install pybiomart

# %%
conda install -y -c future requests requests-cache
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3
#
#   added / updated specs:
#     - requests
#     - requests-cache
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     requests-cache-0.5.0       |             py_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          18 KB
#
# The following NEW packages will be INSTALLED:
#
#   requests-cache     conda-forge/noarch::requests-cache-0.5.0-py_0
#
#
#
# Downloading and Extracting Packages
# requests-cache-0.5.0 | 18 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# (base)
# : 1

# %%
conda install -y -c bioconda pybedtools
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3
#
#   added / updated specs:
#     - pybedtools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-1.17.1               |   py37h95a1406_0         5.2 MB  conda-forge
#     pybedtools-0.8.0           |   py37he860b03_1        12.1 MB  bioconda
#     pysam-0.15.3               |   py37hda2845c_1         2.5 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:        19.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   bedtools           bioconda/linux-64::bedtools-2.28.0-hdf88d34_0
#   curl               conda-forge/linux-64::curl-7.65.3-hf8cf82a_0
#   krb5               conda-forge/linux-64::krb5-1.16.3-h05b26f9_1001
#   libblas            conda-forge/linux-64::libblas-3.8.0-12_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.8.0-12_openblas
#   libcurl            conda-forge/linux-64::libcurl-7.65.3-hda55be3_0
#   libdeflate         bioconda/linux-64::libdeflate-1.0-h14c3975_1
#   libedit            conda-forge/linux-64::libedit-3.1.20170329-hf8c457e_1001
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.3.0-hdf63c60_0
#   liblapack          conda-forge/linux-64::liblapack-3.8.0-12_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.7-h6e990d7_1
#   libssh2            conda-forge/linux-64::libssh2-1.8.2-h22169c7_2
#   numpy              conda-forge/linux-64::numpy-1.17.1-py37h95a1406_0
#   pandas             conda-forge/linux-64::pandas-0.25.1-py37hb3f55d8_0
#   pybedtools         bioconda/linux-64::pybedtools-0.8.0-py37he860b03_1
#   pysam              bioconda/linux-64::pysam-0.15.3-py37hda2845c_1
#
#
#
# Downloading and Extracting Packages
# numpy-1.17.1         | 5.2 MB    | ##################################### | 100%
# pysam-0.15.3         | 2.5 MB    | ##################################### | 100%
# pybedtools-0.8.0     | 12.1 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# (base)
# : 1

# %%
conda install -c bioconda pybedtools
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3/envs/Promoter_pipeline
#
#   added / updated specs:
#     - pybedtools
#
#
# The following NEW packages will be INSTALLED:
#
#   libblas            conda-forge/linux-64::libblas-3.8.0-12_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.8.0-12_openblas
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.3.0-hdf63c60_0
#   liblapack          conda-forge/linux-64::liblapack-3.8.0-12_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.7-h6e990d7_1
#   numpy              conda-forge/linux-64::numpy-1.17.1-py37h95a1406_0
#   pandas             conda-forge/linux-64::pandas-0.25.1-py37hb3f55d8_0
#   pybedtools         bioconda/linux-64::pybedtools-0.8.0-py37he860b03_1
#   pysam              bioconda/linux-64::pysam-0.15.3-py37hda2845c_1
#   pytz               conda-forge/noarch::pytz-2019.2-py_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda biopython

# %%
conda install -c bioconda bcbiogff

# %%
conda install -y -c anaconda pymysql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3/envs/Promoter_pipeline
#
#   added / updated specs:
#     - pymysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asn1crypto-0.24.0          |           py37_0         154 KB  anaconda
#     backcall-0.1.0             |           py37_0          20 KB  anaconda
#     certifi-2019.6.16          |           py37_1         156 KB  anaconda
#     cffi-1.12.3                |   py37h2e261b9_0         222 KB  anaconda
#     cryptography-2.7           |   py37h1ba5d50_0         608 KB  anaconda
#     curl-7.65.3                |       hbc83047_0         141 KB  anaconda
#     dbus-1.13.6                |       h746ee38_0         587 KB  anaconda
#     decorator-4.4.0            |           py37_1          18 KB  anaconda
#     expat-2.2.6                |       he6710b0_0         187 KB  anaconda
#     fontconfig-2.13.0          |       h9420a91_0         291 KB  anaconda
#     freetype-2.9.1             |       h8a8886c_1         822 KB  anaconda
#     glib-2.56.2                |       hd408876_0         5.0 MB  anaconda
#     gst-plugins-base-1.14.0    |       hbbd80ab_1         6.3 MB  anaconda
#     gstreamer-1.14.0           |       hb453b48_1         3.8 MB  anaconda
#     idna-2.8                   |           py37_0         101 KB  anaconda
#     ipykernel-5.1.0            |   py37h39e3cac_0         156 KB  anaconda
#     ipython-7.5.0              |   py37h39e3cac_0         1.1 MB  anaconda
#     ipython_genutils-0.2.0     |           py37_0          39 KB  anaconda
#     jedi-0.13.3                |           py37_0         234 KB  anaconda
#     jupyter_client-5.2.4       |           py37_0         127 KB  anaconda
#     jupyter_core-4.4.0         |           py37_0          63 KB  anaconda
#     jupyterlab-0.34.12         |           py37_0        10.0 MB  anaconda
#     jupyterlab_launcher-0.13.1 |           py37_0          36 KB  anaconda
#     krb5-1.16.1                |       h173b8e3_7         1.4 MB  anaconda
#     libcurl-7.65.3             |       h20c2e04_0         588 KB  anaconda
#     libedit-3.1.20181209       |       hc058e9b_0         188 KB  anaconda
#     libgcc-ng-8.2.0            |       hdf63c60_1         7.6 MB  anaconda
#     libpng-1.6.36              |       hbc83047_0         346 KB  anaconda
#     libsodium-1.0.16           |       h1bed415_0         302 KB  anaconda
#     libstdcxx-ng-8.2.0         |       hdf63c60_1         2.9 MB  anaconda
#     libuuid-1.0.3              |       h1bed415_2          16 KB  anaconda
#     libxcb-1.13                |       h1bed415_1         502 KB  anaconda
#     libxml2-2.9.9              |       he19cac6_0         2.0 MB  anaconda
#     ncurses-6.1                |       he6710b0_1         958 KB  anaconda
#     notebook-5.7.8             |           py37_0         7.2 MB  anaconda
#     parso-0.4.0                |             py_0          66 KB  anaconda
#     pcre-8.43                  |       he6710b0_0         260 KB  anaconda
#     pickleshare-0.7.5          |           py37_0          13 KB  anaconda
#     pip-19.0.3                 |           py37_0         1.8 MB  anaconda
#     prompt_toolkit-2.0.9       |           py37_0         489 KB  anaconda
#     ptyprocess-0.6.0           |           py37_0          23 KB  anaconda
#     pycparser-2.19             |           py37_0         172 KB  anaconda
#     pygments-2.3.1             |           py37_0         1.3 MB  anaconda
#     pymysql-0.9.3              |           py37_0          83 KB  anaconda
#     python-3.7.3               |       h0371630_0        36.7 MB  anaconda
#     python-dateutil-2.8.0      |           py37_0         281 KB  anaconda
#     pyzmq-18.0.0               |   py37he6710b0_0         493 KB  anaconda
#     qt-5.9.7                   |       h5867ecd_1        85.9 MB  anaconda
#     readline-7.0               |       h7b6447c_5         392 KB  anaconda
#     setuptools-40.8.0          |           py37_0         643 KB  anaconda
#     six-1.12.0                 |           py37_0          22 KB  anaconda
#     sqlite-3.27.2              |       h7b6447c_0         1.9 MB  anaconda
#     tk-8.6.8                   |       hbc83047_0         3.1 MB  anaconda
#     tornado-6.0.2              |   py37h7b6447c_0         642 KB  anaconda
#     traitlets-4.3.2            |           py37_0         133 KB  anaconda
#     wcwidth-0.1.7              |           py37_0          23 KB  anaconda
#     wheel-0.33.1               |           py37_0          39 KB  anaconda
#     xz-5.2.4                   |       h14c3975_4         366 KB  anaconda
#     zeromq-4.3.1               |       he6710b0_3         666 KB  anaconda
#     zlib-1.2.11                |       h7b6447c_3         120 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:       189.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   asn1crypto         anaconda/linux-64::asn1crypto-0.24.0-py37_0
#   cffi               anaconda/linux-64::cffi-1.12.3-py37h2e261b9_0
#   cryptography       anaconda/linux-64::cryptography-2.7-py37h1ba5d50_0
#   idna               anaconda/linux-64::idna-2.8-py37_0
#   jupyterlab_launch~ anaconda/linux-64::jupyterlab_launcher-0.13.1-py37_0
#   pycparser          anaconda/linux-64::pycparser-2.19-py37_0
#   pymysql            anaconda/linux-64::pymysql-0.9.3-py37_0
#
# The following packages will be UPDATED:
#
#   decorator          conda-forge/noarch::decorator-4.4.0-p~ --> anaconda/linux-64::decorator-4.4.0-py37_1
#   expat              conda-forge::expat-2.2.5-he1b5a44_1003 --> anaconda::expat-2.2.6-he6710b0_0
#   libedit            conda-forge::libedit-3.1.20170329-hf8~ --> anaconda::libedit-3.1.20181209-hc058e9b_0
#   openssl            conda-forge::openssl-1.1.1c-h516909a_0 --> anaconda::openssl-1.1.1-h7b6447c_0
#   pcre                 conda-forge::pcre-8.41-hf484d3e_1003 --> anaconda::pcre-8.43-he6710b0_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   backcall           conda-forge/noarch::backcall-0.1.0-py~ --> anaconda/linux-64::backcall-0.1.0-py37_0
#   ca-certificates    conda-forge::ca-certificates-2019.6.1~ --> anaconda::ca-certificates-2019.5.15-1
#   certifi                                       conda-forge --> anaconda
#   curl                  conda-forge::curl-7.65.3-hf8cf82a_0 --> anaconda::curl-7.65.3-hbc83047_0
#   dbus                  conda-forge::dbus-1.13.6-he372182_0 --> anaconda::dbus-1.13.6-h746ee38_0
#   fontconfig         conda-forge::fontconfig-2.13.1-h86ecd~ --> anaconda::fontconfig-2.13.0-h9420a91_0
#   freetype           conda-forge::freetype-2.10.0-he983fc9~ --> anaconda::freetype-2.9.1-h8a8886c_1
#   glib               conda-forge::glib-2.58.3-h6f030ca_1002 --> anaconda::glib-2.56.2-hd408876_0
#   gst-plugins-base   conda-forge::gst-plugins-base-1.14.5-~ --> anaconda::gst-plugins-base-1.14.0-hbbd80ab_1
#   gstreamer          conda-forge::gstreamer-1.14.5-h36ae1b~ --> anaconda::gstreamer-1.14.0-hb453b48_1
#   icu                      conda-forge::icu-64.2-he1b5a44_1 --> pkgs/main::icu-58.2-h9c2bf20_1
#   ipykernel          conda-forge::ipykernel-5.1.2-py37h5ca~ --> anaconda::ipykernel-5.1.0-py37h39e3cac_0
#   ipython            conda-forge::ipython-7.8.0-py37h5ca1d~ --> anaconda::ipython-7.5.0-py37h39e3cac_0
#   ipython_genutils   conda-forge/noarch::ipython_genutils-~ --> anaconda/linux-64::ipython_genutils-0.2.0-py37_0
#   jedi                      conda-forge::jedi-0.15.1-py37_0 --> anaconda::jedi-0.13.3-py37_0
#   jpeg                   conda-forge::jpeg-9c-h14c3975_1001 --> pkgs/main::jpeg-9b-h024ee3a_2
#   jupyter_client     conda-forge/noarch::jupyter_client-5.~ --> anaconda/linux-64::jupyter_client-5.2.4-py37_0
#   jupyter_core       conda-forge/noarch::jupyter_core-4.4.~ --> anaconda/linux-64::jupyter_core-4.4.0-py37_0
#   jupyterlab         conda-forge/noarch::jupyterlab-1.1.1-~ --> anaconda/linux-64::jupyterlab-0.34.12-py37_0
#   krb5               conda-forge::krb5-1.16.3-h05b26f9_1001 --> anaconda::krb5-1.16.1-h173b8e3_7
#   libcurl            conda-forge::libcurl-7.65.3-hda55be3_0 --> anaconda::libcurl-7.65.3-h20c2e04_0
#   libffi             conda-forge::libffi-3.2.1-he1b5a44_10~ --> pkgs/main::libffi-3.2.1-hd88cf55_4
#   libgcc-ng           pkgs/main::libgcc-ng-9.1.0-hdf63c60_0 --> anaconda::libgcc-ng-8.2.0-hdf63c60_1
#   libpng              conda-forge::libpng-1.6.37-hed695b0_0 --> anaconda::libpng-1.6.36-hbc83047_0
#   libsodium          conda-forge::libsodium-1.0.17-h516909~ --> anaconda::libsodium-1.0.16-h1bed415_0
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.1.0-hdf63c6~ --> anaconda::libstdcxx-ng-8.2.0-hdf63c60_1
#   libuuid            conda-forge::libuuid-2.32.1-h14c3975_~ --> anaconda::libuuid-1.0.3-h1bed415_2
#   libxcb             conda-forge::libxcb-1.13-h14c3975_1002 --> anaconda::libxcb-1.13-h1bed415_1
#   libxml2             conda-forge::libxml2-2.9.9-hee79883_5 --> anaconda::libxml2-2.9.9-he19cac6_0
#   ncurses            conda-forge::ncurses-6.1-hf484d3e_1002 --> anaconda::ncurses-6.1-he6710b0_1
#   notebook               conda-forge::notebook-6.0.1-py37_0 --> anaconda::notebook-5.7.8-py37_0
#   parso                       conda-forge::parso-0.5.1-py_0 --> anaconda::parso-0.4.0-py_0
#   pickleshare        conda-forge::pickleshare-0.7.5-py37_1~ --> anaconda::pickleshare-0.7.5-py37_0
#   pip                        conda-forge::pip-19.2.3-py37_0 --> anaconda::pip-19.0.3-py37_0
#   prompt_toolkit     conda-forge/noarch::prompt_toolkit-2.~ --> anaconda/linux-64::prompt_toolkit-2.0.9-py37_0
#   ptyprocess         conda-forge/noarch::ptyprocess-0.6.0-~ --> anaconda/linux-64::ptyprocess-0.6.0-py37_0
#   pygments           conda-forge/noarch::pygments-2.4.2-py~ --> anaconda/linux-64::pygments-2.3.1-py37_0
#   python               conda-forge::python-3.7.3-h33d41f4_1 --> anaconda::python-3.7.3-h0371630_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2~ --> anaconda/linux-64::python-dateutil-2.8.0-py37_0
#   pyzmq              conda-forge::pyzmq-18.0.2-py37h176852~ --> anaconda::pyzmq-18.0.0-py37he6710b0_0
#   qt                       conda-forge::qt-5.9.7-h0c104cb_3 --> anaconda::qt-5.9.7-h5867ecd_1
#   readline             conda-forge::readline-8.0-hf8c457e_0 --> anaconda::readline-7.0-h7b6447c_5
#   setuptools          conda-forge::setuptools-41.2.0-py37_0 --> anaconda::setuptools-40.8.0-py37_0
#   six                     conda-forge::six-1.12.0-py37_1000 --> anaconda::six-1.12.0-py37_0
#   sqlite              conda-forge::sqlite-3.29.0-hcee41ef_1 --> anaconda::sqlite-3.27.2-h7b6447c_0
#   tk                    conda-forge::tk-8.6.9-hed695b0_1002 --> anaconda::tk-8.6.8-hbc83047_0
#   tornado            conda-forge::tornado-6.0.3-py37h51690~ --> anaconda::tornado-6.0.2-py37h7b6447c_0
#   traitlets          conda-forge::traitlets-4.3.2-py37_1000 --> anaconda::traitlets-4.3.2-py37_0
#   wcwidth            conda-forge/noarch::wcwidth-0.1.7-py_1 --> anaconda/linux-64::wcwidth-0.1.7-py37_0
#   wheel                    conda-forge::wheel-0.33.6-py37_0 --> anaconda::wheel-0.33.1-py37_0
#   xz                    conda-forge::xz-5.2.4-h14c3975_1001 --> anaconda::xz-5.2.4-h14c3975_4
#   zeromq               conda-forge::zeromq-4.3.2-he1b5a44_2 --> anaconda::zeromq-4.3.1-he6710b0_3
#   zlib               conda-forge::zlib-1.2.11-h516909a_1005 --> anaconda::zlib-1.2.11-h7b6447c_3
#
#
#
# Downloading and Extracting Packages
# traitlets-4.3.2      | 133 KB    | ##################################### | 100%
# libxml2-2.9.9        | 2.0 MB    | ##################################### | 100%
# ipython_genutils-0.2 | 39 KB     | ##################################### | 100%
# libcurl-7.65.3       | 588 KB    | ##################################### | 100%
# cffi-1.12.3          | 222 KB    | ##################################### | 100%
# prompt_toolkit-2.0.9 | 489 KB    | ##################################### | 100%
# libuuid-1.0.3        | 16 KB     | ##################################### | 100%
# freetype-2.9.1       | 822 KB    | ##################################### | 100%
# pcre-8.43            | 260 KB    | ##################################### | 100%
# decorator-4.4.0      | 18 KB     | ##################################### | 100%
# wheel-0.33.1         | 39 KB     | ##################################### | 100%
# libpng-1.6.36        | 346 KB    | ##################################### | 100%
# certifi-2019.6.16    | 156 KB    | ##################################### | 100%
# asn1crypto-0.24.0    | 154 KB    | ##################################### | 100%
# libedit-3.1.20181209 | 188 KB    | ##################################### | 100%
# pip-19.0.3           | 1.8 MB    | ##################################### | 100%
# jupyter_client-5.2.4 | 127 KB    | ##################################### | 100%
# libsodium-1.0.16     | 302 KB    | ##################################### | 100%
# zlib-1.2.11          | 120 KB    | ##################################### | 100%
# notebook-5.7.8       | 7.2 MB    | ##################################### | 100%
# ncurses-6.1          | 958 KB    | ##################################### | 100%
# setuptools-40.8.0    | 643 KB    | ##################################### | 100%
# gst-plugins-base-1.1 | 6.3 MB    | ##################################### | 100%
# parso-0.4.0          | 66 KB     | ##################################### | 100%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ##################################### | 100%
# jedi-0.13.3          | 234 KB    | ##################################### | 100%
# ipykernel-5.1.0      | 156 KB    | ##################################### | 100%
# curl-7.65.3          | 141 KB    | ##################################### | 100%
# jupyterlab_launcher- | 36 KB     | ##################################### | 100%
# xz-5.2.4             | 366 KB    | ##################################### | 100%
# sqlite-3.27.2        | 1.9 MB    | ##################################### | 100%
# tornado-6.0.2        | 642 KB    | ##################################### | 100%
# backcall-0.1.0       | 20 KB     | ##################################### | 100%
# dbus-1.13.6          | 587 KB    | ##################################### | 100%
# fontconfig-2.13.0    | 291 KB    | ##################################### | 100%
# wcwidth-0.1.7        | 23 KB     | ##################################### | 100%
# zeromq-4.3.1         | 666 KB    | ##################################### | 100%
# pygments-2.3.1       | 1.3 MB    | ##################################### | 100%
# idna-2.8             | 101 KB    | ##################################### | 100%
# gstreamer-1.14.0     | 3.8 MB    | ##################################### | 100%
# ptyprocess-0.6.0     | 23 KB     | ##################################### | 100%
# jupyterlab-0.34.12   | 10.0 MB   | ##################################### | 100%
# ipython-7.5.0        | 1.1 MB    | ##################################### | 100%
# qt-5.9.7             | 85.9 MB   | ##################################### | 100%
# libgcc-ng-8.2.0      | 7.6 MB    | ##################################### | 100%
# tk-8.6.8             | 3.1 MB    | ##################################### | 100%
# jupyter_core-4.4.0   | 63 KB     | ##################################### | 100%
# pyzmq-18.0.0         | 493 KB    | ##################################### | 100%
# libxcb-1.13          | 502 KB    | ##################################### | 100%
# readline-7.0         | 392 KB    | ##################################### | 100%
# krb5-1.16.1          | 1.4 MB    | ##################################### | 100%
# pycparser-2.19       | 172 KB    | ##################################### | 100%
# glib-2.56.2          | 5.0 MB    | ##################################### | 100%
# pickleshare-0.7.5    | 13 KB     | ##################################### | 100%
# python-3.7.3         | 36.7 MB   | ##################################### | 100%
# python-dateutil-2.8. | 281 KB    | ##################################### | 100%
# cryptography-2.7     | 608 KB    | ##################################### | 100%
# six-1.12.0           | 22 KB     | ##################################### | 100%
# expat-2.2.6          | 187 KB    | ##################################### | 100%
# pymysql-0.9.3        | 83 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -y -c bioconda pyfaidx
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3/envs/Promoter_pipeline
#
#   added / updated specs:
#     - pyfaidx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyfaidx-0.5.5.2            |             py_1          26 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:          26 KB
#
# The following NEW packages will be INSTALLED:
#
#   pyfaidx            bioconda/noarch::pyfaidx-0.5.5.2-py_1
#
# The following packages will be UPDATED:
#
#   ca-certificates     anaconda::ca-certificates-2019.5.15-1 --> conda-forge::ca-certificates-2019.6.16-hecc5488_0
#
#
#
# Downloading and Extracting Packages
# pyfaidx-0.5.5.2      | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -y -c anaconda mysql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3/envs/Promoter_pipeline
#
#   added / updated specs:
#     - mysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.8.28  |                0         132 KB  anaconda
#     certifi-2019.9.11          |           py37_0         154 KB  anaconda
#     cyrus-sasl-2.1.26          |       h82bf5a1_4         279 KB  anaconda
#     libdb-6.1.26               |       he6710b0_0        22.1 MB  anaconda
#     libntlm-1.5                |       h7b6447c_0          35 KB  anaconda
#     mysql-5.7.24               |       hbb652a2_0        75.8 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:        98.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cyrus-sasl         anaconda/linux-64::cyrus-sasl-2.1.26-h82bf5a1_4
#   libdb              anaconda/linux-64::libdb-6.1.26-he6710b0_0
#   libntlm            anaconda/linux-64::libntlm-1.5-h7b6447c_0
#   mysql              anaconda/linux-64::mysql-5.7.24-hbb652a2_0
#
# The following packages will be UPDATED:
#
#   openssl            conda-forge::openssl-1.1.1c-h516909a_0 --> anaconda::openssl-1.1.1-h7b6447c_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2019.9.1~ --> anaconda::ca-certificates-2019.8.28-0
#   certifi                                       conda-forge --> anaconda
#
#
#
# Downloading and Extracting Packages
# libdb-6.1.26         | 22.1 MB   | ##################################### | 100%
# libntlm-1.5          | 35 KB     | ##################################### | 100%
# certifi-2019.9.11    | 154 KB    | ##################################### | 100%
# cyrus-sasl-2.1.26    | 279 KB    | ##################################### | 100%
# mysql-5.7.24         | 75.8 MB   | ##################################### | 100%
# ca-certificates-2019 | 132 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -y --channel conda-forge --channel bioconda bedtools htslib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3/envs/Promoter_pipeline
#
#   added / updated specs:
#     - bedtools
#     - htslib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.9.11          |           py37_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         147 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates     anaconda::ca-certificates-2019.8.28-0 --> conda-forge::ca-certificates-2019.9.11-hecc5488_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                          anaconda --> conda-forge
#
#
#
# Downloading and Extracting Packages
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -y -c conda-forge plumbum
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/witham/opt/anaconda3/envs/Promoter_pipeline
#
#   added / updated specs:
#     - plumbum
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asn1crypto-1.0.1           |           py37_0         157 KB  conda-forge
#     bcrypt-3.1.6               |   py37h516909a_1          42 KB  conda-forge
#     paramiko-2.6.0             |           py37_0         268 KB  conda-forge
#     plumbum-1.6.7              |             py_0          80 KB  conda-forge
#     pynacl-1.3.0               |py37h14c3975_1000         1.5 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   asn1crypto         conda-forge/linux-64::asn1crypto-1.0.1-py37_0
#   bcrypt             conda-forge/linux-64::bcrypt-3.1.6-py37h516909a_1
#   cffi               conda-forge/linux-64::cffi-1.12.3-py37h8022711_0
#   cryptography       conda-forge/linux-64::cryptography-2.7-py37h72c5cf5_0
#   idna               conda-forge/linux-64::idna-2.8-py37_1000
#   paramiko           conda-forge/linux-64::paramiko-2.6.0-py37_0
#   plumbum            conda-forge/noarch::plumbum-1.6.7-py_0
#   pycparser          conda-forge/linux-64::pycparser-2.19-py37_1
#   pynacl             conda-forge/linux-64::pynacl-1.3.0-py37h14c3975_1000
#
#
#
# Downloading and Extracting Packages
# plumbum-1.6.7        | 80 KB     | ##################################### | 100%
# pynacl-1.3.0         | 1.5 MB    | ##################################### | 100%
# bcrypt-3.1.6         | 42 KB     | ##################################### | 100%
# asn1crypto-1.0.1     | 157 KB    | ##################################### | 100%
# paramiko-2.6.0       | 268 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statannot
