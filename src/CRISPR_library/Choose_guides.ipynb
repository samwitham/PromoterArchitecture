# %%
#choose guides falling in my promoters of interest for the mutation library
#guide pairs falling around 100bp from each other are chosen to increase chances of 100bp deletion

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import pdist, squareform

# %%
ARF9_guides_file = '../../data/CRISPR_library/sgRNAs-ARF9.csv'
ARF18_guides_file = '../../data/CRISPR_library/sgRNAs-ARF18.csv'
DREB26_guides_file = '../../data/CRISPR_library/sgRNAs-DREB26.csv'
NLP7_guides_file = '../../data/CRISPR_library/sgRNAs-NLP7.csv'

# %%
def select_guides(input_file):
    guides = pd.read_csv(input_file, header=2)
    #rename headers
    cols = ['Benchling_position', 'distance_from_ATG_bp', 'strand', 'sequence','PAM', 'specificity_score_2013', 'specificity_score_2016', 'efficiency_score','deleteme']
    guides.columns = cols
    guides = guides[['Benchling_position', 'distance_from_ATG_bp', 'strand', 'sequence','PAM', 'specificity_score_2013', 'specificity_score_2016', 'efficiency_score']]
    #add guide no. column
    guides['name'] = guides.index + 1
    #prepend string to name
    guides['name'] ='guide' + guides['name'].astype(str)
    #make distance matrix
    #summary = guides.groupby(['name','distance_from_ATG_bp']).size().unstack()
    #distance from atg column
    #remove if efficiency less than 40%
    guides = guides[guides.efficiency_score > 40]

    #pairwise differences between distance from ATG
    differences = abs(guides['distance_from_ATG_bp'].values - guides['distance_from_ATG_bp'].values[:, None])
    #turn back into dataframe
    differences = pd.DataFrame(differences, columns = guides.index, index = guides.index)
    #filter values less than 110 and more than 90 
    df = guides
    results = []
    #created based on https://stackoverflow.com/questions/51409927/python-selecting-pairs-of-objects-from-a-data-frame
    for i, row1 in df.iterrows():

         # calculate distance between current coordinate and all original rows in the data
        df['distance'] = df.apply(lambda row2: dist(row1['distance_from_ATG_bp'], row2['distance_from_ATG_bp']), axis=1)
        # filter only those within a specific distance and drop rows with same name as current coordinate
        df_tmp = df[(df['distance'] > 90) & (df['distance'] < 110) & (df['name'] != row1['name'])].copy()
         # prepare final data
        df_tmp['name2'] = row1['name']
        df_tmp['guide2'] = df_tmp['name']
        df_tmp['guide1'] = df_tmp['name2']
        df_tmp['pairs'] = list(zip(df_tmp['name'], df_tmp['name2']))
        # remember data
        results.append(df_tmp)

    # combine all into one dataframe
    df = pd.concat(results)
    # select columns of interest
    df = df[['pairs','guide1','guide2', 'distance']]
    def sort_tuple(idx):
        x, y = idx
        if y < x:
            return y, x
        return x, y
    #sort values of each tuple from low to high
    df['pairs'] = df['pairs'].apply(sort_tuple)
    
    # drop duplicates
    df.drop_duplicates(subset=['pairs'], inplace=True)     
    
    return df.reset_index(drop=True), guides[['name','Benchling_position', 'distance_from_ATG_bp', 'strand', 'sequence','PAM', 'specificity_score_2013', 'specificity_score_2016', 'efficiency_score']].reset_index(drop=True)

# %%
pairs,ARF9 =select_guides(ARF9_guides_file)
inboth = ARF9[ARF9.name.isin(pairs.guide1)| ARF9.name.isin(pairs.guide2)]
pairs
# Out:
#                  pairs   guide1   guide2  distance
# 0     (guide1, guide8)   guide1   guide8      98.0
# 1     (guide1, guide9)   guide1   guide9     106.0
# 2    (guide12, guide2)   guide2  guide12      93.0
# 3    (guide13, guide2)   guide2  guide13      99.0
# 4    (guide13, guide3)   guide3  guide13      96.0
# 5    (guide14, guide8)   guide8  guide14      99.0
# 6    (guide15, guide8)   guide8  guide15     103.0
# 7    (guide14, guide9)   guide9  guide14      91.0
# 8    (guide15, guide9)   guide9  guide15      95.0
# 9   (guide10, guide16)  guide10  guide16     108.0
# 10  (guide11, guide16)  guide11  guide16     107.0
# 11  (guide12, guide16)  guide12  guide16      98.0
# 12  (guide13, guide16)  guide13  guide16      92.0
# 13  (guide25, guide29)  guide25  guide29      93.0
# 14  (guide45, guide53)  guide45  guide53      97.0
# 15  (guide45, guide54)  guide45  guide54      98.0
# 16  (guide47, guide55)  guide47  guide55     102.0
# 17  (guide48, guide55)  guide48  guide55      97.0
# 18  (guide48, guide56)  guide48  guide56     109.0
# 19  (guide49, guide56)  guide49  guide56     100.0
# 20  (guide49, guide57)  guide49  guide57     107.0
# 21  (guide50, guide56)  guide50  guide56      99.0
# 22  (guide50, guide57)  guide50  guide57     106.0
# 23  (guide51, guide58)  guide51  guide58     100.0
# 24  (guide53, guide60)  guide53  guide60      93.0
# 25  (guide53, guide62)  guide53  guide62      96.0
# 26  (guide54, guide60)  guide54  guide60      92.0
# 27  (guide54, guide62)  guide54  guide62      95.0
# 28  (guide55, guide64)  guide55  guide64     104.0
# 29  (guide55, guide65)  guide55  guide65     106.0
# 30  (guide55, guide66)  guide55  guide66     107.0
# 31  (guide56, guide64)  guide56  guide64      92.0
# 32  (guide56, guide65)  guide56  guide65      94.0
# 33  (guide56, guide66)  guide56  guide66      95.0
# 34  (guide57, guide67)  guide57  guide67     106.0
# 35  (guide57, guide68)  guide57  guide68     107.0
# 36  (guide58, guide67)  guide58  guide67      94.0
# 37  (guide58, guide68)  guide58  guide68      95.0
# 38  (guide59, guide69)  guide59  guide69     105.0
# 39  (guide60, guide70)  guide60  guide70      96.0
# 40  (guide62, guide70)  guide62  guide70      93.0
# 41  (guide64, guide72)  guide64  guide72      93.0
# 42  (guide65, guide72)  guide65  guide72      91.0
# 43  (guide70, guide74)  guide70  guide74      94.0

# %%
inboth
# Out:
#        name  Benchling_position  distance_from_ATG_bp  strand  \
# 0    guide1                5721                    33       1
# 1    guide2                5693                    61       1
# 2    guide3                5690                    64      -1
# 6    guide8                5623                   131      -1
# 7    guide9                5615                   139      -1
# 8   guide10                5610                   144       1
# 9   guide11                5609                   145       1
# 10  guide12                5600                   154       1
# 11  guide13                5594                   160       1
# 12  guide14                5524                   230       1
# 13  guide15                5520                   234       1
# 14  guide16                5502                   252       1
# 19  guide25                5338                   416       1
# 22  guide29                5245                   509       1
# 28  guide45                4664                  1090      -1
# 29  guide47                4651                  1103      -1
# 30  guide48                4646                  1108      -1
# 31  guide49                4637                  1117      -1
# 32  guide50                4636                  1118      -1
# 33  guide51                4618                  1136       1
# 34  guide53                4567                  1187       1
# 35  guide54                4566                  1188       1
# 36  guide55                4549                  1205       1
# 37  guide56                4537                  1217       1
# 38  guide57                4530                  1224      -1
# 39  guide58                4518                  1236      -1
# 40  guide59                4508                  1246      -1
# 41  guide60                4474                  1280       1
# 42  guide62                4471                  1283       1
# 43  guide64                4445                  1309       1
# 44  guide65                4443                  1311      -1
# 45  guide66                4442                  1312      -1
# 46  guide67                4424                  1330      -1
# 47  guide68                4423                  1331      -1
# 48  guide69                4403                  1351       1
# 49  guide70                4378                  1376       1
# 50  guide72                4352                  1402       1
# 51  guide74                4284                  1470      -1
#
#                 sequence  PAM  specificity_score_2013  specificity_score_2016  \
# 0   GATAGAGAGACTGTGTGTTT  TGG               95.532602               55.272810
# 1   TTCAGCTTCCGGTTCTTCAT  CGG               86.672752               25.559409
# 2   ATCTCTCTCCGATGAAGAAC  CGG               93.448259               49.000705
# 6   AGGAATTAAATTGAAGAAGA  AGG               74.574487               13.560658
# 7   AATTGAAGAAGAAGGTCCCT  TGG               95.172168               40.478023
# 8   AACGTGGAGACGGAATCCAA  GGG               99.027037               77.699162
# 9   AAACGTGGAGACGGAATCCA  AGG               97.977391               54.182481
# 10  AGAACAAGAAAACGTGGAGA  CGG               88.893283               26.254992
# 11  CATTAGAGAACAAGAAAACG  TGG               88.254120               30.854637
# 12  GTTACAGTTACAGAGCAGGA  AGG               99.034700               64.583247
# 13  AGAGGTTACAGTTACAGAGC  AGG               97.466441               69.814227
# 14  TTACGGGAGAGAAATTAGAG  AGG               96.771043               52.768646
# 19  ACGGAGATAAAAGCAAACGG  AGG               97.610932               45.032528
# 22  GCGTATTATTATATACGAAA  AGG               94.692012               53.349765
# 28  TGGATAAATCATAAATGTGT  TGG               93.289762               31.023965
# 29  AATGTGTTGGCTTTTAAGGC  TGG               97.867169               78.803888
# 30  GTTGGCTTTTAAGGCTGGTA  CGG               99.207979               75.007202
# 31  TAAGGCTGGTACGGAGCGTG  AGG               99.871961               95.471715
# 32  AAGGCTGGTACGGAGCGTGA  GGG               99.832955               90.639122
# 33  TTTTGTTACCGTAACGACAA  CGG               99.161293               91.752924
# 34  GACGGACTCTTAACGATGAC  GGG               99.437377               96.559275
# 35  TGACGGACTCTTAACGATGA  CGG               97.874473               87.536225
# 36  AGAGCAAACGGTAAAAGTGA  CGG               94.227314               33.492375
# 37  GTTGCCTGCATAAGAGCAAA  CGG               98.081059               55.757868
# 38  TTTACCGTTTGCTCTTATGC  AGG               98.134930               62.689799
# 39  TCTTATGCAGGCAACAATAC  TGG               96.214061               73.270603
# 40  GCAACAATACTGGCTAGACT  TGG               96.883789               64.007854
# 41  TGTAATTTATCCAAAGAAGG  AGG               95.176285               42.135000
# 42  AAATGTAATTTATCCAAAGA  AGG               86.782387               33.704710
# 43  ATGTTAGTCCCACCATTTAG  TGG               99.196975               69.039867
# 44  ACATTTCTACCACTAAATGG  TGG               98.211841               60.260990
# 45  CATTTCTACCACTAAATGGT  GGG               98.048176               44.702241
# 46  GTGGGACTAACATAAGCATG  TGG               96.054655               47.940632
# 47  TGGGACTAACATAAGCATGT  GGG               98.174421               74.309221
# 48  AAAAGAACAAAAATCAGAGA  TGG               79.992028               21.096278
# 49  TGGAAAAAAGTTCTTGCAAA  AGG               94.855164               55.452494
# 50  TGTTTCTAATTAGTAAAATG  TGG               87.642065               18.801255
# 51  GTTGCCAAACAAATATTATC  CGG               93.556431               52.768860
#
#     efficiency_score
# 0          43.682139
# 1          42.003969
# 2          46.880008
# 6          56.049875
# 7          50.287386
# 8          66.886488
# 9          56.554217
# 10         61.194235
# 11         65.575095
# 12         63.565916
# 13         49.203698
# 14         59.830925
# 19         75.876625
# 22         54.349157
# 28         49.524607
# 29         44.894381
# 30         46.049300
# 31         52.193635
# 32         65.646605
# 33         64.441494
# 34         54.448161
# 35         58.442796
# 36         65.773570
# 37         59.329859
# 38         53.161323
# 39         49.878431
# 40         49.274240
# 41         64.903385
# 42         53.016797
# 43         46.152137
# 44         60.774181
# 45         59.163538
# 46         57.491396
# 47         70.091616
# 48         51.029101
# 49         47.718623
# 50         59.022720
# 51         46.178715

# %%
inboth = ARF9[ARF9.name.isin(pairs.guide1)| ARF9.name.isin(pairs.guide2)]

# %%
inboth
# Out:
#        name  Benchling_position  distance_from_ATG_bp  strand  \
# 0    guide1                5721                    33       1
# 1    guide2                5693                    61       1
# 2    guide3                5690                    64      -1
# 7    guide8                5623                   131      -1
# 8    guide9                5615                   139      -1
# 9   guide10                5610                   144       1
# 10  guide11                5609                   145       1
# 11  guide12                5600                   154       1
# 12  guide13                5594                   160       1
# 13  guide14                5524                   230       1
# 14  guide15                5520                   234       1
# 15  guide16                5502                   252       1
# 16  guide17                5486                   268       1
# 17  guide18                5485                   269       1
# 19  guide20                5455                   299       1
# 20  guide21                5454                   300       1
# 21  guide22                5390                   364       1
# 22  guide23                5356                   398       1
# 23  guide24                5355                   399       1
# 24  guide25                5338                   416       1
# 27  guide28                5260                   494      -1
# 28  guide29                5245                   509       1
# 31  guide32                5160                   594       1
# 32  guide33                5150                   604       1
# 33  guide34                5149                   605      -1
# 35  guide36                4962                   792       1
# 36  guide37                4915                   839      -1
# 37  guide38                4864                   890      -1
# 38  guide39                4863                   891      -1
# 40  guide41                4818                   936      -1
# 41  guide42                4710                  1044      -1
# 44  guide45                4664                  1090      -1
# 45  guide46                4655                  1099      -1
# 46  guide47                4651                  1103      -1
# 47  guide48                4646                  1108      -1
# 48  guide49                4637                  1117      -1
# 49  guide50                4636                  1118      -1
# 50  guide51                4618                  1136       1
# 51  guide52                4615                  1139      -1
# 52  guide53                4567                  1187       1
# 53  guide54                4566                  1188       1
# 54  guide55                4549                  1205       1
# 55  guide56                4537                  1217       1
# 56  guide57                4530                  1224      -1
# 57  guide58                4518                  1236      -1
# 58  guide59                4508                  1246      -1
# 59  guide60                4474                  1280       1
# 60  guide61                4473                  1281      -1
# 61  guide62                4471                  1283       1
# 62  guide63                4446                  1308      -1
# 63  guide64                4445                  1309       1
# 64  guide65                4443                  1311      -1
# 65  guide66                4442                  1312      -1
# 66  guide67                4424                  1330      -1
# 67  guide68                4423                  1331      -1
# 68  guide69                4403                  1351       1
# 69  guide70                4378                  1376       1
# 71  guide72                4352                  1402       1
# 73  guide74                4284                  1470      -1
#
#                 sequence  PAM  specificity_score_2013  specificity_score_2016  \
# 0   GATAGAGAGACTGTGTGTTT  TGG               95.532602               55.272810
# 1   TTCAGCTTCCGGTTCTTCAT  CGG               86.672752               25.559409
# 2   ATCTCTCTCCGATGAAGAAC  CGG               93.448259               49.000705
# 7   AGGAATTAAATTGAAGAAGA  AGG               74.574487               13.560658
# 8   AATTGAAGAAGAAGGTCCCT  TGG               95.172168               40.478023
# 9   AACGTGGAGACGGAATCCAA  GGG               99.027037               77.699162
# 10  AAACGTGGAGACGGAATCCA  AGG               97.977391               54.182481
# 11  AGAACAAGAAAACGTGGAGA  CGG               88.893283               26.254992
# 12  CATTAGAGAACAAGAAAACG  TGG               88.254120               30.854637
# 13  GTTACAGTTACAGAGCAGGA  AGG               99.034700               64.583247
# 14  AGAGGTTACAGTTACAGAGC  AGG               97.466441               69.814227
# 15  TTACGGGAGAGAAATTAGAG  AGG               96.771043               52.768646
# 16  ACGATAGAAGCTGGTTTTAC  GGG               97.945662               59.555845
# 17  GACGATAGAAGCTGGTTTTA  CGG               95.397690               42.768702
# 19  GAGTTTAGTCTTCTTTGTTT  GGG               84.381295               23.840908
# 20  AGAGTTTAGTCTTCTTTGTT  TGG               90.517032               29.676333
# 21  TGAGAGATTCTTTCTTGTAA  CGG               95.293655               31.756690
# 22  GGAGGTGTTAACTTAAAGAC  GGG               97.730419               71.522315
# 23  CGGAGGTGTTAACTTAAAGA  CGG               97.995609               84.353633
# 24  ACGGAGATAAAAGCAAACGG  AGG               97.610932               45.032528
# 27  TTTATATGTATGTCTAAAAT  TGG               91.151150               30.399656
# 28  GCGTATTATTATATACGAAA  AGG               94.692012               53.349765
# 31  CCTAGAAATTTGGTACTGTC  TGG               98.531547               76.987864
# 32  CAAGCTATTTCCTAGAAATT  TGG               96.660834               67.713633
# 33  CCAGACAGTACCAAATTTCT  AGG               96.712086               43.766588
# 35  GTAAAATTAAAACTGATTTT  TGG               87.307471               26.795647
# 36  ACTTTAATTTCAAATTTATT  TGG               72.290758               15.408610
# 37  AGTCAAAAACAAATAAATAA  TGG               71.751581               22.842684
# 38  GTCAAAAACAAATAAATAAT  GGG               76.361168               18.533073
# 40  TGTATAATATAGAAAATAAT  TGG               42.294919               15.585831
# 41  ATTAAATGCAATTGCGTTAG  TGG               98.040215               55.538378
# 44  TGGATAAATCATAAATGTGT  TGG               93.289762               31.023965
# 45  CATAAATGTGTTGGCTTTTA  AGG               90.043028               43.953067
# 46  AATGTGTTGGCTTTTAAGGC  TGG               97.867169               78.803888
# 47  GTTGGCTTTTAAGGCTGGTA  CGG               99.207979               75.007202
# 48  TAAGGCTGGTACGGAGCGTG  AGG               99.871961               95.471715
# 49  AAGGCTGGTACGGAGCGTGA  GGG               99.832955               90.639122
# 50  TTTTGTTACCGTAACGACAA  CGG               99.161293               91.752924
# 51  GGCGCGTGCCGTTGTCGTTA  CGG               99.866570               84.415584
# 52  GACGGACTCTTAACGATGAC  GGG               99.437377               96.559275
# 53  TGACGGACTCTTAACGATGA  CGG               97.874473               87.536225
# 54  AGAGCAAACGGTAAAAGTGA  CGG               94.227314               33.492375
# 55  GTTGCCTGCATAAGAGCAAA  CGG               98.081059               55.757868
# 56  TTTACCGTTTGCTCTTATGC  AGG               98.134930               62.689799
# 57  TCTTATGCAGGCAACAATAC  TGG               96.214061               73.270603
# 58  GCAACAATACTGGCTAGACT  TGG               96.883789               64.007854
# 59  TGTAATTTATCCAAAGAAGG  AGG               95.176285               42.135000
# 60  GCAGCTTTGACCTCCTTCTT  TGG               95.428066               63.088507
# 61  AAATGTAATTTATCCAAAGA  AGG               86.782387               33.704710
# 62  ATTACATTTCTACCACTAAA  TGG               95.649211               35.840929
# 63  ATGTTAGTCCCACCATTTAG  TGG               99.196975               69.039867
# 64  ACATTTCTACCACTAAATGG  TGG               98.211841               60.260990
# 65  CATTTCTACCACTAAATGGT  GGG               98.048176               44.702241
# 66  GTGGGACTAACATAAGCATG  TGG               96.054655               47.940632
# 67  TGGGACTAACATAAGCATGT  GGG               98.174421               74.309221
# 68  AAAAGAACAAAAATCAGAGA  TGG               79.992028               21.096278
# 69  TGGAAAAAAGTTCTTGCAAA  AGG               94.855164               55.452494
# 71  TGTTTCTAATTAGTAAAATG  TGG               87.642065               18.801255
# 73  GTTGCCAAACAAATATTATC  CGG               93.556431               52.768860
#
#     efficiency_score
# 0          43.682139
# 1          42.003969
# 2          46.880008
# 7          56.049875
# 8          50.287386
# 9          66.886488
# 10         56.554217
# 11         61.194235
# 12         65.575095
# 13         63.565916
# 14         49.203698
# 15         59.830925
# 16         35.142201
# 17         17.120214
# 19         36.963197
# 20         29.144300
# 21         45.611585
# 22         62.681496
# 23         54.802606
# 24         75.876625
# 27         26.595411
# 28         54.349157
# 31         36.350185
# 32         27.513967
# 33         30.095158
# 35         24.314397
# 36         17.530860
# 37         36.995198
# 38         29.411393
# 40         28.457460
# 41         37.464296
# 44         49.524607
# 45          0.000000
# 46         44.894381
# 47         46.049300
# 48         52.193635
# 49         65.646605
# 50         64.441494
# 51         39.335259
# 52         54.448161
# 53         58.442796
# 54         65.773570
# 55         59.329859
# 56         53.161323
# 57         49.878431
# 58         49.274240
# 59         64.903385
# 60         27.739985
# 61         53.016797
# 62         35.406781
# 63         46.152137
# 64         60.774181
# 65         59.163538
# 66         57.491396
# 67         70.091616
# 68         51.029101
# 69         47.718623
# 71         59.022720
# 73         46.178715
