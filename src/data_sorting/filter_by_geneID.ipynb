# %%
import pandas as pd
from pybedtools import BedTool

# %%
select_genes_file = '../../data/genomes/ara_housekeeping_list.out'
all_promoters_bedfile = '../../data/FIMO/promoters_renamedChr.bed'

# %%
select_genes = pd.read_table(select_genes_file, sep='\t', header=None)
cols = ['gene','gene_type']
select_genes.columns = cols
all_promoters = pd.read_table(all_promoters_bedfile, sep='\t', header=None)
cols = ['chr', 'start', 'stop', 'gene', 'dot', 'strand', 'source', 'type', 'dot2', 'details']
all_promoters.columns = cols

# %%
select_genes
# Out:
#           gene     gene_type
# 0    AT4G34270  housekeeping
# 1    AT3G32260  housekeeping
# 2    AT1G59830  housekeeping
# 3    AT4G33380  housekeeping
# 4    AT2G28390  housekeeping
# ..         ...           ...
# 401  AT1G65490      randCont
# 402  AT2G30360      randCont
# 403  AT5G56270      randCont
# 404  AT5G57785      randCont
# 405  AT2G46240      randCont
#
# [406 rows x 2 columns]

# %%
all_promoters
# Out:
#                 chr   start    stop                  gene dot strand  \
# 0                 1    2630    3630             AT1G01010   .      +
# 1                 1    9130   10130             AT1G01020   .      -
# 2                 1   10100   11100             AT1G03987   .      +
# 3                 1   13714   14714             AT1G01030   .      -
# 4                 1   22120   23120             AT1G01040   .      +
# ...             ...     ...     ...                   ...  ..    ...
# 33336  mitochondria  361052  362052  ATmitochondriaG01370   .      -
# 33337  mitochondria  361179  362179  ATmitochondriaG01380   .      -
# 33338  mitochondria  362724  363724  ATmitochondriaG01400   .      +
# 33339  mitochondria  363284  364284  ATmitochondriaG01390   .      -
# 33340  mitochondria  366700  366924  ATmitochondriaG01410   .      -
#
#           source  type dot2                                            details
# 0      Araport11  gene    .  Alias=ANAC001,NAC domain containing protein 1;...
# 1      Araport11  gene    .  Dbxref=PMID:15010618,locus:2200940;ID=AT1G0102...
# 2      Araport11  gene    .  ID=AT1G03987;Name=AT1G03987;locus_type=long_no...
# 3      Araport11  gene    .  Dbxref=PMID:11118137,PMID:15010618,PMID:166036...
# 4      Araport11  gene    .  Alias=ASU1,ABNORMAL SUSPENSOR 1,ATDCL1,DICER-L...
# ...          ...   ...  ...                                                ...
# 33336  Araport11  gene    .  Dbxref=locus:504954620;ID=ATmitochondriaG01370...
# 33337  Araport11  gene    .  Dbxref=PmitochondriaID:15067383,PmitochondriaI...
# 33338  Araport11  gene    .  Dbxref=locus:504954623;ID=ATmitochondriaG01400...
# 33339  Araport11  gene    .  Dbxref=PmitochondriaID:14586555,PmitochondriaI...
# 33340  Araport11  gene    .  Dbxref=locus:504954624;ID=ATmitochondriaG01410...
#
# [33341 rows x 10 columns]

# %% [markdown]
# ### filter out unwanted genes

# %%
merged = pd.merge(select_genes, all_promoters, on='gene')

# %%
merged
# Out:
#           gene     gene_type chr     start      stop dot strand     source  \
# 0    AT4G34270  housekeeping   4  16406303  16407303   .      -  Araport11
# 1    AT3G32260  housekeeping   3  13218167  13219167   .      +  Araport11
# 2    AT1G59830  housekeeping   1  22022503  22023503   .      -  Araport11
# 3    AT4G33380  housekeeping   4  16070739  16071739   .      +  Araport11
# 4    AT2G28390  housekeeping   2  12143665  12144665   .      -  Araport11
# ..         ...           ...  ..       ...       ...  ..    ...        ...
# 401  AT1G65490      randCont   1  24353645  24354645   .      +  Araport11
# 402  AT2G30360      randCont   2  12938834  12939834   .      -  Araport11
# 403  AT5G56270      randCont   5  22778613  22779613   .      +  Araport11
# 404  AT5G57785      randCont   5  23409715  23410715   .      -  Araport11
# 405  AT2G46240      randCont   2  18985132  18986132   .      +  Araport11
#
#      type dot2                                            details
# 0    gene    .  Dbxref=PMID:8893552,PMID:16166256,PMID:1708550...
# 1    gene    .  Dbxref=PMID:16166256,locus:2084673;ID=AT3G3226...
# 2    gene    .  Dbxref=PMID:10091592,PMID:10080713,PMID:986939...
# 3    gene    .  Dbxref=PMID:16166256,PMID:17085508,PMID:179083...
# 4    gene    .  Alias=MON1,MONENSIN SENSITIVITY1;Dbxref=PMID:1...
# ..    ...  ...                                                ...
# 401  gene    .  Dbxref=PMID:15894741,PMID:18650403,PMID:207364...
# 402  gene    .  Alias=CIPK11,CBL-INTERACTING PROTEIN KINASE 11...
# 403  gene    .  Alias=ATWRKY2,ARABIDOPSIS THALIANA WRKY DNA-BI...
# 404  gene    .  Dbxref=PMID:16258012,PMID:16792696,PMID:203512...
# 405  gene    .  Alias=ATBAG6,ARABIDOPSIS THALIANA BCL-2-ASSOCI...
#
# [406 rows x 11 columns]

# %%
#check if any NaN
merged[pd.isna(merged.chr)]
# Out:
# Empty DataFrame
# Columns: [gene, gene_type, chr, start, stop, dot, strand, source, type, dot2, details]
# Index: []

# %% [markdown]
# ### change column order to bed file format

# %%
filtered_proms = merged.loc[:, ['chr', 'start', 'stop', 'gene', 'dot', 'strand', 'source', 'type', 'dot2', 'details']]
#sort the df by chromosome then by motif start position
filtered_proms_sorted = filtered_proms.sort_values(['chr','start'])

# %%
filtered_proms_sorted
# Out:
#     chr     start      stop       gene dot strand     source  type dot2  \
# 229   1     33171     34171  AT1G01050   .      -  Araport11  gene    .
# 157   1    281760    282760  AT1G01780   .      +  Araport11  gene    .
# 45    1    316090    317090  AT1G01910   .      -  Araport11  gene    .
# 181   1    344515    345515  AT1G02000   .      +  Araport11  gene    .
# 149   1    728829    729829  AT1G03070   .      +  Araport11  gene    .
# ..   ..       ...       ...        ...  ..    ...        ...   ...  ...
# 346   5  26120581  26121581  AT5G65360   .      -  Araport11  gene    .
# 286   5  26171008  26172008  AT5G65470   .      +  Araport11  gene    .
# 360   5  26467531  26468531  AT5G66250   .      +  Araport11  gene    .
# 154   5  26817948  26818948  AT5G67210   .      +  Araport11  gene    .
# 210   5  26956914  26957914  AT5G67590   .      +  Araport11  gene    .
#
#                                                details
# 229  Alias=AtPPa1,pyrophosphorylase 1;Dbxref=PMID:1...
# 157  Dbxref=PMID:15642518,PMID:15659355,PMID:155317...
# 45   Dbxref=PMID:18315867,PMID:18775970,PMID:207364...
# 181  Dbxref=PMID:15247385,PMID:15911562,PMID:187759...
# 149  Alias=AtLFG4,LFG4,LIFEGUARD 4;Dbxref=PMID:1708...
# ..                                                 ...
# 346  Alias=H3.1,histone 3.1;Dbxref=PMID:12662315,PM...
# 286  Dbxref=PMID:18775970,locus:2168297;ID=AT5G6547...
# 360  Dbxref=PMID:18650403,PMID:18775970,PMID:207364...
# 154  Dbxref=PMID:21251108,PMID:21288268,locus:21555...
# 210  Dbxref=PMID:12084824,PMID:12837548,PMID:146710...
#
# [406 rows x 10 columns]

# %% [markdown]
# ### write out bed file of merged dfs

# %%
BedTool.from_dataframe(filtered_proms_sorted).saveas('../../data/FIMO/responsivepromoters.bed')
# Out:
# <BedTool(../../data/FIMO/responsivepromoters.bed)>
