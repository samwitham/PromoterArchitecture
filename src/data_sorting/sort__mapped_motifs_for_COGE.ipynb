# %%
#rearrange promoters motifs mapped.bed for COGE genome browser
#I make feature type the TF family

# %%
import pandas as pd
import numpy as np

# %%
motifs_mapped = '../../data/output/non-overlapping_includingbidirectional_all_genes_newannotation/FIMO/promoters_5UTR_motifs_mapped.bed'
output = '../../data/output/non-overlapping_includingbidirectional_all_genes_newannotation/FIMO/promoters_5UTR_motifs_mapped_for_COGE.gff3'

# %%
motifs_df = pd.read_table(motifs_mapped, sep='\t', header=None)
cols = ['chr', 'start', 'stop', 'name_rep', 'score', 'strand', 'promoter_AGI', 'p-value', 'q-value', 'matched_sequence','TF_name','TF_family','TF_AGI']
motifs_df.columns = cols
motifs_df['dot1'] ='.'
motifs_df['source'] = 'FIMO_Q0.05_threshold'
motifs_df['attributes'] = 'ID='+motifs_df.TF_AGI+';q-value='+motifs_df['q-value'].astype(str)+';promoter='+motifs_df.promoter_AGI.astype(str)+';TF_name='+motifs_df.TF_name.astype(str)+';TF_family='+motifs_df.TF_family.astype(str)
motifs_df['dot2'] = '.'
#make start 1 based
motifs_df['start'] = motifs_df['start'] + 1

# %%
#search
promoters = ['AT4G24020','AT4G23980', 'AT3G61830','AT1G21910']
families = ['ARF','AP2EREBP','NLP']

promoters_of_interest = motifs_df[motifs_df.promoter_AGI.str.contains('|'.join(promoters ))]

# %%
DREB26 = motifs_df[motifs_df.promoter_AGI.str.contains('AT1G21910')]
ARF9 = motifs_df[motifs_df.promoter_AGI.str.contains('AT4G23980')]
ARF18 = motifs_df[motifs_df.promoter_AGI.str.contains('AT3G61830')]
NLP7 = motifs_df[motifs_df.promoter_AGI.str.contains('AT4G24020')]

# %%
DREB26_output = motifs_df[motifs_df.TF_AGI == 'AT1G21910'].promoter_AGI.unique()
NLP7_output = motifs_df[motifs_df.TF_AGI == 'AT4G24020'].promoter_AGI.unique()
for v in NLP7_output:
    print(v)

# %%
AT4G05490 = motifs_df[motifs_df.promoter_AGI.str.contains('AT4G05490')]
AT4G05490[AT4G05490.TF_family == 'RWPRK']
# Out:
#         chr    start     stop              name_rep    score strand  \
# 724860    4  2772318  2772336  RWPRK_tnt.RKD2_col_a  23.4921      +
#
#        promoter_AGI       p-value  q-value     matched_sequence TF_name  \
# 724860    AT4G05490  3.610000e-09   0.0368  CTGACCTTTCGGCTTCCTT    RKD2
#
#        TF_family     TF_AGI dot1                source  \
# 724860     RWPRK  AT1G74480    .  FIMO_Q0.05_threshold
#
#                                                attributes dot2
# 724860  ID=AT1G74480;q-value=0.0368;promoter=AT4G05490...    .

# %%
arf_family = motifs_df[motifs_df.TF_family == 'ARF'].promoter_AGI.unique()
nlp_family = motifs_df[motifs_df.TF_family == 'NLP'].promoter_AGI.unique()
erf_family = motifs_df[motifs_df.TF_family == 'AP2EREBP'].promoter_AGI.unique()
RWPRK = motifs_df[motifs_df.TF_family == 'RWPRK'].promoter_AGI.unique()
for v in RWPRK:
    print(v)
# Out:
# AT2G32240
# AT2G42490
# AT3G24840
# AT4G05490

# %%
 =countif(C:C,C1)>1

# %%
promoters_of_interest[promoters_of_interest.TF_family.str.contains('|'.join(families))]
# Out:
# Empty DataFrame
# Columns: [chr, start, stop, name_rep, score, strand, promoter_AGI, p-value, q-value, matched_sequence, TF_name, TF_family, TF_AGI, dot1, source, attributes, dot2]
# Index: []

# %%
motifs_df[motifs_df.TF_name.str.contains('|'.join(families ))]
# Out:
#          chr     start      stop              name_rep    score strand  \
# 5354       1    431506    431526   ARF_tnt.ARF16_col_b  28.6076      +
# 5356       1    431584    431604   ARF_tnt.ARF16_col_b  24.6582      +
# 5358       1    431619    431639   ARF_tnt.ARF16_col_b  38.3924      +
# 5364       1    431645    431665   ARF_tnt.ARF16_col_b  15.2278      -
# 5366       1    431692    431712   ARF_tnt.ARF16_col_b  25.2658      +
# ...      ...       ...       ...                   ...      ...    ...
# 1108714    5  24975789  24975809   ARF_tnt.ARF16_col_b  13.2911      +
# 1126963    5  26482139  26482159   ARF_tnt.ARF16_col_b  15.7089      -
# 1128101    5  26579325  26579339  NLP_tnt.AtNLP4_col_b  19.9118      +
# 1132356    5  26915851  26915865  NLP_tnt.AtNLP4_col_b  21.5735      -
# 1132357    5  26915854  26915868  NLP_tnt.AtNLP4_col_b  21.5735      -
#
#         promoter_AGI       p-value       q-value       matched_sequence  \
# 5354       AT1G02220  2.290000e-10  4.870000e-05  TTTACGATTTTGACGGAAAAA
# 5356       AT1G02220  2.280000e-09  3.790000e-04  TTTACAGTTTCGACGGGAAAA
# 5358       AT1G02220  1.530000e-13  3.160000e-07  TTTACGGTTTTGGCGGGAAAA
# 5364       AT1G02220  1.940000e-07  2.010000e-02  ATCACGATTTTGGTAGAAAAA
# 5366       AT1G02220  1.660000e-09  2.920000e-04  TTTACAGTTTTGGTGAGAAAA
# ...              ...           ...           ...                    ...
# 1108714    AT5G62170  4.210000e-07  3.810000e-02  ATTACATTTTTGGTTAGAAAA
# 1126963    AT5G66300  1.590000e-07  1.700000e-02  CTTTTGGTTTTGGCTGAAAAA
# 1128101    AT5G66600  9.010000e-09  1.830000e-02        GCAGCAGCAGAAGCC
# 1132356    AT5G67440  2.850000e-10  5.510000e-03        GCAGCAGCAGCAGCA
# 1132357    AT5G67440  2.850000e-10  5.510000e-03        GCAGCAGCAGCAGCA
#
#         TF_name TF_family     TF_AGI dot1                source  \
# 5354      ARF16       ARF  AT4G30080    .  FIMO_Q0.05_threshold
# 5356      ARF16       ARF  AT4G30080    .  FIMO_Q0.05_threshold
# 5358      ARF16       ARF  AT4G30080    .  FIMO_Q0.05_threshold
# 5364      ARF16       ARF  AT4G30080    .  FIMO_Q0.05_threshold
# 5366      ARF16       ARF  AT4G30080    .  FIMO_Q0.05_threshold
# ...         ...       ...        ...  ...                   ...
# 1108714   ARF16       ARF  AT4G30080    .  FIMO_Q0.05_threshold
# 1126963   ARF16       ARF  AT4G30080    .  FIMO_Q0.05_threshold
# 1128101  ATNLP4       NLP  AT1G20640    .  FIMO_Q0.05_threshold
# 1132356  ATNLP4       NLP  AT1G20640    .  FIMO_Q0.05_threshold
# 1132357  ATNLP4       NLP  AT1G20640    .  FIMO_Q0.05_threshold
#
#                                                 attributes dot2
# 5354     ID=AT4G30080;q-value=4.870000000000001e-05;pro...    .
# 5356     ID=AT4G30080;q-value=0.000379;promoter=AT1G022...    .
# 5358     ID=AT4G30080;q-value=3.16e-07;promoter=AT1G022...    .
# 5364     ID=AT4G30080;q-value=0.0201;promoter=AT1G02220...    .
# 5366     ID=AT4G30080;q-value=0.000292;promoter=AT1G022...    .
# ...                                                    ...  ...
# 1108714  ID=AT4G30080;q-value=0.0381;promoter=AT5G62170...    .
# 1126963  ID=AT4G30080;q-value=0.017;promoter=AT5G66300;...    .
# 1128101  ID=AT1G20640;q-value=0.0183;promoter=AT5G66600...    .
# 1132356  ID=AT1G20640;q-value=0.00551;promoter=AT5G6744...    .
# 1132357  ID=AT1G20640;q-value=0.00551;promoter=AT5G6744...    .
#
# [490 rows x 17 columns]

# %%
promoters_of_interest.TF_family.unique()
# Out:
# array(['ABI3VP1', 'C2C2DOF', 'REM', 'ND', 'BBRBPC', 'C2H2', 'MYBRELATED',
#        'C2C2COLIKE', 'C2C2GATA', 'BHLH'], dtype=object)

# %%
#motifs_df = motifs_df[['chr', 'start', 'stop','TF_AGI','dot1', 'strand', 'source','TF_family','dot2','attributes']]
#convert to gff3
motifs_df = motifs_df[['chr', 'source','TF_family', 'start','stop','dot1', 'strand','dot2','attributes']]

# %%
motifs_df
# Out:
#          chr                source TF_family     start      stop dot1 strand  \
# 0          1  FIMO_Q0.05_threshold   ABI3VP1      3132      3150    .      +
# 1          1  FIMO_Q0.05_threshold       REM      3561      3581    .      +
# 2          1  FIMO_Q0.05_threshold   ABI3VP1      3561      3589    .      -
# 3          1  FIMO_Q0.05_threshold   ABI3VP1      3562      3590    .      -
# 4          1  FIMO_Q0.05_threshold   C2C2DOF      3562      3588    .      -
# ...      ...                   ...       ...       ...       ...  ...    ...
# 1133381    5  FIMO_Q0.05_threshold   ABI3VP1  26971051  26971079    .      -
# 1133382    5  FIMO_Q0.05_threshold   ABI3VP1  26971052  26971080    .      -
# 1133383    5  FIMO_Q0.05_threshold   ABI3VP1  26971063  26971091    .      -
# 1133384    5  FIMO_Q0.05_threshold       NAC  26971534  26971554    .      +
# 1133385    5  FIMO_Q0.05_threshold       NAC  26971535  26971557    .      +
#
#         dot2                                         attributes
# 0          .  ID=AT3G18990;q-value=0.0131;promoter=AT1G01010...
# 1          .  ID=AT1G49480;q-value=0.0389;promoter=AT1G01010...
# 2          .  ID=AT3G18990;q-value=0.0301;promoter=AT1G01010...
# 3          .  ID=AT3G18990;q-value=0.0276;promoter=AT1G01010...
# 4          .  ID=AT1G69570;q-value=0.0429;promoter=AT1G01010...
# ...      ...                                                ...
# 1133381    .  ID=AT3G18990;q-value=0.0282;promoter=AT5G67640...
# 1133382    .  ID=AT3G18990;q-value=0.024;promoter=AT5G67640;...
# 1133383    .  ID=AT3G18990;q-value=0.0307;promoter=AT5G67640...
# 1133384    .  ID=AT1G32510;q-value=0.0399;promoter=AT5G67640...
# 1133385    .  ID=AT4G36160;q-value=0.0357;promoter=AT5G67640...
#
# [1133386 rows x 9 columns]

# %%
motifs_df.to_csv(output, sep='\t', header=None,index=None)
