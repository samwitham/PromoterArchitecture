# %%
import pandas as pd
from pybedtools import BedTool
import numpy as np

# %% [markdown]
# ## variables

# %%
fimo_file = "../../data/output/non-overlapping_includingbidirectional_all_genes_newannotation/FIMO/output/promoters_5UTR_FIMO/fimo.tsv"
promoter_bedfile = "../../data/output/non-overlapping_includingbidirectional_all_genes_newannotation/promoters_5UTR.bed"
motifs_bed = "../../data/output/non-overlapping_includingbidirectional_all_genes_newannotation/promoters_5UTR_motifs.bed"

# %% [markdown]
# ## import data

# %%
def fimo_qfilter(fimo_file, q_value):
    """this uses a meme-suite version 5 fimo.tsv file, filters by a q-value, and returns a pandas df"""
    fimo = pd.read_table(fimo_file, sep='\t', engine='python')
    #rename sequence column to just the AGI code
    fimo.sequence_name = fimo.sequence_name.str.extract(r'(.*?)\:')
    #filter
    fimo_qfilter = fimo[fimo['q-value'] <= q_value]    
    return fimo_qfilter

# %%
def fimo2bed(filtered_fimo_df, promoters_bed, output_bed):
    """This function creates a bed file using fimo.tsv motif file, and the promoter.bed file (chromosome number is used from this). It sorts the bedfile by chromosome then by start"""
    promoters = pd.read_table(promoters_bed, sep='\t', header=None) #read in promoter bed file
    #add column names
    cols = ['chr', 'start', 'stop', 'gene', 'dot', 'strand', 'source', 'type', 'dot2', 'details'] 
    promoters.columns = cols
    #merge promoters.bed with the fimo motif file
    merged = pd.merge(filtered_fimo_df, promoters, left_on='sequence_name', right_on='gene')
    #add motif start position to the promoter start position, and minus 1 (bed file is 0-based), and motif end to promoter start pos (bed file end coord is non-inclusive). Then format with no decimal place
    merged['correct_start'] = (merged['start_x'] + merged['start_y'] -1).astype(np.int64)
    merged['correct_stop'] = (merged['stop_x'] + merged['start_y']).astype(np.int64)
    #create motifs df in bed file column order
    motifs_df = merged.loc[:, ['chr','correct_start','correct_stop', 'motif_id', 'score', 'strand_x', 'sequence_name', 'p-value', 'q-value', 'matched_sequence']]
    #sort the df by chromosome then by motif start position
    motifs_df_sorted = motifs_df.sort_values(['chr','correct_start'])
    #create motifs bed file
    motifs = BedTool.from_dataframe(motifs_df_sorted).saveas(output_bed)

# %%
fimo = pd.read_table(fimo_file, sep='\t')

# %%
fimo.head()
# Out:
#                    motif_id motif_alt_id                   sequence_name  \
# 0  BBRBPC_tnt.BPC5_col_a_m1         MEME    AT5G14390::5:4639575-4640835
# 1  BBRBPC_tnt.BPC5_col_a_m1         MEME  AT4G32530::4:15694958-15696283
# 2  BBRBPC_tnt.BPC5_col_a_m1         MEME    AT5G14390::5:4639575-4640835
# 3  BBRBPC_tnt.BPC5_col_a_m1         MEME  AT4G32530::4:15694958-15696283
# 4  BBRBPC_tnt.BPC5_col_a_m1         MEME  AT4G32530::4:15694958-15696283
#
#    start  stop strand    score       p-value       q-value  \
# 0    1.0  30.0      -  61.8974  9.830000e-20  5.800000e-15
# 1    2.0  31.0      -  61.8974  9.830000e-20  5.800000e-15
# 2    3.0  32.0      -  61.8974  9.830000e-20  5.800000e-15
# 3    4.0  33.0      -  61.8974  9.830000e-20  5.800000e-15
# 4    6.0  35.0      -  61.8974  9.830000e-20  5.800000e-15
#
#                  matched_sequence
# 0  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 1  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 2  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 3  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 4  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG

# %%
fimo.sequence_name
# Out:
# 0            AT5G14390::5:4639575-4640835
# 1          AT4G32530::4:15694958-15696283
# 2            AT5G14390::5:4639575-4640835
# 3          AT4G32530::4:15694958-15696283
# 4          AT4G32530::4:15694958-15696283
#                         ...
# 8661525    AT5G57565::5:23309283-23310871
# 8661526      AT1G20690::1:7173437-7175085
# 8661527                               NaN
# 8661528                               NaN
# 8661529                               NaN
# Name: sequence_name, Length: 8661530, dtype: object

# %%
fimo.sequence_name = fimo.sequence_name.str.extract(r'(.*?)\:')

# %%
fimo
# Out:
#                                                   motif_id motif_alt_id  \
# 0                                 BBRBPC_tnt.BPC5_col_a_m1         MEME
# 1                                 BBRBPC_tnt.BPC5_col_a_m1         MEME
# 2                                 BBRBPC_tnt.BPC5_col_a_m1         MEME
# 3                                 BBRBPC_tnt.BPC5_col_a_m1         MEME
# 4                                 BBRBPC_tnt.BPC5_col_a_m1         MEME
# ...                                                    ...          ...
# 8661525                      AP2EREBP_tnt.ERF2_colamp_a_m1         MEME
# 8661526                      AP2EREBP_tnt.ERF2_colamp_a_m1         MEME
# 8661527  # FIMO (Find Individual Motif Occurrences): Ve...          NaN
# 8661528  # The format of this file is described at http...          NaN
# 8661529  # fimo --bfile ../../data/output/non-overlappi...          NaN
#
#         sequence_name   start    stop strand     score       p-value  \
# 0           AT5G14390     1.0    30.0      -  61.89740  9.830000e-20
# 1           AT4G32530     2.0    31.0      -  61.89740  9.830000e-20
# 2           AT5G14390     3.0    32.0      -  61.89740  9.830000e-20
# 3           AT4G32530     4.0    33.0      -  61.89740  9.830000e-20
# 4           AT4G32530     6.0    35.0      -  61.89740  9.830000e-20
# ...               ...     ...     ...    ...       ...           ...
# 8661525     AT5G57565  1338.0  1358.0      +   4.77778  1.000000e-04
# 8661526     AT1G20690  1399.0  1419.0      +   4.77778  1.000000e-04
# 8661527           NaN     NaN     NaN    NaN       NaN           NaN
# 8661528           NaN     NaN     NaN    NaN       NaN           NaN
# 8661529           NaN     NaN     NaN    NaN       NaN           NaN
#
#               q-value                matched_sequence
# 0        5.800000e-15  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 1        5.800000e-15  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 2        5.800000e-15  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 3        5.800000e-15  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 4        5.800000e-15  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# ...               ...                             ...
# 8661525  2.940000e-01           CTGTGGCCAAATCATCCTCCA
# 8661526  2.940000e-01           CGGCTCATGCTCCGGCCTTCT
# 8661527           NaN                             NaN
# 8661528           NaN                             NaN
# 8661529           NaN                             NaN
#
# [8661530 rows x 10 columns]

# %%
len(fimo)
# Out:
# 10803002

# %%
#filter qvalues below
fimo_qfilter = fimo[fimo['q-value'] <= 0.05]
fimo_qfilter.head()
# Out:
#                    motif_id motif_alt_id sequence_name  start  stop strand  \
# 0  BBRBPC_tnt.BPC5_col_a_m1         MEME     AT4G38760    1.0  30.0      +
# 1  BBRBPC_tnt.BPC5_col_a_m1         MEME     AT1G33350    2.0  31.0      +
# 2  BBRBPC_tnt.BPC5_col_a_m1         MEME     AT3G30580    2.0  31.0      +
# 3  BBRBPC_tnt.BPC5_col_a_m1         MEME     AT3G47600    2.0  31.0      +
# 4  BBRBPC_tnt.BPC5_col_a_m1         MEME     AT3G55960    2.0  31.0      +
#
#      score       p-value       q-value                matched_sequence
# 0  61.3544  1.460000e-19  1.350000e-14  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 1  61.3544  1.460000e-19  1.350000e-14  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 2  61.3544  1.460000e-19  1.350000e-14  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 3  61.3544  1.460000e-19  1.350000e-14  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG
# 4  61.3544  1.460000e-19  1.350000e-14  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG

# %%
len(fimo_qfilter)
# Out:
# 1346100

# %%
#need to read in the promoter gff file to find chromosome no. of each promoter
promoters = pd.read_table(promoter_bedfile, sep='\t', header=None)
cols = ['chr', 'start', 'stop', 'gene', 'dot', 'strand', 'source', 'type', 'dot2', 'details']
promoters.columns = cols
promoters.head()
# Out:
#   chr  start   stop       gene dot strand     source  type dot2  \
# 0   1   2630   3630  AT1G01010   .      +  Araport11  gene    .
# 1   1   9130  10130  AT1G01020   .      -  Araport11  gene    .
# 2   1  10100  11100  AT1G03987   .      +  Araport11  gene    .
# 3   1  13714  14714  AT1G01030   .      -  Araport11  gene    .
# 4   1  22120  23120  AT1G01040   .      +  Araport11  gene    .
#
#                                              details
# 0  Alias=ANAC001,NAC domain containing protein 1;...
# 1  Dbxref=PMID:15010618,locus:2200940;ID=AT1G0102...
# 2  ID=AT1G03987;Name=AT1G03987;locus_type=long_no...
# 3  Dbxref=PMID:11118137,PMID:15010618,PMID:166036...
# 4  Alias=ASU1,ABNORMAL SUSPENSOR 1,ATDCL1,DICER-L...

# %%
merged = pd.merge(fimo_qfilter, promoters, left_on='sequence_name', right_on='gene')
merged_outer = pd.merge(fimo_qfilter, promoters, left_on='sequence_name', right_on='gene', how='outer')
merged.head()
# Out:
#                       motif_id motif_alt_id sequence_name  start_x  stop_x  \
# 0     BBRBPC_tnt.BPC5_col_a_m1         MEME     AT4G38760      1.0    30.0
# 1     BBRBPC_tnt.BPC5_col_a_m1         MEME     AT4G38760      3.0    32.0
# 2  BBRBPC_tnt.BPC5_colamp_a_m1         MEME     AT4G38760      2.0    30.0
# 3  BBRBPC_tnt.BPC5_colamp_a_m1         MEME     AT4G38760      4.0    32.0
# 4     BBRBPC_tnt.BPC5_col_a_m1         MEME     AT4G38760      5.0    34.0
#
#   strand_x    score       p-value       q-value  \
# 0        +  61.3544  1.460000e-19  1.350000e-14
# 1        +  61.3544  1.460000e-19  1.350000e-14
# 2        +  49.1860  4.370000e-19  3.860000e-14
# 3        +  49.1860  4.370000e-19  3.860000e-14
# 4        +  55.4430  2.630000e-18  2.310000e-13
#
#                  matched_sequence chr   start_y    stop_y       gene dot  \
# 0  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG   4  18096218  18097218  AT4G38760   .
# 1  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG   4  18096218  18097218  AT4G38760   .
# 2   GAGAGAGAGAGAGAGAGAGAGAGAGAGAG   4  18096218  18097218  AT4G38760   .
# 3   GAGAGAGAGAGAGAGAGAGAGAGAGAGAG   4  18096218  18097218  AT4G38760   .
# 4  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAT   4  18096218  18097218  AT4G38760   .
#
#   strand_y     source  type dot2  \
# 0        -  Araport11  gene    .
# 1        -  Araport11  gene    .
# 2        -  Araport11  gene    .
# 3        -  Araport11  gene    .
# 4        -  Araport11  gene    .
#
#                                              details
# 0  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 1  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 2  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 3  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 4  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...

# %%
len(merged)
# Out:
# 1346100

# %%
len(merged)
# Out:
# 1346710

# %%
#these promoters had no motifs found in them - 610 promoters
no_motifs = merged[merged['sequence_name'].isnull()]

# %%
no_motifs.head()
# Out:
#         motif_id motif_alt_id sequence_name  start_x  stop_x strand_x  score  \
# 1346100      NaN          NaN           NaN      NaN     NaN      NaN    NaN
# 1346101      NaN          NaN           NaN      NaN     NaN      NaN    NaN
# 1346102      NaN          NaN           NaN      NaN     NaN      NaN    NaN
# 1346103      NaN          NaN           NaN      NaN     NaN      NaN    NaN
# 1346104      NaN          NaN           NaN      NaN     NaN      NaN    NaN
#
#          p-value  q-value matched_sequence chr  start_y   stop_y       gene  \
# 1346100      NaN      NaN              NaN   1   201102   202102  AT1G01560
# 1346101      NaN      NaN              NaN   1  1914895  1915895  AT1G06250
# 1346102      NaN      NaN              NaN   1  1945745  1946745  AT1G06390
# 1346103      NaN      NaN              NaN   1  2011109  2012109  AT1G04483
# 1346104      NaN      NaN              NaN   1  2167560  2168560  AT1G07070
#
#         dot strand_y     source  type dot2  \
# 1346100   .        +  Araport11  gene    .
# 1346101   .        -  Araport11  gene    .
# 1346102   .        +  Araport11  gene    .
# 1346103   .        -  Araport11  gene    .
# 1346104   .        +  Araport11  gene    .
#
#                                                    details
# 1346100  Alias=ATMPK11,MAP kinase 11;Dbxref=PMID:115441...
# 1346101  Dbxref=PMID:15130548,PMID:18433503,PMID:235053...
# 1346102  Alias=ATGSK1,ATSK2-3,A. THALIANA SHAGGY-LIKE K...
# 1346103  ID=AT1G04483;Name=AT1G04483;Note=Natural antis...
# 1346104  Dbxref=PMID:15310832,PMID:16297073,PMID:179342...

# %%
#not all promoters had motifs found in them!

# %%
#need to add motif start to the promoter start -1, and motif end to promoter start -1
merged['correct_start'] = merged['start_x'] + merged['start_y'] -1
merged['correct_stop'] = merged['stop_x'] + merged['start_y'] -1

merged.head()
# Out:
#                       motif_id motif_alt_id sequence_name  start_x  stop_x  \
# 0     BBRBPC_tnt.BPC5_col_a_m1         MEME     AT4G38760      1.0    30.0
# 1     BBRBPC_tnt.BPC5_col_a_m1         MEME     AT4G38760      3.0    32.0
# 2  BBRBPC_tnt.BPC5_colamp_a_m1         MEME     AT4G38760      2.0    30.0
# 3  BBRBPC_tnt.BPC5_colamp_a_m1         MEME     AT4G38760      4.0    32.0
# 4     BBRBPC_tnt.BPC5_col_a_m1         MEME     AT4G38760      5.0    34.0
#
#   strand_x    score       p-value       q-value  \
# 0        +  61.3544  1.460000e-19  1.350000e-14
# 1        +  61.3544  1.460000e-19  1.350000e-14
# 2        +  49.1860  4.370000e-19  3.860000e-14
# 3        +  49.1860  4.370000e-19  3.860000e-14
# 4        +  55.4430  2.630000e-18  2.310000e-13
#
#                  matched_sequence  ...    stop_y       gene  dot strand_y  \
# 0  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG  ...  18097218  AT4G38760    .        -
# 1  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAG  ...  18097218  AT4G38760    .        -
# 2   GAGAGAGAGAGAGAGAGAGAGAGAGAGAG  ...  18097218  AT4G38760    .        -
# 3   GAGAGAGAGAGAGAGAGAGAGAGAGAGAG  ...  18097218  AT4G38760    .        -
# 4  AGAGAGAGAGAGAGAGAGAGAGAGAGAGAT  ...  18097218  AT4G38760    .        -
#
#       source  type dot2                                            details  \
# 0  Araport11  gene    .  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 1  Araport11  gene    .  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 2  Araport11  gene    .  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 3  Araport11  gene    .  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
# 4  Araport11  gene    .  Dbxref=locus:2141767;ID=AT4G38760;Name=AT4G387...
#
#   correct_start correct_stop
# 0    18096218.0   18096247.0
# 1    18096220.0   18096249.0
# 2    18096219.0   18096247.0
# 3    18096221.0   18096249.0
# 4    18096222.0   18096251.0
#
# [5 rows x 22 columns]

# %%
#create motifs df
motifs_df = merged.loc[:, ['chr','correct_start','correct_stop', 'motif_id', 'score', 'strand_x',]]
motifs_df.head()
# Out:
#   chr  correct_start  correct_stop                     motif_id    score  \
# 0   4     18096218.0    18096247.0     BBRBPC_tnt.BPC5_col_a_m1  61.3544
# 1   4     18096220.0    18096249.0     BBRBPC_tnt.BPC5_col_a_m1  61.3544
# 2   4     18096219.0    18096247.0  BBRBPC_tnt.BPC5_colamp_a_m1  49.1860
# 3   4     18096221.0    18096249.0  BBRBPC_tnt.BPC5_colamp_a_m1  49.1860
# 4   4     18096222.0    18096251.0     BBRBPC_tnt.BPC5_col_a_m1  55.4430
#
#   strand_x
# 0        +
# 1        +
# 2        +
# 3        +
# 4        +

# %%
#sort by chromosome then by start position
motifs_df_sorted = motifs_df.sort_values(['chr','correct_start'])

# %%
#create motifs bed file
motifs = BedTool.from_dataframe(motifs_df_sorted).saveas('../../data/FIMO/motifs.bed')

# %%
#same again using the functions
filtered_fimo = fimo_qfilter(fimo_file, 0.05)
fimo2bed(filtered_fimo, promoter_bedfile, motifs_bed)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-9-6e225a2f9c19> in <module>
#       1 #same again using the functions
# ----> 2 filtered_fimo = fimo_qfilter(fimo_file, 0.05)
#       3 fimo2bed(filtered_fimo, promoter_bedfile, motifs_bed)
#
# <ipython-input-8-fed0dfa3953f> in fimo_qfilter(fimo_file, q_value)
#       1 def fimo_qfilter(fimo_file, q_value):
#       2     """this uses a meme-suite version 5 fimo.tsv file, filters by a q-value, and returns a pandas df"""
# ----> 3     fimo = pd.read_table(fimo_file, sep='\t', engine='python')
#       4     fimo_qfilter = fimo[fimo['q-value'] <= q_value]
#       5     return fimo_qfilter
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1145                     ' "python-fwf")'.format(engine=engine)
#    1146                 )
# -> 1147             self._engine = klass(self.f, **self.options)
#    1148
#    1149     def _failover_to_python(self):
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2308             self.num_original_columns,
#    2309             self.unnamed_cols,
# -> 2310         ) = self._infer_columns()
#    2311
#    2312         # Now self.columns has the set of columns that we will process.
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in _infer_columns(self)
#    2591             for level, hr in enumerate(header):
#    2592                 try:
# -> 2593                     line = self._buffered_line()
#    2594
#    2595                     while self.line_pos <= hr:
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in _buffered_line(self)
#    2774             return self.buf[0]
#    2775         else:
# -> 2776             return self._next_line()
#    2777
#    2778     def _check_for_bom(self, first_row):
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in _next_line(self)
#    2871
#    2872             while True:
# -> 2873                 orig_line = self._next_iter_line(row_num=self.pos + 1)
#    2874                 self.pos += 1
#    2875
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/pandas/io/parsers.py in _next_iter_line(self, row_num)
#    2931
#    2932         try:
# -> 2933             return next(self.data)
#    2934         except csv.Error as e:
#    2935             if self.warn_bad_lines or self.error_bad_lines:
#
# PermissionError: [Errno 13] Permission denied

# %%
fimo_file = "../../data/FIMO/output/responsivepromoters_FIMO/fimo.tsv"
promoter_bedfile = "../../data/FIMO/responsivepromoters.bed"
motifs_bed = "../../data/FIMO/responsivepromoters_motifs.bed"
