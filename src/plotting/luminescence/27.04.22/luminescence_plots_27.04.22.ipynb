# %%
import pandas as pd
import shutil
import numpy as np
# import skbio
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy import stats
from statsmodels.formula.api import ols
# import researchpy as rp
from matplotlib import rcParams
#from statsmodels.stats.multicomp import pairwise_tukeyhsd
#from statsmodels.stats.multicomp import MultiComparison
#dunns
from itertools import combinations

# from statsmodels.stats.multitest import multipletests
# from statsmodels.stats.libqsturng import psturng
# import warnings

# import plotly.express as px
# import plotly.graph_objects as go
import os
import re
# from plotly.subplots import make_subplots

# from statsmodels.stats.multicomp import pairwise_tukeyhsd
# from statsmodels.stats.multicomp import MultiComparison
# import statsmodels.api as sm

# import statsmodels.api as sa
# import scikit_posthocs as sp

# from pingouin import kruskal

#from statannot import add_stat_annotation
from statannotations.Annotator import Annotator
# import itertools

rcParams.update({'figure.autolayout': True})

# %%
def add_promoter_column(df,promoter_number,promoter):
    df.loc[df.name.str.match(fr'(^{promoter_number}.*)')==True, 'Promoter'] = promoter

# %%
#add TF coexpression column
def add_tf_column(df, TF_number, TF):
    """function to add TF added column based on an input df, a TF_number and a TF name"""
    df.loc[df.name.str.contains(fr'\+{TF_number}\+')&df.TF_added.isnull()==True, 'TF_added'] = TF
    for index, value in df.loc[df.name.str.contains(fr'\+{TF_number}\+')&df.TF_added.notnull()].TF_added.items():
        if re.match(fr'.*{TF}.*', value):
            pass
        else:
            df.iloc[index, df.columns.get_loc('TF_added')] = f'{value}+{TF}'

# %%
# #add TF coexpression column
# def add_tf_column(df, TF_number, TF):
#     """function to add TF added column based on an input df, a TF_number and a TF name"""
#     df.loc[df.name.str.contains(fr'.*{TF_number}.*')&df.TF_added.isnull()==True, 'TF_added'] = TF
#     for index, value in df.loc[df.name.str.contains(fr'.*{TF_number}.*')&df.TF_added.notnull()].TF_added.items():
#         if re.match(fr'.*{TF}.*', value):
#             pass
#         else:
#             df.iloc[index, df.columns.get_loc('TF_added')] = f'{value}+{TF}'

# %%
# file_location = f'../../../../data/luminescence/to_be_sorted/{date}/plate1_output_raw.csv'
# plate_df = pd.read_csv(file_location, header=0)
# TF = 'NLP6'
# #plate_df.loc[plate_df.name.str.contains(fr'\+27\+')]#(?=\+)
# for index, value in plate_df.loc[plate_df.name.str.contains(fr'27')].name.items():
#     print(value)   
#     print(re.match(fr'.*27.*', value))

# %%
def add_wellcalibrator_column(df,calibrator_code,calibrator):
    #if ends with calibrator_code, change well calibrator column value to the well calibrator name
    df.loc[df.name.str.contains(fr'.*{calibrator_code}$')==True, 'Well_calibrator'] = calibrator

# %%
def batch_correction(df,calibrator_promoter_name,ignore_calibration=False):
   #print(df[df.Promoter==calibrator_promoter_name])
    if ignore_calibration ==False:
        calibrator = df[df.Promoter==calibrator_promoter_name]
        print(calibrator)
        #make sure the condition is "calibrator"
        calibrator = calibrator[calibrator.condition=='calibrator']
        print(calibrator)
        #exclude the NAA condition
        #calibrator_no_NAA = calibrator[calibrator.condition=='nitrogen']
        #exclude added TFs or YFP
        calibrator_no_TFs = calibrator[calibrator.TF_added=='No TF nor YFP']
        calibrator_mean = calibrator_no_TFs['nluc/fluc'].mean(axis=0)
        df['corrected_luminescence'] = df['nluc/fluc']/calibrator_mean*100
    elif ignore_calibration==True:
        df['corrected_luminescence'] = df['nluc/fluc']

# %%
def combine_plates(plate_dict, date):
    """combine the dfs of the plates in the plate dict"""
    for plate_number,plate_df in plate_dict.items():
        #define plate location
        file_location = f'../../../../data/luminescence/to_be_sorted/{date}/plate{plate_number}_output_raw.csv'
        #read in the plate
        plate_df = pd.read_csv(file_location, header=0)
        #add promoters to plate df
        add_promoter_column(plate_df, '14', 'ANAC032')
        add_promoter_column(plate_df, '16', 'ANR1')
        add_promoter_column(plate_df, '18', 'ARF18')
        add_promoter_column(plate_df, '20', 'NLP6')
        add_promoter_column(plate_df, '22', 'DREB26')
        add_promoter_column(plate_df, '24', 'NLP7')
        add_promoter_column(plate_df, '25', 'NIR1')
        add_promoter_column(plate_df, '35', 'NOS')
        add_promoter_column(plate_df, '36', 'STAP4')
        add_promoter_column(plate_df, '70', '35s')
        add_promoter_column(plate_df, '102', 'minimal_STAP4')
        add_promoter_column(plate_df, '103', '1xANR1')
        add_promoter_column(plate_df, '104', '1xNLP7')
        add_promoter_column(plate_df, '105', '1xTCP20+NLP7')
        add_promoter_column(plate_df, '106', '4xANR1')
        add_promoter_column(plate_df, '107', '4xNLP7')
        add_promoter_column(plate_df, '108', '4xTCP20+NLP7')
        add_promoter_column(plate_df, '109', '4xNRE')
        add_promoter_column(plate_df, '71', 'UBQ10')
        add_promoter_column(plate_df, '372', '4x[NRE-TATA]')
        add_promoter_column(plate_df, '373', '4x[NRE-TATA]+spacing')
        add_promoter_column(plate_df, '374', '4x[NRE-random]')
        add_promoter_column(plate_df, '375', '4x[NRE-random]+spacing')
        add_promoter_column(plate_df, '376', '3xHHO2-minsyn_105')
        add_promoter_column(plate_df, '377', 'minsyn_105-3xHHO2')
        add_promoter_column(plate_df, '378', '4x[bZIP3-random]')
        add_promoter_column(plate_df, '379', '4x[TGA1-random]')
        add_promoter_column(plate_df, '380', '2x[bZIP3-random-NRE-random]')
        add_promoter_column(plate_df, '381', '2x[TGA1-random-NRE-random]')
        add_promoter_column(plate_df, '92', 'NRP')
        add_promoter_column(plate_df, 'OZ223', 'NRP:NLUC:YFP')
        add_promoter_column(plate_df, 'OZ224', 'NIR1:NLUC:YFP')
        add_promoter_column(plate_df, 'OZ225', '35s:NLUC:YFP')
        add_promoter_column(plate_df, '491', '4x[NRE-TATA]+spacing:NLUC:YFP')
        add_promoter_column(plate_df, '492', '4x[bZIP3-random]:NLUC:YFP')
        add_promoter_column(plate_df, 'OZ115', '35s:NLUC:YFP_nomarker')
        add_promoter_column(plate_df, '498', 'NIR1_ablated_NRE')
        add_promoter_column(plate_df, '499', 'ANAC032_ablated_ARFs')
        add_promoter_column(plate_df, '500', 'NIR1_ablated_NRE_all_sites')
        add_promoter_column(plate_df, '501', 'ANAC032_ablated_TGA1_all_sites')
        add_promoter_column(plate_df, '502', 'NLP7_ablated_ANAC032_all_sites')

        

        #add TF column to date1 df
        plate_df['TF_added'] = np.nan
        add_tf_column(plate_df,'27','NLP6')
        add_tf_column(plate_df,'29','NLP7')
        add_tf_column(plate_df,'30','DREB26')
        add_tf_column(plate_df,'31','ANAC032')
        add_tf_column(plate_df,'32','ARF18')
        add_tf_column(plate_df,'33','ANR1')
        add_tf_column(plate_df,'111','TCP20')
        add_tf_column(plate_df,'348','HHO2')
        add_tf_column(plate_df,'349','bZIP3')
        add_tf_column(plate_df,'351','TGA1')
        add_tf_column(plate_df,'113','ARF9')
        add_tf_column(plate_df,'YFP','No TF')#35s:YFP
        add_tf_column(plate_df,'IAA','IAA33')
        add_tf_column(plate_df,'355','dCas9_activator1')
        add_tf_column(plate_df,'356','dCas9_activator2')
        add_tf_column(plate_df,'357','dCas9_activator3')
        add_tf_column(plate_df,'362','dCpf1_repressor1')
        add_tf_column(plate_df,'363','dCpf1_repressor2')
        add_tf_column(plate_df,'364','dCpf1_repressor3')
        add_tf_column(plate_df,'411','UBQ10_dCas9_activator_guides1,2,3')
        add_tf_column(plate_df,'438','SRDX-dCpf1_guide1')
        add_tf_column(plate_df,'439','SRDX-dCpf1_guide2')
        add_tf_column(plate_df,'440','SRDX-dCpf1_guide3')
        add_tf_column(plate_df,'441','SRDX-dCpf1_guides1,2,3')
        add_tf_column(plate_df,'464','UBQ10_dCas9_activator')
        add_tf_column(plate_df,'404','guide1')
        add_tf_column(plate_df,'473','UBQ10_dCas9_repressor_guide3')
        add_tf_column(plate_df,'405','guide2')
        add_tf_column(plate_df,'OZ0151','TGA1:GR')
        add_tf_column(plate_df,'366','No TF')#35s:Basta
        add_tf_column(plate_df,'OZ234','VP64-Suntag_guides1,2,3')
        add_tf_column(plate_df,'OZ238','SRDX-Suntag_123guides1,2,3')
        add_tf_column(plate_df,'OZ242','SRDX-dCpf1_guides1,2,4')
        add_tf_column(plate_df,'OZ246','VP64-Suntag_guide1')
        add_tf_column(plate_df,'OZ273','TAD-Suntag_guides1,2,3')
        add_tf_column(plate_df,'OZ277','TAD-Suntag_guide1')
        add_tf_column(plate_df,'OZ285','SRDX-dCpf1_noguide')
        add_tf_column(plate_df,'OZ286','VP64-Suntag_noguide')
        add_tf_column(plate_df,'OZ287','TAD-Suntag_noguide')
        add_tf_column(plate_df,'OZ288','SRDX-Suntag_noguide')



        #add well calibrator column
        add_wellcalibrator_column(plate_df, 'YC003', 'NOS_LucF')
        add_wellcalibrator_column(plate_df, '34', '35s_LucF')
        

        #add plate number column
        plate_df['Plate_number'] = plate_number

        #Change TF_added NaN values to none
        plate_df.loc[plate_df.TF_added.isnull()==True, 'TF_added'] = 'No TF nor YFP'

        #Change condition NaN values to nitrogen
        plate_df.loc[plate_df.condition.isnull()==True, 'condition'] = 'nitrogen'

        #Change Well_calibrator NaN values to unknown
        plate_df.loc[plate_df.Well_calibrator.isnull()==True, 'Well_calibrator'] = 'unknown'

        #add plate df to dictionary
        plate_dict[plate_number] = plate_df
        
        #divide by NOS calibrator (mean nos-LucN/35SLucF luminescence)       
        batch_correction(plate_df, 'NOS',ignore_calibration=False)
        
        #if NAA condition, add that name to the TF name
        plate_df.loc[plate_df['condition'].str.contains(r'^1uM_auxin'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^1uM_auxin'), 'TF_added'] + '_1μM_NAA'
         #if DEX or CHX condition, add that name to the TF name
        plate_df.loc[plate_df['condition'].str.contains(r'^EtOH_DMSO'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^EtOH_DMSO'), 'TF_added'] + '_EtOH+DMSO'
        plate_df.loc[plate_df['condition'].str.contains(r'^10uM_DEX_DMSO'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^10uM_DEX_DMSO'), 'TF_added'] + '_10uM_DEX+DMSO'
        plate_df.loc[plate_df['condition'].str.contains(r'^35uM_CHX_EtOH'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^35uM_CHX_EtOH'), 'TF_added'] + '_35uM_CHX+EtOH'
        plate_df.loc[plate_df['condition'].str.contains(r'^10uM_DEX_35uM_CHX'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^10uM_DEX_35uM_CHX'), 'TF_added'] + '_10uM_DEX+35uM_CHX'
        plate_df.loc[plate_df['condition'].str.contains(r'^overnight_EtOH_DMSO'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^overnight_EtOH_DMSO'), 'TF_added'] + '_overnight_EtOH+DMSO'
        plate_df.loc[plate_df['condition'].str.contains(r'^overnight_10uM_DEX_DMSO'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^overnight_10uM_DEX_DMSO'), 'TF_added'] + '_overnight_10uM_DEX+DMSO'
        plate_df.loc[plate_df['condition'].str.contains(r'^overnight_35uM_CHX_EtOH'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^overnight_35uM_CHX_EtOH'), 'TF_added'] + '_overnight_35uM_CHX+EtOH'
        plate_df.loc[plate_df['condition'].str.contains(r'^overnight_10uM_DEX_35uM_CHX'),'TF_added' ] = plate_df.loc[plate_df['condition'].str.contains(r'^overnight_10uM_DEX_35uM_CHX'), 'TF_added'] + '_overnight_10uM_DEX+35uM_CHX'


        #if calibrator, add to the promoter name
        plate_df.loc[plate_df['condition'].str.contains('calibrator'),'Promoter' ] = plate_df.loc[plate_df['condition'].str.contains('calibrator'),'Promoter' ] + '_calibrator'
        #if well calibrator, add to the promoter
        # plate_df.loc[plate_df['Well_calibrator'].str.contains('NOS_LucF'),'TF_added' ] = plate_df.loc[plate_df['Well_calibrator'].str.contains('NOS_LucF'), 'TF_added'] + '_NOS:LucF_calibrator'
        # plate_df.loc[plate_df['Well_calibrator'].str.contains('35s_LucF'),'TF_added' ] = plate_df.loc[plate_df['Well_calibrator'].str.contains('35s_LucF'), 'TF_added'] + '_35s:LucF_calibrator'
        plate_df.loc[plate_df['Well_calibrator'].str.contains('35s_LucF'),'Promoter' ] = plate_df.loc[plate_df['Well_calibrator'].str.contains('35s_LucF'),'Promoter' ] + '_35s:LucF_calibrator'
        
        
        

    #merge the dfs with different dates
    luminescence_raw_df = pd.concat(plate_dict.values(), ignore_index=True)
    # luminescence_raw_df_plate1 = plate_dict[1]
    # luminescence_raw_df_plate2 = plate_dict[2]
    # luminescence_raw_df_plate3 = plate_dict[3]
    # luminescence_raw_df_plate4 = plate_dict[4]
    # luminescence_raw_df_plate5 = plate_dict[5]
    # luminescence_raw_df_plate6 = plate_dict[6]
    # luminescence_raw_df_plate7 = plate_dict[7]
    # luminescence_raw_df_plate8 = plate_dict[8]
    # #Change TF_added NaN values to none
    # luminescence_raw_df_plate1.loc[luminescence_raw_df_plate1.TF_added.isnull()==True, 'TF_added'] = 'No TF'
    # luminescence_raw_df_plate2.loc[luminescence_raw_df_plate2.TF_added.isnull()==True, 'TF_added'] = 'No TF'

    
    

    #sort rows by the custom promoter order I want so plots are in the correct order
    #sort rows by the custom promoter order I want so plots are in the correct order
    # luminescence_raw_df_plate1.Promoter = pd.Categorical(luminescence_raw_df_plate1.Promoter,
    #                                           ['YFP','NOS','NOS_calibrator','minimal_STAP4','UBQ10','NRP','4xNRE','4x[NRE-TATA]','4x[NRE-TATA]+spacing','4x[NRE-random]','4x[NRE-random]+spacing','3xHHO2-minsyn_105','minsyn_105-3xHHO2','4x[bZIP3-random]','2x[bZIP3-random-NRE-random]','4x[TGA1-random]','2x[TGA1-random-NRE-random]'])
    # luminescence_raw_df_plate1 = luminescence_raw_df_plate1.sort_values("Promoter")

    # luminescence_raw_df_plate2.Promoter = pd.Categorical(luminescence_raw_df_plate2.Promoter,
    #                                           ['YFP','NOS','NOS_calibrator','STAP4','35s','ANAC032','ANR1','ARF18','DREB26','NIR1','NLP6', 'NLP7'])
    # luminescence_raw_df_plate2 = luminescence_raw_df_plate2.sort_values("Promoter")
    luminescence_raw_df.Promoter = pd.Categorical(luminescence_raw_df.Promoter,
                                              ['NOS','NOS_calibrator','STAP4','35s','4x[NRE-TATA]+spacing','4x[NRE-TATA]+spacing_35s:LucF_calibrator','ANAC032','ANAC032_ablated_ARFs','ANAC032_ablated_TGA1_all_sites','ANR1','ARF18','DREB26','NIR1','NIR1_ablated_NRE','NIR1_ablated_NRE_all_sites','NLP6', 'NLP7','NLP7_ablated_ANAC032_all_sites','NOS_35s:LucF_calibrator','NOS_calibrator_35s:LucF_calibrator','STAP4_35s:LucF_calibrator','35s_35s:LucF_calibrator','ANAC032_35s:LucF_calibrator_35s:LucF_calibrator','ANAC032_ablated_ARFs_35s:LucF_calibrator','ANAC032_ablated_TGA1_all_sites_35s:LucF_calibrator','ANR1_35s:LucF_calibrator','ARF18_35s:LucF_calibrator','DREB26_35s:LucF_calibrator','NIR1_35s:LucF_calibrator','NIR1_ablated_NRE_35s:LucF_calibrator','NIR1_ablated_NRE_all_sites_35s:LucF_calibrator','NLP6_35s:LucF_calibrator', 'NLP7_35s:LucF_calibrator','NLP7_ablated_ANAC032_all_sites_35s:LucF_calibrator','NRP','NRP_35s:LucF_calibrator','NRP:NLUC:YFP','NIR1:NLUC:YFP','35s:NLUC:YFP','35s:NLUC:YFP_nomarker','4x[NRE-TATA]+spacing:NLUC:YFP','4x[NRE-TATA]+spacing:NLUC:YFP_35s:LucF_calibrator','4x[bZIP3-random]:NLUC:YFP','NRP:NLUC:YFP_35s:LucF_calibrator','NIR1:NLUC:YFP_35s:LucF_calibrator'])
    luminescence_raw_df = luminescence_raw_df.sort_values("Promoter")

    
    #save as file
    # location1 = f'../../../../data/luminescence/to_be_sorted/{date}/output_plate1.tsv'
    # location2 = f'../../../../data/luminescence/to_be_sorted/{date}/output_plate2.tsv'
    location = f'../../../../data/luminescence/to_be_sorted/{date}/combined_output.tsv'

    luminescence_raw_df.to_csv(location,sep='\t',header=True)

    # luminescence_raw_df_plate1.to_csv(location1,sep='\t',header=True)
    # luminescence_raw_df_plate2.to_csv(location2,sep='\t',header=True)
    
    return luminescence_raw_df

# %%
#first creat a dict of plate numbers and plate dfs
#first create empty variables
luminescence_raw_df_plate1 = ""
luminescence_raw_df_plate2 = ""
luminescence_raw_df_plate3 = ""
luminescence_raw_df_plate4 = ""
#luminescence_raw_df_plate4 = ""
# luminescence_raw_df_plate5 = ""
# luminescence_raw_df_plate6 = ""
# luminescence_raw_df_plate7 = ""
# luminescence_raw_df_plate8 = ""
plate_dict = {1:luminescence_raw_df_plate1, 2:luminescence_raw_df_plate2, 3:luminescence_raw_df_plate3,4:luminescence_raw_df_plate4 }#4:luminescence_raw_df_plate4, 5:luminescence_raw_df_plate5,6:luminescence_raw_df_plate6,7:luminescence_raw_df_plate7,8:luminescence_raw_df_plate8

# %%
#combine plates
date = '27.04.22'
luminescence_raw_df_plate1 = combine_plates(plate_dict, date)
# Out:
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 75  G10  Sample X85          4040635.0        143590355.0        G        10
# 76  G11  Sample X87          4214268.0        151172415.0        G        11
# 77  G12  Sample X89          4052159.0        142937607.0        G        12
# 87  H10  Sample X86           228476.0         82083735.0        H        10
# 88  H11  Sample X88           218313.0         77067206.0        H        11
# 89  H12  Sample X90           223150.0         80240390.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 75     35+34    nitrogen   35.536582  27.04.22      NOS  No TF nor YFP
# 76     35+34    nitrogen   35.871571  27.04.22      NOS  No TF nor YFP
# 77     35+34    nitrogen   35.274432  27.04.22      NOS  No TF nor YFP
# 87  35+YC003  calibrator  359.266334  27.04.22      NOS  No TF nor YFP
# 88  35+YC003  calibrator  353.012445  27.04.22      NOS  No TF nor YFP
# 89  35+YC003  calibrator  359.580506  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 75        35s_LucF             1
# 76        35s_LucF             1
# 77        35s_LucF             1
# 87        NOS_LucF             1
# 88        NOS_LucF             1
# 89        NOS_LucF             1
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 87  H10  Sample X86           228476.0         82083735.0        H        10
# 88  H11  Sample X88           218313.0         77067206.0        H        11
# 89  H12  Sample X90           223150.0         80240390.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 87  35+YC003  calibrator  359.266334  27.04.22      NOS  No TF nor YFP
# 88  35+YC003  calibrator  353.012445  27.04.22      NOS  No TF nor YFP
# 89  35+YC003  calibrator  359.580506  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 87        NOS_LucF             1
# 88        NOS_LucF             1
# 89        NOS_LucF             1
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 65  G10  Sample X76          3412118.0        140550192.0        G        10
# 66  G11  Sample X78          3407900.0        140426377.0        G        11
# 67  G12  Sample X80          3355499.0        137597360.0        G        12
# 77  H10  Sample X77           244953.0         82761818.0        H        10
# 78  H11  Sample X79           249231.0         86194623.0        H        11
# 79  H12  Sample X81           244941.0         84404854.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 65     35+34    nitrogen   41.191480  27.04.22      NOS  No TF nor YFP
# 66     35+34    nitrogen   41.206132  27.04.22      NOS  No TF nor YFP
# 67     35+34    nitrogen   41.006527  27.04.22      NOS  No TF nor YFP
# 77  35+YC003  calibrator  337.868154  27.04.22      NOS  No TF nor YFP
# 78  35+YC003  calibrator  345.842303  27.04.22      NOS  No TF nor YFP
# 79  35+YC003  calibrator  344.592592  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 65        35s_LucF             2
# 66        35s_LucF             2
# 67        35s_LucF             2
# 77        NOS_LucF             2
# 78        NOS_LucF             2
# 79        NOS_LucF             2
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 77  H10  Sample X77           244953.0         82761818.0        H        10
# 78  H11  Sample X79           249231.0         86194623.0        H        11
# 79  H12  Sample X81           244941.0         84404854.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 77  35+YC003  calibrator  337.868154  27.04.22      NOS  No TF nor YFP
# 78  35+YC003  calibrator  345.842303  27.04.22      NOS  No TF nor YFP
# 79  35+YC003  calibrator  344.592592  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 77        NOS_LucF             2
# 78        NOS_LucF             2
# 79        NOS_LucF             2
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 33  G10  Sample X49          3335802.0        127273764.0        G        10
# 34  G11  Sample X51          3198745.0        127307606.0        G        11
# 35  G12  Sample X53          3377824.0        126262823.0        G        12
# 39  H10  Sample X50           251168.0         76626602.0        H        10
# 40  H11  Sample X52           239704.0         74515354.0        H        11
# 41  H12  Sample X54           248754.0         75165671.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 33     35+34    nitrogen   38.153872  27.04.22      NOS  No TF nor YFP
# 34     35+34    nitrogen   39.799236  27.04.22      NOS  No TF nor YFP
# 35     35+34    nitrogen   37.379930  27.04.22      NOS  No TF nor YFP
# 39  35+YC003  calibrator  305.081069  27.04.22      NOS  No TF nor YFP
# 40  35+YC003  calibrator  310.864041  27.04.22      NOS  No TF nor YFP
# 41  35+YC003  calibrator  302.168693  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 33        35s_LucF             3
# 34        35s_LucF             3
# 35        35s_LucF             3
# 39        NOS_LucF             3
# 40        NOS_LucF             3
# 41        NOS_LucF             3
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 39  H10  Sample X50           251168.0         76626602.0        H        10
# 40  H11  Sample X52           239704.0         74515354.0        H        11
# 41  H12  Sample X54           248754.0         75165671.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 39  35+YC003  calibrator  305.081069  27.04.22      NOS  No TF nor YFP
# 40  35+YC003  calibrator  310.864041  27.04.22      NOS  No TF nor YFP
# 41  35+YC003  calibrator  302.168693  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 39        NOS_LucF             3
# 40        NOS_LucF             3
# 41        NOS_LucF             3
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 66  G10  Sample X76          3124170.0        109949864.0        G        10
# 67  G11  Sample X78          3145779.0        120068146.0        G        11
# 68  G12  Sample X80          3159473.0        117166455.0        G        12
# 78  H10  Sample X77           221438.0         69322408.0        H        10
# 79  H11  Sample X79           217950.0         72285883.0        H        11
# 80  H12  Sample X81           223062.0         71358853.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 66     35+34    nitrogen   35.193304  27.04.22      NOS  No TF nor YFP
# 67     35+34    nitrogen   38.168017  27.04.22      NOS  No TF nor YFP
# 68     35+34    nitrogen   37.084177  27.04.22      NOS  No TF nor YFP
# 78  35+YC003  calibrator  313.055609  27.04.22      NOS  No TF nor YFP
# 79  35+YC003  calibrator  331.662689  27.04.22      NOS  No TF nor YFP
# 80  35+YC003  calibrator  319.905914  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 66        35s_LucF             4
# 67        35s_LucF             4
# 68        35s_LucF             4
# 78        NOS_LucF             4
# 79        NOS_LucF             4
# 80        NOS_LucF             4
#    well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 78  H10  Sample X77           221438.0         69322408.0        H        10
# 79  H11  Sample X79           217950.0         72285883.0        H        11
# 80  H12  Sample X81           223062.0         71358853.0        H        12
#
#         name   condition   nluc/fluc      date Promoter       TF_added  \
# 78  35+YC003  calibrator  313.055609  27.04.22      NOS  No TF nor YFP
# 79  35+YC003  calibrator  331.662689  27.04.22      NOS  No TF nor YFP
# 80  35+YC003  calibrator  319.905914  27.04.22      NOS  No TF nor YFP
#
#    Well_calibrator  Plate_number
# 78        NOS_LucF             4
# 79        NOS_LucF             4
# 80        NOS_LucF             4

# %%
luminescence_raw_df_plate1
# Out:
#     well     content  fluc_luminescence  nluc_luminescence well_row  well_col  \
# 292  H12  Sample X81           223062.0         71358853.0        H        12
# 89   H12  Sample X90           223150.0         80240390.0        H        12
# 291  H11  Sample X79           217950.0         72285883.0        H        11
# 167  H10  Sample X77           244953.0         82761818.0        H        10
# 168  H11  Sample X79           249231.0         86194623.0        H        11
# ..   ...         ...                ...                ...      ...       ...
# 149  G04  Sample X31          4996011.0         16916399.0        G         4
# 162  H05  Sample X40           343288.0           578743.0        H         5
# 161  H04  Sample X32           347077.0           586112.0        H         4
# 151  G06  Sample X47          4860004.0         16652670.0        G         6
# 163  H06  Sample X48           366393.0           629014.0        H         6
#
#            name   condition   nluc/fluc      date  \
# 292    35+YC003  calibrator  319.905914  27.04.22
# 89     35+YC003  calibrator  359.580506  27.04.22
# 291    35+YC003  calibrator  331.662689  27.04.22
# 167    35+YC003  calibrator  337.868154  27.04.22
# 168    35+YC003  calibrator  345.842303  27.04.22
# ..          ...         ...         ...       ...
# 149  502+366+34    nitrogen    3.385981  27.04.22
# 162   502+31+34    nitrogen    1.685882  27.04.22
# 161   502+31+34    nitrogen    1.688709  27.04.22
# 151  502+366+34    nitrogen    3.426472  27.04.22
# 163   502+31+34    nitrogen    1.716774  27.04.22
#
#                                               Promoter       TF_added  \
# 292                                     NOS_calibrator  No TF nor YFP
# 89                                      NOS_calibrator  No TF nor YFP
# 291                                     NOS_calibrator  No TF nor YFP
# 167                                     NOS_calibrator  No TF nor YFP
# 168                                     NOS_calibrator  No TF nor YFP
# ..                                                 ...            ...
# 149  NLP7_ablated_ANAC032_all_sites_35s:LucF_calibr...          No TF
# 162  NLP7_ablated_ANAC032_all_sites_35s:LucF_calibr...        ANAC032
# 161  NLP7_ablated_ANAC032_all_sites_35s:LucF_calibr...        ANAC032
# 151  NLP7_ablated_ANAC032_all_sites_35s:LucF_calibr...          No TF
# 163  NLP7_ablated_ANAC032_all_sites_35s:LucF_calibr...        ANAC032
#
#     Well_calibrator  Plate_number  corrected_luminescence
# 292        NOS_LucF             4               99.491359
# 89         NOS_LucF             1              100.642084
# 291        NOS_LucF             4              103.147739
# 167        NOS_LucF             2               98.570598
# 168        NOS_LucF             2              100.896998
# ..              ...           ...                     ...
# 149        35s_LucF             2                0.987836
# 162        35s_LucF             2                0.491844
# 161        35s_LucF             2                0.492669
# 151        35s_LucF             2                0.999649
# 163        35s_LucF             2                0.500856
#
# [293 rows x 15 columns]

# %%
# luminescence_raw_df_renamed = luminescence_raw_df.copy()
# luminescence_raw_df_renamed.gene_type.replace('DREB26+ARF18','+DREB26+ARF18', inplace=True)
# luminescence_raw_df_renamed.gene_type.replace('ARF18','+ARF18', inplace=True)
# luminescence_raw_df_renamed.gene_type.replace('randCont','random', inplace=True)

# %%
luminescence_raw_df_plate1.condition.unique()
# Out:
# array(['calibrator', '10uM_DEX_35uM_CHX', 'EtOH_DMSO', '10uM_DEX_DMSO',
#        '35uM_CHX_EtOH', 'nitrogen', '1uM_auxin', 'overnight_EtOH_DMSO',
#        'overnight_10uM_DEX_DMSO'], dtype=object)

# %%
#get TF names
pd.Categorical(luminescence_raw_df_plate1.TF_added)
names = luminescence_raw_df_plate1.TF_added.unique()
#Change TF names to +TF
luminescence_raw_df_plate1_renamed = luminescence_raw_df_plate1.copy()
for TF in names:
    if TF != 'No TF nor YFP' and TF != 'No TF' and TF != 'No TF_1μM_NAA' and TF != 'No TF_EtOH+DMSO' and TF != 'No TF_10uM_DEX+DMSO' and TF != 'No TF_35uM_CHX+EtOH' and TF != 'No TF_10uM_DEX+35uM_CHX' and TF != 'No TF_overnight_EtOH+DMSO' and TF != 'No TF_overnight_10uM_DEX+DMSO' and TF != 'No TF_overnight_35uM_CHX+EtOH' and TF != 'No TF_overnight_10uM_DEX+35uM_CHX':
        luminescence_raw_df_plate1_renamed.TF_added.replace(TF,f'+{TF}', inplace=True)
luminescence_raw_df_plate1 = luminescence_raw_df_plate1_renamed

# %%
# #get TF names
# pd.Categorical(luminescence_raw_df_plate2.TF_added)
# names = luminescence_raw_df_plate2.TF_added.unique()
# #Change TF names to +TF
# luminescence_raw_df_plate2_renamed = luminescence_raw_df_plate2.copy()
# for TF in names:
#     if TF != 'No TF':
#         luminescence_raw_df_plate2_renamed.TF_added.replace(TF,f'+{TF}', inplace=True)
# luminescence_raw_df_plate2 = luminescence_raw_df_plate2_renamed

# %% [markdown]
# ### get names of each TF_added for later

# %%
pd.Categorical(luminescence_raw_df_plate1.TF_added)
names_plate1 = luminescence_raw_df_plate1.TF_added.unique()
for name in names_plate1:
    print(name)
# Out:
# No TF nor YFP
# +TGA1:GR_10uM_DEX+35uM_CHX
# +TGA1:GR_EtOH+DMSO
# No TF_10uM_DEX+DMSO
# No TF_35uM_CHX+EtOH
# +TGA1:GR_10uM_DEX+DMSO
# No TF
# No TF_EtOH+DMSO
# +TGA1:GR_35uM_CHX+EtOH
# No TF_10uM_DEX+35uM_CHX
# +ARF9+IAA33_1μM_NAA
# +ARF18+ARF9+IAA33_1μM_NAA
# +ARF18+ARF9+IAA33
# No TF_1μM_NAA
# +ARF9+IAA33
# +ARF18+IAA33
# +ARF18+IAA33_1μM_NAA
# +TAD-Suntag_guide1
# +SRDX-Suntag_123guides1,2,3
# +SRDX-Suntag_noguide
# +SRDX-dCpf1_guides1,2,4
# +VP64-Suntag_guide1
# +SRDX-dCpf1_guide2
# +TAD-Suntag_guides1,2,3
# +SRDX-dCpf1_guide1
# +SRDX-dCpf1_noguide
# +SRDX-dCpf1_guide3
# +SRDX-dCpf1_guides1,2,3
# +VP64-Suntag_noguide
# +TAD-Suntag_noguide
# +VP64-Suntag_guides1,2,3
# +TGA1:GR_overnight_EtOH+DMSO
# +TGA1:GR_overnight_10uM_DEX+DMSO
# No TF_overnight_10uM_DEX+DMSO
# No TF_overnight_EtOH+DMSO
# +NLP7
# +NLP6
# +ANAC032

# %%
# pd.Categorical(luminescence_raw_df_plate2.TF_added)
# names_plate2 = luminescence_raw_df_plate2.TF_added.unique()
# for name in names_plate2:
#     print(name)

# %%
#get list of promoters
pd.Categorical(luminescence_raw_df_plate1.Promoter)
prom_names_plate1 = luminescence_raw_df_plate1.Promoter.unique()
for name in prom_names_plate1:
    print(name)
# Out:
# NOS_calibrator
# ANAC032
# ANAC032_ablated_ARFs
# ANAC032_ablated_TGA1_all_sites
# ARF18
# NIR1
# NLP7
# NOS_35s:LucF_calibrator
# ARF18_35s:LucF_calibrator
# NIR1_35s:LucF_calibrator
# NIR1_ablated_NRE_35s:LucF_calibrator
# NIR1_ablated_NRE_all_sites_35s:LucF_calibrator
# NLP7_35s:LucF_calibrator
# NLP7_ablated_ANAC032_all_sites_35s:LucF_calibrator

# %%
# #get list of promoters
# pd.Categorical(luminescence_raw_df_plate2.Promoter)
# prom_names_plate2 = luminescence_raw_df_plate2.Promoter.unique()
# for name in prom_names_plate2:
#     print(name)

# %%
#create colours
from random import randint
color_plate1 = []
n_plate1 = len(prom_names_plate1)
for i in range(n_plate1):
    color_plate1.append('#%06X' % randint(0, 0xFFFFFF))
print(color_plate1)
# Out:
# ['#BCCDA0', '#391717', '#1E7EC7', '#BA263C', '#C4B3E3', '#BECF19', '#7D51D9', '#088C48', '#937FB2', '#A77116', '#CC250F', '#AB4F15', '#BCE1E2', '#ABEE8B']

# %%
# #create colours
# from random import randint
# color_plate2 = []
# n_plate2 = len(prom_names_plate2)
# for i in range(n_plate2):
#     color_plate2.append('#%06X' % randint(0, 0xFFFFFF))
# print(color_plate2)

# %%
#make dictionary with TF_added names as key and the randomly generated colors as values
new_color_plate1 = dict(zip(names, color_plate1))
new_color_plate1
# Out:
# {'No TF nor YFP': '#BCCDA0',
#  'TGA1:GR_10uM_DEX+35uM_CHX': '#391717',
#  'TGA1:GR_EtOH+DMSO': '#1E7EC7',
#  'No TF_10uM_DEX+DMSO': '#BA263C',
#  'No TF_35uM_CHX+EtOH': '#C4B3E3',
#  'TGA1:GR_10uM_DEX+DMSO': '#BECF19',
#  'No TF': '#7D51D9',
#  'No TF_EtOH+DMSO': '#088C48',
#  'TGA1:GR_35uM_CHX+EtOH': '#937FB2',
#  'No TF_10uM_DEX+35uM_CHX': '#A77116',
#  'ARF9+IAA33_1μM_NAA': '#CC250F',
#  'ARF18+ARF9+IAA33_1μM_NAA': '#AB4F15',
#  'ARF18+ARF9+IAA33': '#BCE1E2',
#  'No TF_1μM_NAA': '#ABEE8B'}

# %%
# #make dictionary with TF_added names as key and the randomly generated colors as values
# new_color_plate2 = dict(zip(names, color_plate2))
# new_color_plate2

# %%
# #layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
# #make graphs for each promoter
# #color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}


# for prom in prom_names:
#     if prom == 'NOS' or prom == 'STAP4':
#         pass
#     else:
#         df = luminescence_raw_df[luminescence_raw_df.Promoter == prom].sort_values("TF_added", ascending=False)


#         fig = px.violin(df, x='TF_added',
#                                   y='corrected_luminescence', box=True,                       
#                                 color='TF_added', color_discrete_map=new_color,violinmode='overlay') #points="all"

#         fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
#         fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
#         fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
#         #hide legend
#         fig.layout.update(showlegend=False)
#         #write to file static image and interactive one
#         fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
#         fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
#         fig.show()

# %%
for TF in names_plate1:
    print(TF)
# Out:
# No TF nor YFP
# +TGA1:GR_10uM_DEX+35uM_CHX
# +TGA1:GR_EtOH+DMSO
# No TF_10uM_DEX+DMSO
# No TF_35uM_CHX+EtOH
# +TGA1:GR_10uM_DEX+DMSO
# No TF
# No TF_EtOH+DMSO
# +TGA1:GR_35uM_CHX+EtOH
# No TF_10uM_DEX+35uM_CHX
# +ARF9+IAA33_1μM_NAA
# +ARF18+ARF9+IAA33_1μM_NAA
# +ARF18+ARF9+IAA33
# No TF_1μM_NAA
# +ARF9+IAA33
# +ARF18+IAA33
# +ARF18+IAA33_1μM_NAA
# +TAD-Suntag_guide1
# +SRDX-Suntag_123guides1,2,3
# +SRDX-Suntag_noguide
# +SRDX-dCpf1_guides1,2,4
# +VP64-Suntag_guide1
# +SRDX-dCpf1_guide2
# +TAD-Suntag_guides1,2,3
# +SRDX-dCpf1_guide1
# +SRDX-dCpf1_noguide
# +SRDX-dCpf1_guide3
# +SRDX-dCpf1_guides1,2,3
# +VP64-Suntag_noguide
# +TAD-Suntag_noguide
# +VP64-Suntag_guides1,2,3
# +TGA1:GR_overnight_EtOH+DMSO
# +TGA1:GR_overnight_10uM_DEX+DMSO
# No TF_overnight_10uM_DEX+DMSO
# No TF_overnight_EtOH+DMSO
# +NLP7
# +NLP6
# +ANAC032

# %%
# #layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
# fig = go.Figure(go.Violin(y=luminescence_raw_df[luminescence_raw_df.Promoter == 'ANR1'].corrected_luminescence, x=luminescence_raw_df[luminescence_raw_df.Promoter == 'ANR1'].TF_added,
#                           fillcolor='#840122', box_visible=True, meanline_visible=True))
#               #points="all"

# fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)')
# fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
# fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
# #write to file static image and interactive one
# #fig.write_image(f'../../../../data/plots/luminescence/{date}/violin23.9.19.pdf')
# #fig.write_html(f'../../../../data/plots/luminescence/{date}/violin23.9.19.html')

# fig.show()

# %%
def dunn_posthoc_test(df, dependent_variable, between):
    """dunn_posthoc tests with bonferroni multiple correction"""
    return sp.posthoc_dunn(
        df,
        val_col=dependent_variable,
        group_col=between,
        p_adjust="bonferroni",
    )

# %%
#create plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22  already exists

# %%
#create individual plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/individual'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/individual  already exists

# %%
#create individual plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/individual/calibrator_35s'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/individual/calibrator_35s  already exists

# %%
#create individual plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/individual/calibrator_nos'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/individual/calibrator_nos  already exists

# %%
#create individual plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/compare_auxin'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/compare_auxin  already exists

# %%
#create individual plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/compare_DEX'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/compare_DEX  already exists

# %%
#create ablated prom plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/ablated_prom'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/ablated_prom  already exists

# %%
#create individual plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/ablated_prom/calibrator_nos'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/ablated_prom/calibrator_nos  already exists

# %%
#create individual plot folder name
#make directory for the plots to be exported to
dirName = f'../../../../data/plots/luminescence/{date}/ablated_prom/calibrator_nos'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " created") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  ../../../../data/plots/luminescence/27.04.22/ablated_prom/calibrator_nos  already exists

# %%
# #try matplotlib figures and set absolute width here: https://stackoverflow.com/questions/42555761/matplotlib-set-width-of-bars-to-be-the-same-size-for-all-subplots
# #make experimental design graph for thesis
# #make individual plots
# #layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
# #make graphs for each promoter
# #color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
# #plots for promoters with more than 2 Tf categories
# #prom == 'minimal_STAP4'
# #set matplotlib default parameters
# #sns.set(font="arial")

# rcParams['xtick.major.width'] = 2
# rcParams['ytick.major.width'] = 2
# rcParams['axes.linewidth'] = 2
# #rcParams['lines.linewidth'] = 2
# #remove top and right lines
# rcParams['axes.spines.top'] = False
# rcParams['axes.spines.right'] = False
# #font size
# rcParams['font.size'] = 18
# #for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
# rcParams['font.family'] = 'sans-serif'
# rcParams['font.sans-serif'] = ['Arial']
# #allow font to be edited later in pdf editor
# rcParams ['pdf.fonttype'] = 42 
# #make svg text editable
# rcParams['svg.fonttype'] = 'none'
# #align y-axis top most tick with end of axis
# rcParams['axes.autolimit_mode'] = 'round_numbers'
# #set margins to ensure any error bars fit
# rcParams['axes.xmargin'] = 0.2
# rcParams['axes.ymargin'] = 0.2
# #define bar width
# bar_width = 0.9

# #set width of bars
# def change_width(ax, new_value) :
#     for patch in ax.patches :
#         current_width = patch.get_width()
#         diff = current_width - new_value
#         # we change the bar width
#         patch.set_width(new_value)
#         # we recenter the bar
#         patch.set_x(patch.get_x() + diff * .5)

# for prom in prom_names_plate1:
#     if prom == 'NOS_calibrator' or prom == 'STAP4' or prom == 'minimal_STAP4' or prom == 'NOS_calibrator_35s:LucF_calibrator':
#         pass
#     else:
#         df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
#         #split based on well calibrator
#         if "_35s:LucF_calibrator" in prom:
#             #get list of TFs coexpressed with that promoter
#             TFs_orig =  df.TF_added.unique()
#             #assign list of TFs of interest with this well calibrator
#             TF_order = ['No TF nor YFP','No TF']
#             #sort based on custom order
#             TFs = []
#             for i in range(len(TF_order)):
#                 if TF_order[i] in TFs_orig:
#                     TFs+=[TF_order[i]]

#             if len(TFs) < 2:
#                 pass
#             else:
#                 for TF in TFs:
#                     if TF == 'No TF nor YFP':
#                         pass
#                     else:
                        
                        
#                         #create new df with only TF of interest
#                         df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF nor YFP')]
#                         #create box pairs
#                         pair = [('No TF nor YFP', TF)]
#                         print(pair)
#                         #pvalue = []
                    
#                         # #create series objects
#                         # TF1 = df_new.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
#                         # TF2 = df_new.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
#                         # # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
#                         # # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
#                         # #equal variance = false so do Welch's T-test
#                         # results = stats.ttest_ind(TF1, TF2, equal_var=False)
#                         #     #append pvalue to dict
#                         # pvalue = results.pvalue
#                         # # box_pairs_significant.append(pair)
#                         # # p_values.append(results.pvalue)
#                         # print(f'pvalue={pvalue}')

#                         # # #filter dict by significance and put in a new dictionary
#                         # # box_pairs_significant = {}
#                         # # for k,v in box_pairs_all_pvalues.items():
#                         # #     if v <0.05:
#                         # #         box_pairs_significant[k] = v
                        


#                         #make plot 
#                         plt.figure(figsize=(2,6))
#                         order_new = pair[0]
#                         fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new, linewidth=2,errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,dodge=False,color='#BFBFBF')#facecolor=(1,1,1,1)
#                         #plt.bar(x='TF_added', height='corrected_luminescence', data=df_new,width=bar_width)
#                         sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new,color='black')
#                         #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new,color='black')

#                         #set width of bars
#                         change_width(fig, bar_width)

#                         #add stats
#                         annotator = Annotator(fig, pair, data=df_new, x='TF_added', y='corrected_luminescence',order=order_new)
#                         #[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]]#{0.001:"***",0.01:"**",0.05:"*", 1:"ns"}
#                         annotator.configure(test='t-test_welch',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]])#loc='inside'#text_format='star',
#                         annotator.apply_and_annotate()

                        
                       



#                         # if pvalue<0.05:

#                         #     add_stat_annotation(
#                         #     fig,
#                         #     data=df_new,
#                         #     x='TF_added',
#                         #     y='corrected_luminescence',
#                         #     order=order_new,
#                         #     box_pairs=pair,
#                         #     text_format="star",
#                         #     loc="inside",
#                         #     verbose=2,
#                         #     perform_stat_test=False,
#                         #     pvalues=list(pvalue),
#                         #     #test='Mann-Whitney'
#                         #     #test_short_name="Dunn",
#                         #     )
#                         new_labels = ['No YFP', '+YFP']                
#                         fig.set_xticklabels(new_labels)
                        
#                         # change axes labels
#                         plt.ylabel('Normalised expression (a.u.)')
#                         #add title
#                         plt.title(prom, y=1.4,size=18)
#                         #make xticks diagonal
#                         plt.xticks(rotation=45, ha='right')
#                         #plt.xlabel(x_label)
#                         # tight layout
#                         plt.tight_layout()
#                         # save figure
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/exp_design/calibrator_35s/scatter{prom}_{TF}_plate1.pdf',
#                             format="pdf",
#                             bbox_inches="tight",transparent=True)
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/exp_design/calibrator_35s/scatter{prom}_{TF}_plate1.svg',
#                             format="svg",
#                             bbox_inches="tight",transparent=True)

#         else:            
#             #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
#             #change name of TF added in df2 to minimal_stap4        
#             #df2['TF_added'] = 'pSTAP4 no TF'
#             # df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
#             TFs_orig =  df.TF_added.unique()
#             #print(TFs_orig)
#             TF_order = ['No TF nor YFP','No TF']
#             #'No TF/YFP','+No TF/YFP_1μM_NAA',
#             #sort based on custom order
#             TFs = []
#             for i in range(len(TF_order)):
#                 if TF_order[i] in TFs_orig:
#                     TFs+=[TF_order[i]]
#             #print(TFs)
#             #print(df)
#             #get length of number of TFs
#             #length_tf = len(TFs)
#             #create order and box pairs based on the length of TFs
#             #iterate through TFs
#             #pass if only one TF
#             if len(TFs) < 2:
#                 pass
#             else:
#                 for TF in TFs:
#                     if TF == 'No TF nor YFP':
#                         pass
#                     else:
                        
                        
#                         #create new df with only TF of interest
#                         df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF nor YFP')]
#                         #create box pairs
#                         pair = [('No TF nor YFP', TF)]
#                         print(pair)
#                         #pvalue = []
                    
#                         # #create series objects
#                         # TF1 = df_new.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
#                         # TF2 = df_new.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
#                         # # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
#                         # # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
#                         # #equal variance = false so do Welch's T-test
#                         # results = stats.ttest_ind(TF1, TF2, equal_var=False)
#                         #     #append pvalue to dict
#                         # pvalue = results.pvalue
#                         # # box_pairs_significant.append(pair)
#                         # # p_values.append(results.pvalue)
#                         # print(f'pvalue={pvalue}')

#                         # # #filter dict by significance and put in a new dictionary
#                         # # box_pairs_significant = {}
#                         # # for k,v in box_pairs_all_pvalues.items():
#                         # #     if v <0.05:
#                         # #         box_pairs_significant[k] = v
                        


#                         #make plot 
#                         plt.figure(figsize=(2,6))
#                         order_new = pair[0]
#                         fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4, dodge=False, color='#BFBFBF')#facecolor=(1,1,1,1)
#                         #plt.bar(x='TF_added', height='corrected_luminescence', data=df_new,width=bar_width)
#                         sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new,color='black')
#                         #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new,color='black')

#                         change_width(fig, bar_width)

                        
#                         # #add stats
#                         annotator = Annotator(fig, pair, data=df_new, x='TF_added', y='corrected_luminescence',order=order_new)
#                         annotator.configure(test='t-test_welch', pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]])#loc='inside'#text_format='star',
#                         annotator.apply_and_annotate()



#                         # if pvalue<0.05:

#                         #     add_stat_annotation(
#                         #     fig,
#                         #     data=df_new,
#                         #     x='TF_added',
#                         #     y='corrected_luminescence',
#                         #     order=order_new,
#                         #     box_pairs=pair,
#                         #     text_format="star",
#                         #     loc="inside",
#                         #     verbose=2,
#                         #     perform_stat_test=False,
#                         #     pvalues=list(pvalue),
#                         #     #test='Mann-Whitney'
#                         #     #test_short_name="Dunn",
#                         #     )
#                         new_labels = ['No YFP', '+YFP']                
#                         fig.set_xticklabels(new_labels)
                       
#                         # change axes labels
#                         plt.ylabel('Normalised expression (a.u.)')
#                         #add title
#                         plt.title(prom, y=1,size=18)
#                         #make xticks diagonal
#                         plt.xticks(rotation=45, ha='right')
#                         #plt.xlabel(x_label)
#                         # tight layout
#                         plt.tight_layout()
#                         # save figure
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/exp_design/calibrator_nos/scatter{prom}_{TF}_plate1.pdf',
#                             format="pdf",
#                             bbox_inches="tight",transparent=True)
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/exp_design/calibrator_nos/scatter{prom}_{TF}_plate1.svg',
#                             format="svg",
#                             bbox_inches="tight",transparent=True)

# %%
#make ablated prom plots
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 14
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.65
#plot height and width
height = 5
width = 2.4
#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


#NIR1
proms = ['NIR1_35s:LucF_calibrator','NIR1_ablated_NRE_35s:LucF_calibrator','NIR1_ablated_NRE_all_sites_35s:LucF_calibrator']
prom='NIR1'
df = luminescence_raw_df_plate1.loc[(luminescence_raw_df_plate1.Promoter == proms[0]) | (luminescence_raw_df_plate1.Promoter == proms[1]) | (luminescence_raw_df_plate1.Promoter == proms[2])].sort_values("TF_added", ascending=False)
#split based on well calibrator
if "_35s:LucF_calibrator" in prom:
    #get list of TFs coexpressed with that promoter
    TFs_orig =  df.TF_added.unique()
    #assign list of TFs of interest with this well calibrator
    TF_order = ['No TF','+ANAC032','+NLP6','+NLP7',]
    #sort based on custom order
    TFs = []
    for i in range(len(TF_order)):
        if TF_order[i] in TFs_orig:
            TFs+=[TF_order[i]]
    if len(TFs) < 2:
        pass
    else:
        for TF in TFs:
            if TF == 'No TF':
                pass
        else:
            
            
            #create new df with only TF of interest
            df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF')]
            #create box pairs
            pair = [('No TF', TF)]
            #print(f'prom={prom}pair={pair}')

            #make plot 
            plt.figure(figsize=(width,height))
                        
            order_new = pair[0]
            fig = sns.barplot(x='Promoter', y='corrected_luminescence', data=df_new, order=order_new, linewidth=2,  errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,color='#BFBFBF')#facecolor=(1,1,1,1),
            #fig.set_aspect(0.5)
            sns.swarmplot(x='Promoter', y='corrected_luminescence', data=df_new, order=order_new,color='black')
            #change bar width
            change_width(fig, bar_width)
            # #add stats
            # annotator = Annotator(fig, pair, data=df_new, x='Promoter', y='corrected_luminescence',order=order_new)
            # annotator.configure(test='t-test_welch', text_format='star',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]])#loc='inside'
            # annotator.apply_and_annotate()


            # change axes labels
            plt.ylabel('Normalised expression (a.u.)')
            #add title

            #plt.title(prom[:len(prom)-20], y=1,size=fontsize)
            plt.title(f'Co-expression\n 35s:{TF[1:]} + {prom}p:LucN', y=1,size=fontsize)
                        
            #make xticks diagonal
            plt.xticks(rotation=90, ha='center')#ha='right'
            #plt.xlabel(x_label)
            # tight layout
            plt.tight_layout()
            # save figure
            plt.savefig(
                            f'../../../../data/plots/luminescence/{date}/ablated_prom/calibrator_35s/scatter{prom}_{TF}_plate1.pdf',
                            format="pdf",
                            bbox_inches="tight",transparent=True)
            plt.savefig(
                            f'../../../../data/plots/luminescence/{date}/ablated_prom/calibrator_35s/scatter{prom}_{TF}_plate1.svg',
                            format="svg",
                            bbox_inches="tight",transparent=True)
            #don't show plot in notebook
            plt.close()

else:          
    #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
    #change name of TF added in df2 to minimal_stap4        
    #df2['TF_added'] = 'pSTAP4 no TF'
    # df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
    TFs_orig =  df.TF_added.unique()
    #print(TFs_orig)
    TF_order = ['No TF','+ANR1','+bZIP3','+DREB26','+HHO2','+NLP6','+TGA1','+TGA1:GR','+bZIP3','+DREB26','+HHO2','+NLP6','+NLP7','+TGA1','+NLP7+bZIP3','+NLP7+TGA1','No TF nor YFP', 'No TF', '+TAD-Suntag_noguide','+TAD-Suntag_guide1','+TAD-Suntag_guides1,2,3','+VP64-Suntag_noguide','+VP64-Suntag_guide1','+VP64-Suntag_guides1,2,3','+SRDX-dCpf1_noguide','+SRDX-dCpf1_guide1','+SRDX-dCpf1_guide2','+SRDX-dCpf1_guide3','+SRDX-dCpf1_guides1,2,3','+SRDX-dCpf1_guides1,2,4','+SRDX-Suntag_noguide','+SRDX-Suntag_123guides1,2,3']
    #'No TF/YFP','+No TF/YFP_1μM_NAA',
    #sort based on custom order
    TFs = []
    for i in range(len(TF_order)):
        if TF_order[i] in TFs_orig:
            TFs+=[TF_order[i]]
    #print(TFs)
    #print(df)
    #get length of number of TFs
    #length_tf = len(TFs)
    #create order and box pairs based on the length of TFs
    #iterate through TFs
    #pass if only one TF
    if len(TFs) < 2:
        pass
    else:
        for TF in TFs:
            if TF == 'No TF':
                        pass
            else:
                        
                        
                #create new df with only TF of interest
                df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF')]
                #create box pairs
                pair = [('No TF', TF)]
                #print(pair)
                #pvalue = []
                    
                        
                        
                #make plot 
                if TF == '+TAD-Suntag_noguide' or TF == '+TAD-Suntag_guide1' or TF == '+TAD-Suntag_guides1,2,3' or TF == '+VP64-Suntag_noguide' or TF == '+VP64-Suntag_guide1' or TF == '+VP64-Suntag_guides1,2,3' or TF == '+SRDX-dCpf1_noguide' or TF == '+SRDX-dCpf1_guide1' or TF == '+SRDX-dCpf1_guide2' or TF == '+SRDX-dCpf1_guide3' or TF == '+SRDX-dCpf1_guides1,2,3' or TF == '+SRDX-dCpf1_guides1,2,4' or TF == '+SRDX-Suntag_noguide' or TF == '+SRDX-Suntag_123guides1,2,3':
                    plt.figure(figsize=(6,6))
                else:
                    plt.figure(figsize=(width,height))
                order_new = pair[0]
                fig = sns.barplot(x='Promoter', y='corrected_luminescence', data=df_new, order=order_new, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,color='#BFBFBF')#facecolor=(1,1,1,1)
                #fig.set_aspect(0.5)
                sns.swarmplot(x='Promoter', y='corrected_luminescence', data=df_new, order=order_new,color='black')
                #change bar width
                change_width(fig, bar_width)

                #add stats

                # annotator = Annotator(fig, pair, data=df_new, x='Promoter', y='corrected_luminescence',order=order_new)
                # annotator.configure(test='t-test_welch', text_format='star',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1,"ns"]])#loc='inside'
                # annotator.apply_and_annotate()
                        



                    
                # change axes labels
                plt.ylabel('Normalised expression (a.u.)')
                #add title
                if TF == '+TAD-Suntag_noguide' or TF == '+TAD-Suntag_guide1' or TF == '+TAD-Suntag_guides1,2,3' or TF == '+VP64-Suntag_noguide' or TF == '+VP64-Suntag_guide1' or TF == '+VP64-Suntag_guides1,2,3' or TF == '+SRDX-dCpf1_noguide' or TF == '+SRDX-dCpf1_guide1' or TF == '+SRDX-dCpf1_guide2' or TF == '+SRDX-dCpf1_guide3' or TF == '+SRDX-dCpf1_guides1,2,3' or TF == '+SRDX-dCpf1_guides1,2,4' or TF == '+SRDX-Suntag_noguide' or TF == '+SRDX-Suntag_123guides1,2,3':
                    pass
                else:
                    plt.title(f'Co-expression\n 35s:{TF[1:]} + {prom}p:LucN', y=1,size=fontsize)
                #make xticks diagonal
                plt.xticks(rotation=90, ha='center')#ha='right'
                #plt.xlabel(x_label)
                # tight layout
                plt.tight_layout()
                # save figure
                plt.savefig(
                            f'../../../../data/plots/luminescence/{date}/ablated_prom/calibrator_nos/scatter{prom}_{TF}_plate1.pdf',
                            format="pdf",
                            bbox_inches="tight",transparent=True)
                plt.savefig(
                            f'../../../../data/plots/luminescence/{date}/ablated_prom/calibrator_nos/scatter{prom}_{TF}_plate1.svg',
                            format="svg",
                            bbox_inches="tight",transparent=True)
                #don't show plot in notebook
                plt.close()

# %%
#make plot
def make_plot(prom,TF,date,df,order, pair, fig_width, fig_height,bar_width, fontsize,plot_title=None):
    """function to make and save plots"""
    plt.figure(figsize=(fig_width,fig_height))
    
    #order_new = pair[0]
    fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2,  errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,color='#BFBFBF')#facecolor=(1,1,1,1),
    #fig.set_aspect(0.5)
    sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, order=order,color='black')
    #change bar width
    change_width(fig, bar_width)
    #add stats
    annotator = Annotator(fig, pair, data=df, x='TF_added', y='corrected_luminescence',order=order, verbose=False)
    annotator.configure(test='t-test_welch', text_format='star',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]])#loc='inside'
    ax, test_results = annotator.apply_and_annotate()
    with open(f'../../../../data/plots/luminescence/{date}/individual/stats.txt', 'a') as f:                            
        for res in test_results:
            f.write(f'{str(prom)},{pair},{str(res.data)}\n')
    # change axes labels
    plt.ylabel('Normalised expression (a.u.)')
    #add title
    #plt.title(prom[:len(prom)-20], y=1,size=fontsize)
    if plot_title==None:
        plt.title(f'Co-expression\n 35s:{TF[1:]} + {prom}p:LucN', y=1,size=fontsize)
    if plot_title!=None:
        plt.title(plot_title, y=1,size=fontsize)
    
    #make xticks diagonal
    plt.xticks(rotation=90, ha='center')#ha='right'
    #plt.xlabel(x_label)
    # tight layout
    plt.tight_layout()
    # save figure
    plt.savefig(
        f'../../../../data/plots/luminescence/{date}/individual/calibrator_35s/scatter{prom}_{TF}_plate1.pdf',
        format="pdf",
        bbox_inches="tight",transparent=True)
    plt.savefig(
        f'../../../../data/plots/luminescence/{date}/individual/calibrator_35s/scatter{prom}_{TF}_plate1.svg',
        format="svg",
        bbox_inches="tight",transparent=True)
    #don't show plot in notebook
    plt.close()

# %%
#make individual plots
#To improve code, make one figure function, and a different function which loops over the figure function to make the plots
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters

rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 14
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.65
#plot height and width
height = 5
width = 2.4
#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'NRP:NLUC:YFP' or prom == 'NIR1:NLUC:YFP' or prom == '35s:NLUC:YFP' or prom == '4x[NRE-TATA]+spacing:NLUC:YFP' or prom == '4x[bZIP3-random]:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker':
        pass
    else:
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #split based on well calibrator
        if "_35s:LucF_calibrator" in prom:
            #get list of TFs coexpressed with that promoter
            TFs_orig =  df.TF_added.unique()
            #assign list of TFs of interest with this well calibrator
            TF_order = ['No TF','+ANAC032','+NLP6','+NLP7',]
            #sort based on custom order
            TFs = []
            for i in range(len(TF_order)):
                if TF_order[i] in TFs_orig:
                    TFs+=[TF_order[i]]

            if len(TFs) < 2:
                pass
            if len(TFs) >= 2:
                for TF in TFs:
                    if TF == 'No TF':
                        pass
                    else:
                        
                        
                        #create new df with only TF of interest
                        df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF')]
                        #create box pairs
                        pair = [('No TF', TF)]
                        order_new = pair[0]



                        #make plot                        
                        make_plot(prom,TF,date,df_new,order_new, pair, width, height,bar_width, fontsize)                        
               
        if "_35s:LucF_calibrator" not in prom:         
            #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
            #change name of TF added in df2 to minimal_stap4        
            #df2['TF_added'] = 'pSTAP4 no TF'
            # df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
            TFs_orig =  df.TF_added.unique()
            #print(TFs_orig)
            TF_order = ['No TF','+ANR1','+bZIP3','+DREB26','+HHO2','+NLP6','+TGA1','+TGA1:GR','+bZIP3','+DREB26','+HHO2','+NLP6','+NLP7','+TGA1','+NLP7+bZIP3','+NLP7+TGA1','No TF nor YFP', 'No TF', '+TAD-Suntag_noguide','+TAD-Suntag_guide1','+TAD-Suntag_guides1,2,3','+VP64-Suntag_noguide','+VP64-Suntag_guide1','+VP64-Suntag_guides1,2,3','+SRDX-dCpf1_noguide','+SRDX-dCpf1_guide1','+SRDX-dCpf1_guide2','+SRDX-dCpf1_guide3','+SRDX-dCpf1_guides1,2,3','+SRDX-dCpf1_guides1,2,4','+SRDX-Suntag_noguide','+SRDX-Suntag_123guides1,2,3']
            #'No TF/YFP','+No TF/YFP_1μM_NAA',
            #sort based on custom order
            TFs = []
            for i in range(len(TF_order)):
                if TF_order[i] in TFs_orig:
                    TFs+=[TF_order[i]]
            #print(TFs)
            #print(df)
            #get length of number of TFs
            #length_tf = len(TFs)
            #create order and box pairs based on the length of TFs
            #iterate through TFs
            #pass if only one TF
            if len(TFs) < 2:
                pass
            if len(TFs) >= 2:
                for TF in TFs:
                    if TF == 'No TF':
                        pass
                    else:                       
                        
                        #create new df with only TF of interest
                        df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF')]
                        #create box pairs
                        pair = [('No TF', TF)]

                        
                        #make plot 
                        if TF == '+TAD-Suntag_noguide' or TF == '+TAD-Suntag_guide1' or TF == '+TAD-Suntag_guides1,2,3' or TF == '+VP64-Suntag_noguide' or TF == '+VP64-Suntag_guide1' or TF == '+VP64-Suntag_guides1,2,3' or TF == '+SRDX-dCpf1_noguide' or TF == '+SRDX-dCpf1_guide1' or TF == '+SRDX-dCpf1_guide2' or TF == '+SRDX-dCpf1_guide3' or TF == '+SRDX-dCpf1_guides1,2,3' or TF == '+SRDX-dCpf1_guides1,2,4' or TF == '+SRDX-Suntag_noguide' or TF == '+SRDX-Suntag_123guides1,2,3':
                            fig_width=6
                            fig_height=6
                            #plt.figure(figsize=(6,6))

                        else:
                            fig_width = width
                            fig_height = height
                            #plt.figure(figsize=(width,height))
                        order_new = pair[0]
                        #print(order_new)
                        #print(TF)                         

                        
                        #add title
                        if TF == '+TAD-Suntag_noguide' or TF == '+TAD-Suntag_guide1' or TF == '+TAD-Suntag_guides1,2,3' or TF == '+VP64-Suntag_noguide' or TF == '+VP64-Suntag_guide1' or TF == '+VP64-Suntag_guides1,2,3' or TF == '+SRDX-dCpf1_noguide' or TF == '+SRDX-dCpf1_guide1' or TF == '+SRDX-dCpf1_guide2' or TF == '+SRDX-dCpf1_guide3' or TF == '+SRDX-dCpf1_guides1,2,3' or TF == '+SRDX-dCpf1_guides1,2,4' or TF == '+SRDX-Suntag_noguide' or TF == '+SRDX-Suntag_123guides1,2,3':
                            plot_title=None
                        else:
                            plot_title = f'Co-expression\n 35s:{TF[1:]} + {prom}p:LucN'                        
                            #plt.title(f'Co-expression\n 35s:{TF[1:]} + {prom}p:LucN', y=1,size=fontsize)
                        #makeplot                        
                        make_plot(prom,TF,date,df_new,order_new, pair, fig_width, fig_height, bar_width, fontsize, plot_title)

# %%
# #make individual plots
# #To improve code, make one figure function, and a different function which loops over the figure function to make the plots
# #layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
# #make graphs for each promoter
# #color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
# #plots for promoters with more than 2 Tf categories
# #prom == 'minimal_STAP4'
# #set matplotlib default parameters

# rcParams['xtick.major.width'] = 2
# rcParams['ytick.major.width'] = 2
# rcParams['axes.linewidth'] = 2
# #rcParams['lines.linewidth'] = 2
# #remove top and right lines
# rcParams['axes.spines.top'] = False
# rcParams['axes.spines.right'] = False
# #font size
# fontsize = 14
# rcParams['font.size'] = fontsize
# #for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
# rcParams['font.family'] = 'sans-serif'
# rcParams['font.sans-serif'] = ['Arial']
# #allow font to be edited later in pdf editor
# rcParams ['pdf.fonttype'] = 42
# #make svg text editable
# rcParams['svg.fonttype'] = 'none'
# #align y-axis top most tick with end of axis
# rcParams['axes.autolimit_mode'] = 'round_numbers'
# #set margins to ensure any error bars fit
# rcParams['axes.xmargin'] = 0.2
# rcParams['axes.ymargin'] = 0.2
# #define bar width
# bar_width = 0.65
# #plot height and width
# height = 5
# width = 2.4
# #set width of bars
# def change_width(ax, new_value) :
#     for patch in ax.patches :
#         current_width = patch.get_width()
#         diff = current_width - new_value
#         # we change the bar width
#         patch.set_width(new_value)
#         # we recenter the bar
#         patch.set_x(patch.get_x() + diff * .5)

# for prom in prom_names_plate1:
#     if prom == 'NOS_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'NRP:NLUC:YFP' or prom == 'NIR1:NLUC:YFP' or prom == '35s:NLUC:YFP' or prom == '4x[NRE-TATA]+spacing:NLUC:YFP' or prom == '4x[bZIP3-random]:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker':
#         pass
#     else:
#         df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
#         #split based on well calibrator
#         if "_35s:LucF_calibrator" in prom:
#             #get list of TFs coexpressed with that promoter
#             TFs_orig =  df.TF_added.unique()
#             #assign list of TFs of interest with this well calibrator
#             TF_order = ['No TF','+ANAC032','+NLP6','+NLP7',]
#             #sort based on custom order
#             TFs = []
#             for i in range(len(TF_order)):
#                 if TF_order[i] in TFs_orig:
#                     TFs+=[TF_order[i]]

#             if len(TFs) < 2:
#                 pass
#             else:
#                 for TF in TFs:
#                     if TF == 'No TF':
#                         pass
#                     else:
                        
                        
#                         #create new df with only TF of interest
#                         df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF')]
#                         #create box pairs
#                         pair = [('No TF', TF)]
#                         #print(f'prom={prom}pair={pair}')
#                         #pvalue = []
                    
#                         # #create series objects
#                         # TF1 = df_new.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
#                         # TF2 = df_new.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
#                         # # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
#                         # # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
#                         # #equal variance = false so do Welch's T-test
#                         # results = stats.ttest_ind(TF1, TF2, equal_var=False)
#                         #     #append pvalue to dict
#                         # pvalue = results.pvalue
#                         # # box_pairs_significant.append(pair)
#                         # # p_values.append(results.pvalue)
#                         # print(f'pvalue={pvalue}')

#                         # # #filter dict by significance and put in a new dictionary
#                         # # box_pairs_significant = {}
#                         # # for k,v in box_pairs_all_pvalues.items():
#                         # #     if v <0.05:
#                         # #         box_pairs_significant[k] = v
                        


#                         #make plot 
#                         plt.figure(figsize=(width,height))
                        
#                         order_new = pair[0]
#                         fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new, linewidth=2,  errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,color='#BFBFBF')#facecolor=(1,1,1,1),
#                         #fig.set_aspect(0.5)
#                         sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new,color='black')
#                         #change bar width
#                         change_width(fig, bar_width)
#                         #add stats
#                         annotator = Annotator(fig, pair, data=df_new, x='TF_added', y='corrected_luminescence',order=order_new, verbose=False)
#                         annotator.configure(test='t-test_welch', text_format='star',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]])#loc='inside'
#                         ax, test_results = annotator.apply_and_annotate()
#                         with open(f'../../../../data/plots/luminescence/{date}/individual/stats.txt', 'a') as f:                            
#                             for res in test_results:
#                                 f.write(f'{str(prom)},{pair},{str(res.data)}\n')   



#                         # if pvalue<0.05:

#                         #     add_stat_annotation(
#                         #     fig,
#                         #     data=df_new,
#                         #     x='TF_added',
#                         #     y='corrected_luminescence',
#                         #     order=order_new,
#                         #     box_pairs=pair,
#                         #     text_format="star",
#                         #     loc="inside",
#                         #     verbose=2,
#                         #     perform_stat_test=False,
#                         #     pvalues=list(pvalue),
#                         #     #test='Mann-Whitney'
#                         #     #test_short_name="Dunn",
#                         #     )

#                         # change axes labels
#                         plt.ylabel('Normalised expression (a.u.)')
#                         #add title

#                         #plt.title(prom[:len(prom)-20], y=1,size=fontsize)
#                         plt.title(f'Co-expression\n 35s:{TF[1:]} + {prom}p:LucN', y=1,size=fontsize)
                        
#                         #make xticks diagonal
#                         plt.xticks(rotation=90, ha='center')#ha='right'
#                         #plt.xlabel(x_label)
#                         # tight layout
#                         plt.tight_layout()
#                         # save figure
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/individual/calibrator_35s/scatter{prom}_{TF}_plate1.pdf',
#                             format="pdf",
#                             bbox_inches="tight",transparent=True)
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/individual/calibrator_35s/scatter{prom}_{TF}_plate1.svg',
#                             format="svg",
#                             bbox_inches="tight",transparent=True)
#                         #don't show plot in notebook
#                         plt.close()

#         else:          
#             #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
#             #change name of TF added in df2 to minimal_stap4        
#             #df2['TF_added'] = 'pSTAP4 no TF'
#             # df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
#             TFs_orig =  df.TF_added.unique()
#             #print(TFs_orig)
#             TF_order = ['No TF','+ANR1','+bZIP3','+DREB26','+HHO2','+NLP6','+TGA1','+TGA1:GR','+bZIP3','+DREB26','+HHO2','+NLP6','+NLP7','+TGA1','+NLP7+bZIP3','+NLP7+TGA1','No TF nor YFP', 'No TF', '+TAD-Suntag_noguide','+TAD-Suntag_guide1','+TAD-Suntag_guides1,2,3','+VP64-Suntag_noguide','+VP64-Suntag_guide1','+VP64-Suntag_guides1,2,3','+SRDX-dCpf1_noguide','+SRDX-dCpf1_guide1','+SRDX-dCpf1_guide2','+SRDX-dCpf1_guide3','+SRDX-dCpf1_guides1,2,3','+SRDX-dCpf1_guides1,2,4','+SRDX-Suntag_noguide','+SRDX-Suntag_123guides1,2,3']
#             #'No TF/YFP','+No TF/YFP_1μM_NAA',
#             #sort based on custom order
#             TFs = []
#             for i in range(len(TF_order)):
#                 if TF_order[i] in TFs_orig:
#                     TFs+=[TF_order[i]]
#             #print(TFs)
#             #print(df)
#             #get length of number of TFs
#             #length_tf = len(TFs)
#             #create order and box pairs based on the length of TFs
#             #iterate through TFs
#             #pass if only one TF
#             if len(TFs) < 2:
#                 pass
#             else:
#                 for TF in TFs:
#                     if TF == 'No TF':
#                         pass
#                     else:
                        
                        
#                         #create new df with only TF of interest
#                         df_new = df[(df.TF_added == TF) | (df.TF_added == 'No TF')]
#                         #create box pairs
#                         pair = [('No TF', TF)]
#                         #print(pair)
#                         #pvalue = []
                    
#                         # #create series objects
#                         # TF1 = df_new.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
#                         # TF2 = df_new.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
#                         # # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
#                         # # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
#                         # #equal variance = false so do Welch's T-test
#                         # results = stats.ttest_ind(TF1, TF2, equal_var=False)
#                         #     #append pvalue to dict
#                         # pvalue = results.pvalue
#                         # # box_pairs_significant.append(pair)
#                         # # p_values.append(results.pvalue)
#                         # print(f'pvalue={pvalue}')

#                         # # #filter dict by significance and put in a new dictionary
#                         # # box_pairs_significant = {}
#                         # # for k,v in box_pairs_all_pvalues.items():
#                         # #     if v <0.05:
#                         # #         box_pairs_significant[k] = v
                        
#                         #make plot 
#                         if TF == '+TAD-Suntag_noguide' or TF == '+TAD-Suntag_guide1' or TF == '+TAD-Suntag_guides1,2,3' or TF == '+VP64-Suntag_noguide' or TF == '+VP64-Suntag_guide1' or TF == '+VP64-Suntag_guides1,2,3' or TF == '+SRDX-dCpf1_noguide' or TF == '+SRDX-dCpf1_guide1' or TF == '+SRDX-dCpf1_guide2' or TF == '+SRDX-dCpf1_guide3' or TF == '+SRDX-dCpf1_guides1,2,3' or TF == '+SRDX-dCpf1_guides1,2,4' or TF == '+SRDX-Suntag_noguide' or TF == '+SRDX-Suntag_123guides1,2,3':

#                             plt.figure(figsize=(6,6))

#                         else:
#                             plt.figure(figsize=(width,height))
#                         order_new = pair[0]
#                         fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,color='#BFBFBF')#facecolor=(1,1,1,1)
#                         #fig.set_aspect(0.5)
#                         sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df_new, order=order_new,color='black')
#                         #change bar width
#                         change_width(fig, bar_width)

#                         #add stats

#                         annotator = Annotator(fig, pair, data=df_new, x='TF_added', y='corrected_luminescence',order=order_new,verbose=False)
#                         annotator.configure(test='t-test_welch', text_format='star',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1,"ns"]])#loc='inside'
#                         ax, test_results = annotator.apply_and_annotate()
#                         with open(f'../../../../data/plots/luminescence/{date}/individual/stats.txt', 'a') as f:                            
#                             for res in test_results:
#                                 f.write(f'{str(prom)},{pair},{str(res.data)}\n') 
                        



#                         # if pvalue<0.05:

#                         #     add_stat_annotation(
#                         #     fig,
#                         #     data=df_new,
#                         #     x='TF_added',
#                         #     y='corrected_luminescence',
#                         #     order=order_new,
#                         #     box_pairs=pair,
#                         #     text_format="star",
#                         #     loc="inside",
#                         #     verbose=2,
#                         #     perform_stat_test=False,
#                         #     pvalues=list(pvalue),
#                         #     #test='Mann-Whitney'
#                         #     #test_short_name="Dunn",
#                         #     )

#                         # change axes labels
#                         plt.ylabel('Normalised expression (a.u.)')
#                         #add title
#                         if TF == '+TAD-Suntag_noguide' or TF == '+TAD-Suntag_guide1' or TF == '+TAD-Suntag_guides1,2,3' or TF == '+VP64-Suntag_noguide' or TF == '+VP64-Suntag_guide1' or TF == '+VP64-Suntag_guides1,2,3' or TF == '+SRDX-dCpf1_noguide' or TF == '+SRDX-dCpf1_guide1' or TF == '+SRDX-dCpf1_guide2' or TF == '+SRDX-dCpf1_guide3' or TF == '+SRDX-dCpf1_guides1,2,3' or TF == '+SRDX-dCpf1_guides1,2,4' or TF == '+SRDX-Suntag_noguide' or TF == '+SRDX-Suntag_123guides1,2,3':
#                             pass
#                         else:
#                             plt.title(f'Co-expression\n 35s:{TF[1:]} + {prom}p:LucN', y=1,size=fontsize)
#                         #make xticks diagonal
#                         plt.xticks(rotation=90, ha='center')#ha='right'
#                         #plt.xlabel(x_label)
#                         # tight layout
#                         plt.tight_layout()
#                         # save figure
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/individual/calibrator_nos/scatter{prom}_{TF}_plate1.pdf',
#                             format="pdf",
#                             bbox_inches="tight",transparent=True)
#                         plt.savefig(
#                             f'../../../../data/plots/luminescence/{date}/individual/calibrator_nos/scatter{prom}_{TF}_plate1.svg',
#                             format="svg",
#                             bbox_inches="tight",transparent=True)
#                         #don't show plot in notebook
#                         plt.close()

# %%
#make ARF plots
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 24
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.65

#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == 'ARF18' or prom == 'ANR1' or prom == 'ANAC032' or prom =='NIR1' or prom == 'NLP6' or prom == '35s:NLUC:YFP' or prom == 'NRP:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker' or prom == '4x[bZIP3-random]:NLUC:YFP' or prom =='DREB26' or prom == 'NLP7' or prom =='ANAC032_ablated_TGA1_all_sites':
        pass
    #if 35s calibrator in promoter name, skip promoter
    elif "_35s:LucF_calibrator" in prom:
        pass
    else:        
          
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF18_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA','+ARF18+IAA33_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        #new_TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33','','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF18_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA','+ARF18+IAA33_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        #'No TF/YFP','+No TF/YFP_1μM_NAA',
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        if len(TFs) <= 1:
            pass
        else:
            #create order and box pairs based on the length of TFs
            order = []
            box_pairs = []   
            for x in range (0, (length_tf)):
                order.append(TFs[x])
                if TFs[x] == "No TF" or TFs[x] == "No TF_1μM_NAA":
                    pass
                #if auxin condition, use auxin control
                elif "_1μM_NAA" in TFs[x]:
                    box_pairs.append(('No TF_1μM_NAA',TFs[x]))

                else:
                    box_pairs.append(('No TF',TFs[x]))
            #add every combination of box pairs of length 2
            #box_pairs=list(combinations(order, 2))~
            #make box pairs dict with box pair and p value
            box_pairs_all_pvalues = {}
            #make dict containing the TF and p value compared to its control (either No TF with auxin or no auxin No TF)
            TFs_pvalues = {}
            for pair in box_pairs:
                #create series objects
                TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
                TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
            # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
            # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
            #equal variance = false so do Welch's T-test
                results = stats.ttest_ind(TF1, TF2, equal_var=False)
                #append pvalue to dict
                box_pairs_all_pvalues[pair] = results.pvalue
                TFs_pvalues[pair[1]] = results.pvalue
            # box_pairs_significant.append(pair)
            # p_values.append(results.pvalue)
            #print(f'all pvalues={box_pairs_all_pvalues}')

            # #filter dict by significance and put in a new dictionary
            box_pairs_significant = {}
            for k,v in box_pairs_all_pvalues.items():
                if v <0.05:
                    box_pairs_significant[k] = v

            def convert_pvalue_to_asterisks(pvalue):
                if pvalue <= 0.001:
                    return "***"
                elif pvalue <= 0.01:
                    return "**"
                elif pvalue <= 0.05:
                    return "*"
                return "ns"
            #print(df.columns)
            #'well', 'content', 'fluc_luminescence', 'nluc_luminescence', 'well_row',
        #    'well_col', 'name', 'condition', 'nluc/fluc', 'date', 'Promoter',
        #    'TF_added', 'Well_calibrator', 'Plate_number',
        #    'corrected_luminescence'
            #add a blank data point in between non-auxin and auxin conditions

            #new_df = pd.concat([df[df.condition == 'nitrogen'], pd.DataFrame({'well':[''],'content':[''],'fluc_luminescence':[0],'nluc_luminescence':[0], 'well_row':[''],'well_col':[0], 'name':[''], 'condition':['nitrogen'], 'nluc/fluc':[0], 'date':[''], 'Promoter':[prom],'TF_added':[''], 'Well_calibrator':[''], 'Plate_number':[0],'corrected_luminescence':[0]}, df[df.condition == '1uM_auxin'])])

            # #rename x values
            # names = df.TF_added.unique()
            # #Change TF names to +TF
            # df_renamed = df.copy()
            # for TF in names:
            #     if '_1μM_NAA' in TF:
            #         new_name = TF[:len(TF)-8]
            #         df_renamed.TF_added.replace(TF,new_name, inplace=True)
            
            # if len(TFs) is 3:
            #     order = [TFs[0],TFs[1],TFs[2]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[1],TFs[2])]
            # elif len(TFs) is 4:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]),(TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]  
            # elif len(TFs) is 5:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[3],TFs[4])]
            # elif len(TFs) is 6:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[4],TFs[5])]
            # elif len(TFs) is 7:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[5],TFs[6])]
            # elif len(TFs) is 8:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6],TFs[7]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]),(TFs[0],TFs[7]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[1],TFs[7]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[2],TFs[7]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[3],TFs[7]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[4],TFs[7]),(TFs[5],TFs[6]),(TFs[5],TFs[7]),(TFs[6],TFs[7])]
                


            if len(TFs) == 2:
                #plt.figure()
                plt.figure(figsize=(length_tf*0.8,8))
                #order_new = [TFs[0],TFs[1]]
                
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4, dodge=True, color='#BFBFBF')#facecolor=(1,1,1,1),
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True,)
                #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, color=".25", order=order_new)


                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                #stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # label box pairs        
                #box_pairs = [(TFs[0],TFs[1])]
                
                # make empty list of p_values
            # p_values = []
                # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                #     print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
                # add_stat_annotation(
                #     fig,
                #     data=df,
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     order=order_new,
                #     box_pairs=list(box_pairs_significant.keys()),
                #     text_format="star",
                #     loc="outside",
                #     verbose=2,
                #     perform_stat_test=False,
                #     pvalues=list(box_pairs_significant.values()),
                #     #test='Mann-Whitney',
                # )
                # # change axes labels
                # plt.ylabel('Normalised expression (a.u.)')
                # #add title
                # plt.title(prom)
                # #make xticks diagonal
                # plt.xticks(rotation=45, ha='right')
                # #plt.xlabel(x_label)
                # # tight layout
                # plt.tight_layout()
                # # save figure
                # plt.savefig(
                #     f'../../../../data/plots/luminescence/{date}/scatter{prom}_plate1.pdf',
                #     format="pdf",
                #     bbox_inches="tight",
            # )
            elif len(TFs) < 2:
                pass
            else:
                #print(prom)
                #print(TFs)
                plt.figure(figsize=(length_tf*0.8,8))
                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,dodge=True, color='lightgrey')#facecolor=(1,1,1,1)
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True)
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                # stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # # label box pairs        
                # #box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]
                # # make empty list of p_values
                # p_values = []
                # # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                # #    print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
            #add stats
            #print(box_pairs)
            #if no significant values, don't add stats annotation

            


            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     pass
                # #add a gap between no auxin and auxin conditions
                # #first identify No TF_1μM_NAA X position
                # middle = order.index("No TF_1μM_NAA")
                # #then modify x locations with a gap before the auxin no tf position

                # x_locations = list(range(0,middle))+list(range(middle+1,len(order)+1))
                # print(x_locations)
                # plt.xticks(x_locations,order)
                
                #plt.bar_label(box_pairs_all_pvalues.values())
                #get x length
                xlength=len(fig.patches)
                #print(f'xlength={xlength}')
                #add patterned hatching to the bars length_tf
                #hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                #also add asterisks for p values
                #make empty variable to show when No TF_1μM_NAA has been iterated over
                auxin_control_picked = False
                for x in range (0, (xlength)):
                    current_TF = order[x]
                    if current_TF == "No TF" or current_TF == '':                
                        pass
                    elif current_TF == "No TF_1μM_NAA":
                        auxin_control_picked = True                    
                    # hatch = next(hatches)
                        fig.patches[x].set_facecolor('grey')
                    else:
                        pvalue = TFs_pvalues[current_TF]

                        
                    # pvalue = list(box_pairs_all_pvalues.values())[x]
                        #key=list(box_pairs_all_pvalues.keys())[x][1]
                        p = fig.patches[x]
                        fig.annotate(convert_pvalue_to_asterisks(pvalue),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha = 'center', va = 'center',
                        size=fontsize,
                        xytext = (0, 10), 
                        textcoords = 'offset points')
                        #add patterned hatching to the bars length_tf
                        if auxin_control_picked == True:
                            
                            p.set_facecolor('grey')
                
                # hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                # for i, bar in enumerate(fig.patches):
                #     print(f'i={i},bar={bar}')
                #     if i % length_tf == 0:
                #         hatch = next(hatches)
                #     bar.set_hatch(hatch)
                # y_position = df['corrected_luminescence'].max()
                # for k, v in box_pairs_all_pvalues.items():
                #     plt.text(x=k[1], y=y_position, s=convert_pvalue_to_asterisks(v))
                # #annotator = Annotator(fig, pairs=list(box_pairs), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # annotator = Annotator(fig, pairs=list(box_pairs_significant.keys()), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # #annotator.set_pvalues(list(box_pairs))
                # annotator.set_pvalues(list(box_pairs_significant.values()))
                # #annotator.configure(test='Mann-Whitney',verbose=2,text_format='star', loc='inside',)#loc='inside'
                # #annotator.apply_and_annotate()
                # annotator.annotate()


                #if no significant values, don't add stats annotation
            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     add_stat_annotation(
            #         fig,
            #         data=df,
            #         x='TF_added',
            #         y='corrected_luminescence',
            #         order=order,
            #         box_pairs=list(box_pairs_significant.keys()),
            #         text_format="star",
            #         loc="outside",
            #         verbose=2,
            #         perform_stat_test=False,
            #         pvalues=list(box_pairs_significant.values()),
            #         #test_short_name="Dunn",
            #     )
                    #change name of promoters

        #add custom legend
        handles = []
        labels = []
        no_auxin = mpatches.Patch(facecolor='lightgrey', hatch='',edgecolor='black',linewidth=2)
        auxin = mpatches.Patch(facecolor='grey', hatch='',edgecolor='black',linewidth=2)
        no_auxin_label = "No NAA"
        auxin_label = "1 µM NAA"
        handles.append(no_auxin)
        handles.append(auxin)
        labels.append(no_auxin_label)
        labels.append(auxin_label)
        fig.legend(handles=handles,labels=labels,ncol=1,bbox_to_anchor=(0.1,0.85), loc='lower left',fontsize=fontsize*0.7)
        
        new_labels = []        
        for TF in order:
            if '_1μM_NAA' in TF:
                TFs_orig_renamed = TF[:len(TF)-8]
                new_labels.append(TFs_orig_renamed)
            else:
                new_labels.append(TF)
                
        fig.set_xticklabels(new_labels)
        # change axes labels
        plt.ylabel('Normalised expression (a.u.)')
        #add title
        plt.title(prom, y=1,size=fontsize)
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARFs_plate1.pdf',
            format="pdf",
            bbox_inches="tight",transparent=True)

        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARFs_plate1.svg',
            format="svg",
            bbox_inches="tight",transparent=True)

        #don't show plot in notebook
        plt.close()
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# ANAC032_ablated_ARFs
# ['No TF', '+ARF9+IAA33', '+ARF18+IAA33', '+ARF18+ARF9+IAA33', 'No TF_1μM_NAA', '+ARF9+IAA33_1μM_NAA', '+ARF18+IAA33_1μM_NAA', '+ARF18+ARF9+IAA33_1μM_NAA']

# %%
#make ARF9 plots separate
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 24
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.65

#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == 'ARF18' or prom == 'ANR1' or prom == 'ANAC032' or prom =='NIR1' or prom == 'NLP6' or prom == '35s:NLUC:YFP' or prom == 'NRP:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker' or prom == '4x[bZIP3-random]:NLUC:YFP' or prom =='DREB26' or prom == 'NLP7' or prom =='ANAC032_ablated_TGA1_all_sites':
        pass
    #if 35s calibrator in promoter name, skip promoter
    elif "_35s:LucF_calibrator" in prom:
        pass
    else:    


          
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        TF_order = ['No TF','+ARF9','+ARF9+IAA33','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA']
        #new_TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33','','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF18_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA','+ARF18+IAA33_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        #'No TF/YFP','+No TF/YFP_1μM_NAA',
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        if len(TFs) <= 1:
            pass
        else:
            #create order and box pairs based on the length of TFs
            order = []
            box_pairs = []   
            for x in range (0, (length_tf)):
                order.append(TFs[x])
                if TFs[x] == "No TF" or TFs[x] == "No TF_1μM_NAA":
                    pass
                #if auxin condition, use auxin control
                elif "_1μM_NAA" in TFs[x]:
                    box_pairs.append(('No TF_1μM_NAA',TFs[x]))

                else:
                    box_pairs.append(('No TF',TFs[x]))
            #add every combination of box pairs of length 2
            #box_pairs=list(combinations(order, 2))~
            #make box pairs dict with box pair and p value
            box_pairs_all_pvalues = {}
            #make dict containing the TF and p value compared to its control (either No TF with auxin or no auxin No TF)
            TFs_pvalues = {}
            for pair in box_pairs:
                #create series objects
                TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
                TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
            # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
            # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
            #equal variance = false so do Welch's T-test
                results = stats.ttest_ind(TF1, TF2, equal_var=False)
                #append pvalue to dict
                box_pairs_all_pvalues[pair] = results.pvalue
                TFs_pvalues[pair[1]] = results.pvalue
            # box_pairs_significant.append(pair)
            # p_values.append(results.pvalue)
            #print(f'all pvalues={box_pairs_all_pvalues}')

            # #filter dict by significance and put in a new dictionary
            box_pairs_significant = {}
            for k,v in box_pairs_all_pvalues.items():
                if v <0.05:
                    box_pairs_significant[k] = v

            def convert_pvalue_to_asterisks(pvalue):
                if pvalue <= 0.001:
                    return "***"
                elif pvalue <= 0.01:
                    return "**"
                elif pvalue <= 0.05:
                    return "*"
                return "ns"
            #print(df.columns)
            #'well', 'content', 'fluc_luminescence', 'nluc_luminescence', 'well_row',
        #    'well_col', 'name', 'condition', 'nluc/fluc', 'date', 'Promoter',
        #    'TF_added', 'Well_calibrator', 'Plate_number',
        #    'corrected_luminescence'
            #add a blank data point in between non-auxin and auxin conditions

            #new_df = pd.concat([df[df.condition == 'nitrogen'], pd.DataFrame({'well':[''],'content':[''],'fluc_luminescence':[0],'nluc_luminescence':[0], 'well_row':[''],'well_col':[0], 'name':[''], 'condition':['nitrogen'], 'nluc/fluc':[0], 'date':[''], 'Promoter':[prom],'TF_added':[''], 'Well_calibrator':[''], 'Plate_number':[0],'corrected_luminescence':[0]}, df[df.condition == '1uM_auxin'])])

            # #rename x values
            # names = df.TF_added.unique()
            # #Change TF names to +TF
            # df_renamed = df.copy()
            # for TF in names:
            #     if '_1μM_NAA' in TF:
            #         new_name = TF[:len(TF)-8]
            #         df_renamed.TF_added.replace(TF,new_name, inplace=True)
            
            # if len(TFs) is 3:
            #     order = [TFs[0],TFs[1],TFs[2]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[1],TFs[2])]
            # elif len(TFs) is 4:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]),(TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]  
            # elif len(TFs) is 5:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[3],TFs[4])]
            # elif len(TFs) is 6:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[4],TFs[5])]
            # elif len(TFs) is 7:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[5],TFs[6])]
            # elif len(TFs) is 8:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6],TFs[7]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]),(TFs[0],TFs[7]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[1],TFs[7]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[2],TFs[7]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[3],TFs[7]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[4],TFs[7]),(TFs[5],TFs[6]),(TFs[5],TFs[7]),(TFs[6],TFs[7])]
                


            if len(TFs) == 2:
                #plt.figure()
                plt.figure(figsize=(length_tf*0.8,8))
                #order_new = [TFs[0],TFs[1]]
                
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4, dodge=True, color='#BFBFBF')#facecolor=(1,1,1,1),
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True,)
                #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, color=".25", order=order_new)


                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                #stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # label box pairs        
                #box_pairs = [(TFs[0],TFs[1])]
                
                # make empty list of p_values
            # p_values = []
                # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                #     print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
                # add_stat_annotation(
                #     fig,
                #     data=df,
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     order=order_new,
                #     box_pairs=list(box_pairs_significant.keys()),
                #     text_format="star",
                #     loc="outside",
                #     verbose=2,
                #     perform_stat_test=False,
                #     pvalues=list(box_pairs_significant.values()),
                #     #test='Mann-Whitney',
                # )
                # # change axes labels
                # plt.ylabel('Normalised expression (a.u.)')
                # #add title
                # plt.title(prom)
                # #make xticks diagonal
                # plt.xticks(rotation=45, ha='right')
                # #plt.xlabel(x_label)
                # # tight layout
                # plt.tight_layout()
                # # save figure
                # plt.savefig(
                #     f'../../../../data/plots/luminescence/{date}/scatter{prom}_plate1.pdf',
                #     format="pdf",
                #     bbox_inches="tight",
            # )
            elif len(TFs) < 2:
                pass
            else:
                print(prom)
                print(TFs)
                plt.figure(figsize=(length_tf,8))
                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,dodge=True, color='lightgrey')#facecolor=(1,1,1,1)
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True)
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                # stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # # label box pairs        
                # #box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]
                # # make empty list of p_values
                # p_values = []
                # # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                # #    print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
            #add stats
            #print(box_pairs)
            #if no significant values, don't add stats annotation

            


            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     pass
                # #add a gap between no auxin and auxin conditions
                # #first identify No TF_1μM_NAA X position
                # middle = order.index("No TF_1μM_NAA")
                # #then modify x locations with a gap before the auxin no tf position

                # x_locations = list(range(0,middle))+list(range(middle+1,len(order)+1))
                # print(x_locations)
                # plt.xticks(x_locations,order)
                
                #plt.bar_label(box_pairs_all_pvalues.values())
                #get x length
                xlength=len(fig.patches)
                #print(f'xlength={xlength}')
                #add patterned hatching to the bars length_tf
                #hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                #also add asterisks for p values
                #make empty variable to show when No TF_1μM_NAA has been iterated over
                auxin_control_picked = False
                for x in range (0, (xlength)):
                    current_TF = order[x]
                    if current_TF == "No TF" or current_TF == '':                
                        pass
                    elif current_TF == "No TF_1μM_NAA":
                        auxin_control_picked = True                    
                    # hatch = next(hatches)
                        fig.patches[x].set_facecolor('grey')
                    else:
                        pvalue = TFs_pvalues[current_TF]

                        
                    # pvalue = list(box_pairs_all_pvalues.values())[x]
                        #key=list(box_pairs_all_pvalues.keys())[x][1]
                        p = fig.patches[x]
                        fig.annotate(convert_pvalue_to_asterisks(pvalue),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha = 'center', va = 'center',
                        size=fontsize,
                        xytext = (0, 10), 
                        textcoords = 'offset points')
                        #add patterned hatching to the bars length_tf
                        if auxin_control_picked == True:
                            
                            p.set_facecolor('grey')
                
                # hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                # for i, bar in enumerate(fig.patches):
                #     print(f'i={i},bar={bar}')
                #     if i % length_tf == 0:
                #         hatch = next(hatches)
                #     bar.set_hatch(hatch)
                # y_position = df['corrected_luminescence'].max()
                # for k, v in box_pairs_all_pvalues.items():
                #     plt.text(x=k[1], y=y_position, s=convert_pvalue_to_asterisks(v))
                # #annotator = Annotator(fig, pairs=list(box_pairs), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # annotator = Annotator(fig, pairs=list(box_pairs_significant.keys()), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # #annotator.set_pvalues(list(box_pairs))
                # annotator.set_pvalues(list(box_pairs_significant.values()))
                # #annotator.configure(test='Mann-Whitney',verbose=2,text_format='star', loc='inside',)#loc='inside'
                # #annotator.apply_and_annotate()
                # annotator.annotate()


                #if no significant values, don't add stats annotation
            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     add_stat_annotation(
            #         fig,
            #         data=df,
            #         x='TF_added',
            #         y='corrected_luminescence',
            #         order=order,
            #         box_pairs=list(box_pairs_significant.keys()),
            #         text_format="star",
            #         loc="outside",
            #         verbose=2,
            #         perform_stat_test=False,
            #         pvalues=list(box_pairs_significant.values()),
            #         #test_short_name="Dunn",
            #     )
                    #change name of promoters

        #add custom legend
        handles = []
        labels = []
        no_auxin = mpatches.Patch(facecolor='lightgrey', hatch='',edgecolor='black',linewidth=2)
        auxin = mpatches.Patch(facecolor='grey', hatch='',edgecolor='black',linewidth=2)
        no_auxin_label = "No NAA"
        auxin_label = "1 µM NAA"
        handles.append(no_auxin)
        handles.append(auxin)
        labels.append(no_auxin_label)
        labels.append(auxin_label)
        fig.legend(handles=handles,labels=labels,ncol=1,bbox_to_anchor=(0.1,0.85), loc='lower left',fontsize=fontsize*0.7)
        
        new_labels = []        
        for TF in order:
            if '_1μM_NAA' in TF:
                TFs_orig_renamed = TF[:len(TF)-8]
                new_labels.append(TFs_orig_renamed)
            else:
                new_labels.append(TF)
                
        fig.set_xticklabels(new_labels)
        # change axes labels
        plt.ylabel('Normalised expression (a.u.)')
        #add title
        plt.title(prom, y=1,size=fontsize)
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARF9_plate1.pdf',
            format="pdf",
            bbox_inches="tight",transparent=True)

        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARF9_plate1.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# ANAC032_ablated_ARFs
# ['No TF', '+ARF9+IAA33', 'No TF_1μM_NAA', '+ARF9+IAA33_1μM_NAA']

# %%
#make ARF18 plots separate
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 24
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.65

#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == 'ARF18' or prom == 'ANR1' or prom == 'ANAC032' or prom =='NIR1' or prom == 'NLP6' or prom == '35s:NLUC:YFP' or prom == 'NRP:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker' or prom == '4x[bZIP3-random]:NLUC:YFP' or prom =='DREB26' or prom == 'NLP7' or prom =='ANAC032_ablated_TGA1_all_sites':
        pass
    #if 35s calibrator in promoter name, skip promoter
    elif "_35s:LucF_calibrator" in prom:
        pass
    else:           
          
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        TF_order = ['No TF','+ARF18','+ARF18+IAA33','No TF_1μM_NAA','+ARF18_1μM_NAA','+ARF18+IAA33_1μM_NAA']

        #new_TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33','','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF18_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA','+ARF18+IAA33_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        #'No TF/YFP','+No TF/YFP_1μM_NAA',
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        if len(TFs) <= 1:
            pass
        else:
            #create order and box pairs based on the length of TFs
            order = []
            box_pairs = []   
            for x in range (0, (length_tf)):
                order.append(TFs[x])
                if TFs[x] == "No TF" or TFs[x] == "No TF_1μM_NAA":
                    pass
                #if auxin condition, use auxin control
                elif "_1μM_NAA" in TFs[x]:
                    box_pairs.append(('No TF_1μM_NAA',TFs[x]))

                else:
                    box_pairs.append(('No TF',TFs[x]))
            #add every combination of box pairs of length 2
            #box_pairs=list(combinations(order, 2))~
            #make box pairs dict with box pair and p value
            box_pairs_all_pvalues = {}
            #make dict containing the TF and p value compared to its control (either No TF with auxin or no auxin No TF)
            TFs_pvalues = {}
            for pair in box_pairs:
                #create series objects
                TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
                TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
            # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
            # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
            #equal variance = false so do Welch's T-test
                results = stats.ttest_ind(TF1, TF2, equal_var=False)
                #append pvalue to dict
                box_pairs_all_pvalues[pair] = results.pvalue
                TFs_pvalues[pair[1]] = results.pvalue
            # box_pairs_significant.append(pair)
            # p_values.append(results.pvalue)
            #print(f'all pvalues={box_pairs_all_pvalues}')

            # #filter dict by significance and put in a new dictionary
            box_pairs_significant = {}
            for k,v in box_pairs_all_pvalues.items():
                if v <0.05:
                    box_pairs_significant[k] = v

            def convert_pvalue_to_asterisks(pvalue):
                if pvalue <= 0.001:
                    return "***"
                elif pvalue <= 0.01:
                    return "**"
                elif pvalue <= 0.05:
                    return "*"
                return "ns"
            #print(df.columns)
            #'well', 'content', 'fluc_luminescence', 'nluc_luminescence', 'well_row',
        #    'well_col', 'name', 'condition', 'nluc/fluc', 'date', 'Promoter',
        #    'TF_added', 'Well_calibrator', 'Plate_number',
        #    'corrected_luminescence'
            #add a blank data point in between non-auxin and auxin conditions

            #new_df = pd.concat([df[df.condition == 'nitrogen'], pd.DataFrame({'well':[''],'content':[''],'fluc_luminescence':[0],'nluc_luminescence':[0], 'well_row':[''],'well_col':[0], 'name':[''], 'condition':['nitrogen'], 'nluc/fluc':[0], 'date':[''], 'Promoter':[prom],'TF_added':[''], 'Well_calibrator':[''], 'Plate_number':[0],'corrected_luminescence':[0]}, df[df.condition == '1uM_auxin'])])

            # #rename x values
            # names = df.TF_added.unique()
            # #Change TF names to +TF
            # df_renamed = df.copy()
            # for TF in names:
            #     if '_1μM_NAA' in TF:
            #         new_name = TF[:len(TF)-8]
            #         df_renamed.TF_added.replace(TF,new_name, inplace=True)
            
            # if len(TFs) is 3:
            #     order = [TFs[0],TFs[1],TFs[2]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[1],TFs[2])]
            # elif len(TFs) is 4:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]),(TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]  
            # elif len(TFs) is 5:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[3],TFs[4])]
            # elif len(TFs) is 6:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[4],TFs[5])]
            # elif len(TFs) is 7:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[5],TFs[6])]
            # elif len(TFs) is 8:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6],TFs[7]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]),(TFs[0],TFs[7]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[1],TFs[7]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[2],TFs[7]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[3],TFs[7]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[4],TFs[7]),(TFs[5],TFs[6]),(TFs[5],TFs[7]),(TFs[6],TFs[7])]
                


            if len(TFs) == 2:
                #plt.figure()
                plt.figure(figsize=(length_tf*0.8,8))
                #order_new = [TFs[0],TFs[1]]
                
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4, dodge=True, color='#BFBFBF')#facecolor=(1,1,1,1),
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True,)
                #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, color=".25", order=order_new)


                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                #stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # label box pairs        
                #box_pairs = [(TFs[0],TFs[1])]
                
                # make empty list of p_values
            # p_values = []
                # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                #     print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
                # add_stat_annotation(
                #     fig,
                #     data=df,
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     order=order_new,
                #     box_pairs=list(box_pairs_significant.keys()),
                #     text_format="star",
                #     loc="outside",
                #     verbose=2,
                #     perform_stat_test=False,
                #     pvalues=list(box_pairs_significant.values()),
                #     #test='Mann-Whitney',
                # )
                # # change axes labels
                # plt.ylabel('Normalised expression (a.u.)')
                # #add title
                # plt.title(prom)
                # #make xticks diagonal
                # plt.xticks(rotation=45, ha='right')
                # #plt.xlabel(x_label)
                # # tight layout
                # plt.tight_layout()
                # # save figure
                # plt.savefig(
                #     f'../../../../data/plots/luminescence/{date}/scatter{prom}_plate1.pdf',
                #     format="pdf",
                #     bbox_inches="tight",
            # )
            elif len(TFs) < 2:
                pass
            else:
                print(prom)
                print(TFs)
                plt.figure(figsize=(length_tf,8))
                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,dodge=True, color='lightgrey')#facecolor=(1,1,1,1)
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True)
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                # stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # # label box pairs        
                # #box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]
                # # make empty list of p_values
                # p_values = []
                # # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                # #    print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
            #add stats
            #print(box_pairs)
            #if no significant values, don't add stats annotation

            


            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     pass
                # #add a gap between no auxin and auxin conditions
                # #first identify No TF_1μM_NAA X position
                # middle = order.index("No TF_1μM_NAA")
                # #then modify x locations with a gap before the auxin no tf position

                # x_locations = list(range(0,middle))+list(range(middle+1,len(order)+1))
                # print(x_locations)
                # plt.xticks(x_locations,order)
                
                #plt.bar_label(box_pairs_all_pvalues.values())
                #get x length
                xlength=len(fig.patches)
                #print(f'xlength={xlength}')
                #add patterned hatching to the bars length_tf
                #hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                #also add asterisks for p values
                #make empty variable to show when No TF_1μM_NAA has been iterated over
                auxin_control_picked = False
                for x in range (0, (xlength)):
                    current_TF = order[x]
                    if current_TF == "No TF" or current_TF == '':                
                        pass
                    elif current_TF == "No TF_1μM_NAA":
                        auxin_control_picked = True                    
                    # hatch = next(hatches)
                        fig.patches[x].set_facecolor('grey')
                    else:
                        pvalue = TFs_pvalues[current_TF]

                        
                    # pvalue = list(box_pairs_all_pvalues.values())[x]
                        #key=list(box_pairs_all_pvalues.keys())[x][1]
                        p = fig.patches[x]
                        fig.annotate(convert_pvalue_to_asterisks(pvalue),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha = 'center', va = 'center',
                        size=fontsize,
                        xytext = (0, 10), 
                        textcoords = 'offset points')
                        #add patterned hatching to the bars length_tf
                        if auxin_control_picked == True:
                            
                            p.set_facecolor('grey')
                
                # hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                # for i, bar in enumerate(fig.patches):
                #     print(f'i={i},bar={bar}')
                #     if i % length_tf == 0:
                #         hatch = next(hatches)
                #     bar.set_hatch(hatch)
                # y_position = df['corrected_luminescence'].max()
                # for k, v in box_pairs_all_pvalues.items():
                #     plt.text(x=k[1], y=y_position, s=convert_pvalue_to_asterisks(v))
                # #annotator = Annotator(fig, pairs=list(box_pairs), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # annotator = Annotator(fig, pairs=list(box_pairs_significant.keys()), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # #annotator.set_pvalues(list(box_pairs))
                # annotator.set_pvalues(list(box_pairs_significant.values()))
                # #annotator.configure(test='Mann-Whitney',verbose=2,text_format='star', loc='inside',)#loc='inside'
                # #annotator.apply_and_annotate()
                # annotator.annotate()


                #if no significant values, don't add stats annotation
            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     add_stat_annotation(
            #         fig,
            #         data=df,
            #         x='TF_added',
            #         y='corrected_luminescence',
            #         order=order,
            #         box_pairs=list(box_pairs_significant.keys()),
            #         text_format="star",
            #         loc="outside",
            #         verbose=2,
            #         perform_stat_test=False,
            #         pvalues=list(box_pairs_significant.values()),
            #         #test_short_name="Dunn",
            #     )
                    #change name of promoters

        #add custom legend
        handles = []
        labels = []
        no_auxin = mpatches.Patch(facecolor='lightgrey', hatch='',edgecolor='black',linewidth=2)
        auxin = mpatches.Patch(facecolor='grey', hatch='',edgecolor='black',linewidth=2)
        no_auxin_label = "No NAA"
        auxin_label = "1 µM NAA"
        handles.append(no_auxin)
        handles.append(auxin)
        labels.append(no_auxin_label)
        labels.append(auxin_label)
        fig.legend(handles=handles,labels=labels,ncol=1,bbox_to_anchor=(0.1,0.85), loc='lower left',fontsize=fontsize*0.7)
        
        new_labels = []        
        for TF in order:
            if '_1μM_NAA' in TF:
                TFs_orig_renamed = TF[:len(TF)-8]
                new_labels.append(TFs_orig_renamed)
            else:
                new_labels.append(TF)
                
        fig.set_xticklabels(new_labels)
        # change axes labels
        plt.ylabel('Normalised expression (a.u.)')
        #add title
        plt.title(prom, y=1,size=fontsize)
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARF18_plate1.pdf',
            format="pdf",
            bbox_inches="tight",transparent=True)

        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARF18_plate1.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# ANAC032_ablated_ARFs
# ['No TF', '+ARF18+IAA33', 'No TF_1μM_NAA', '+ARF18+IAA33_1μM_NAA']

# %%
#make ARF9+18 plots separate
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 24
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.65

#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == 'ARF18' or prom == 'ANR1' or prom == 'ANAC032' or prom =='NIR1' or prom == 'NLP6' or prom == '35s:NLUC:YFP' or prom == 'NRP:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker' or prom == '4x[bZIP3-random]:NLUC:YFP' or prom =='DREB26' or prom == 'NLP7' or prom =='ANAC032_ablated_TGA1_all_sites':
        pass
    #if 35s calibrator in promoter name, skip promoter
    elif "_35s:LucF_calibrator" in prom:
        pass
    else:    
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        TF_order = ['No TF','+ARF18+ARF9','+ARF18+ARF9+IAA33','No TF_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        
        #new_TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33','','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF18_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA','+ARF18+IAA33_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        #'No TF/YFP','+No TF/YFP_1μM_NAA',
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        if len(TFs) <= 1:
            pass
        else:
            #create order and box pairs based on the length of TFs
            order = []
            box_pairs = []   
            for x in range (0, (length_tf)):
                order.append(TFs[x])
                if TFs[x] == "No TF" or TFs[x] == "No TF_1μM_NAA":
                    pass
                #if auxin condition, use auxin control
                elif "_1μM_NAA" in TFs[x]:
                    box_pairs.append(('No TF_1μM_NAA',TFs[x]))

                else:
                    box_pairs.append(('No TF',TFs[x]))
            #add every combination of box pairs of length 2
            #box_pairs=list(combinations(order, 2))~
            #make box pairs dict with box pair and p value
            box_pairs_all_pvalues = {}
            #make dict containing the TF and p value compared to its control (either No TF with auxin or no auxin No TF)
            TFs_pvalues = {}
            for pair in box_pairs:
                #create series objects
                TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
                TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
            # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
            # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
            #equal variance = false so do Welch's T-test
                results = stats.ttest_ind(TF1, TF2, equal_var=False)
                #append pvalue to dict
                box_pairs_all_pvalues[pair] = results.pvalue
                TFs_pvalues[pair[1]] = results.pvalue
            # box_pairs_significant.append(pair)
            # p_values.append(results.pvalue)
            #print(f'all pvalues={box_pairs_all_pvalues}')

            # #filter dict by significance and put in a new dictionary
            box_pairs_significant = {}
            for k,v in box_pairs_all_pvalues.items():
                if v <0.05:
                    box_pairs_significant[k] = v

            def convert_pvalue_to_asterisks(pvalue):
                if pvalue <= 0.001:
                    return "***"
                elif pvalue <= 0.01:
                    return "**"
                elif pvalue <= 0.05:
                    return "*"
                return "ns"
            #print(df.columns)
            #'well', 'content', 'fluc_luminescence', 'nluc_luminescence', 'well_row',
        #    'well_col', 'name', 'condition', 'nluc/fluc', 'date', 'Promoter',
        #    'TF_added', 'Well_calibrator', 'Plate_number',
        #    'corrected_luminescence'
            #add a blank data point in between non-auxin and auxin conditions

            #new_df = pd.concat([df[df.condition == 'nitrogen'], pd.DataFrame({'well':[''],'content':[''],'fluc_luminescence':[0],'nluc_luminescence':[0], 'well_row':[''],'well_col':[0], 'name':[''], 'condition':['nitrogen'], 'nluc/fluc':[0], 'date':[''], 'Promoter':[prom],'TF_added':[''], 'Well_calibrator':[''], 'Plate_number':[0],'corrected_luminescence':[0]}, df[df.condition == '1uM_auxin'])])

            # #rename x values
            # names = df.TF_added.unique()
            # #Change TF names to +TF
            # df_renamed = df.copy()
            # for TF in names:
            #     if '_1μM_NAA' in TF:
            #         new_name = TF[:len(TF)-8]
            #         df_renamed.TF_added.replace(TF,new_name, inplace=True)
            
            # if len(TFs) is 3:
            #     order = [TFs[0],TFs[1],TFs[2]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[1],TFs[2])]
            # elif len(TFs) is 4:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]),(TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]  
            # elif len(TFs) is 5:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[3],TFs[4])]
            # elif len(TFs) is 6:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[4],TFs[5])]
            # elif len(TFs) is 7:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[5],TFs[6])]
            # elif len(TFs) is 8:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6],TFs[7]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]),(TFs[0],TFs[7]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[1],TFs[7]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[2],TFs[7]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[3],TFs[7]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[4],TFs[7]),(TFs[5],TFs[6]),(TFs[5],TFs[7]),(TFs[6],TFs[7])]
                


            if len(TFs) == 2:
                #plt.figure()
                plt.figure(figsize=(length_tf*0.8,8))
                #order_new = [TFs[0],TFs[1]]
                
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4, dodge=True, color='#BFBFBF')#facecolor=(1,1,1,1),
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True,)
                #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, color=".25", order=order_new)


                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                #stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # label box pairs        
                #box_pairs = [(TFs[0],TFs[1])]
                
                # make empty list of p_values
            # p_values = []
                # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                #     print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
                # add_stat_annotation(
                #     fig,
                #     data=df,
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     order=order_new,
                #     box_pairs=list(box_pairs_significant.keys()),
                #     text_format="star",
                #     loc="outside",
                #     verbose=2,
                #     perform_stat_test=False,
                #     pvalues=list(box_pairs_significant.values()),
                #     #test='Mann-Whitney',
                # )
                # # change axes labels
                # plt.ylabel('Normalised expression (a.u.)')
                # #add title
                # plt.title(prom)
                # #make xticks diagonal
                # plt.xticks(rotation=45, ha='right')
                # #plt.xlabel(x_label)
                # # tight layout
                # plt.tight_layout()
                # # save figure
                # plt.savefig(
                #     f'../../../../data/plots/luminescence/{date}/scatter{prom}_plate1.pdf',
                #     format="pdf",
                #     bbox_inches="tight",
            # )
            elif len(TFs) < 2:
                pass
            else:
                print(prom)
                print(TFs)
                plt.figure(figsize=(length_tf,8))
                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,dodge=True, color='lightgrey')#facecolor=(1,1,1,1)
                change_width(fig, bar_width)
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True)
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                # stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # # label box pairs        
                # #box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]
                # # make empty list of p_values
                # p_values = []
                # # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                # #    print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
            #add stats
            #print(box_pairs)
            #if no significant values, don't add stats annotation

            


            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     pass
                # #add a gap between no auxin and auxin conditions
                # #first identify No TF_1μM_NAA X position
                # middle = order.index("No TF_1μM_NAA")
                # #then modify x locations with a gap before the auxin no tf position

                # x_locations = list(range(0,middle))+list(range(middle+1,len(order)+1))
                # print(x_locations)
                # plt.xticks(x_locations,order)
                
                #plt.bar_label(box_pairs_all_pvalues.values())
                #get x length
                xlength=len(fig.patches)
                #print(f'xlength={xlength}')
                #add patterned hatching to the bars length_tf
                #hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                #also add asterisks for p values
                #make empty variable to show when No TF_1μM_NAA has been iterated over
                auxin_control_picked = False
                for x in range (0, (xlength)):
                    current_TF = order[x]
                    if current_TF == "No TF" or current_TF == '':                
                        pass
                    elif current_TF == "No TF_1μM_NAA":
                        auxin_control_picked = True                    
                    # hatch = next(hatches)
                        fig.patches[x].set_facecolor('grey')
                    else:
                        pvalue = TFs_pvalues[current_TF]

                        
                    # pvalue = list(box_pairs_all_pvalues.values())[x]
                        #key=list(box_pairs_all_pvalues.keys())[x][1]
                        p = fig.patches[x]
                        fig.annotate(convert_pvalue_to_asterisks(pvalue),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha = 'center', va = 'center',
                        size=fontsize,
                        xytext = (0, 10), 
                        textcoords = 'offset points')
                        #add patterned hatching to the bars length_tf
                        if auxin_control_picked == True:
                            
                            p.set_facecolor('grey')
                
                # hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                # for i, bar in enumerate(fig.patches):
                #     print(f'i={i},bar={bar}')
                #     if i % length_tf == 0:
                #         hatch = next(hatches)
                #     bar.set_hatch(hatch)
                # y_position = df['corrected_luminescence'].max()
                # for k, v in box_pairs_all_pvalues.items():
                #     plt.text(x=k[1], y=y_position, s=convert_pvalue_to_asterisks(v))
                # #annotator = Annotator(fig, pairs=list(box_pairs), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # annotator = Annotator(fig, pairs=list(box_pairs_significant.keys()), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # #annotator.set_pvalues(list(box_pairs))
                # annotator.set_pvalues(list(box_pairs_significant.values()))
                # #annotator.configure(test='Mann-Whitney',verbose=2,text_format='star', loc='inside',)#loc='inside'
                # #annotator.apply_and_annotate()
                # annotator.annotate()


                #if no significant values, don't add stats annotation
            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     add_stat_annotation(
            #         fig,
            #         data=df,
            #         x='TF_added',
            #         y='corrected_luminescence',
            #         order=order,
            #         box_pairs=list(box_pairs_significant.keys()),
            #         text_format="star",
            #         loc="outside",
            #         verbose=2,
            #         perform_stat_test=False,
            #         pvalues=list(box_pairs_significant.values()),
            #         #test_short_name="Dunn",
            #     )
                    #change name of promoters

        #add custom legend
        handles = []
        labels = []
        no_auxin = mpatches.Patch(facecolor='lightgrey', hatch='',edgecolor='black',linewidth=2)
        auxin = mpatches.Patch(facecolor='grey', hatch='',edgecolor='black',linewidth=2)
        no_auxin_label = "No NAA"
        auxin_label = "1 µM NAA"
        handles.append(no_auxin)
        handles.append(auxin)
        labels.append(no_auxin_label)
        labels.append(auxin_label)
        fig.legend(handles=handles,labels=labels,ncol=1,bbox_to_anchor=(0.1,0.85), loc='lower left',fontsize=fontsize*0.7)
        
        new_labels = []        
        for TF in order:
            if '_1μM_NAA' in TF:
                TFs_orig_renamed = TF[:len(TF)-8]
                new_labels.append(TFs_orig_renamed)
            else:
                new_labels.append(TF)
                
        fig.set_xticklabels(new_labels)
        # change axes labels
        plt.ylabel('Normalised expression (a.u.)')
        #add title
        plt.title(prom, y=1,size=fontsize)
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARF9and18_plate1.pdf',
            format="pdf",
            bbox_inches="tight",transparent=True)

        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_ARF9and18_plate1.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# ANAC032_ablated_ARFs
# ['No TF', '+ARF18+ARF9+IAA33', 'No TF_1μM_NAA', '+ARF18+ARF9+IAA33_1μM_NAA']
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:411: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:416: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
#make DEX plots
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 24
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.65
#if exists, remove file
if os.path.exists(f'../../../../data/plots/luminescence/{date}/compare_DEX/stats.txt'):
    os.remove(f'../../../../data/plots/luminescence/{date}/compare_DEX/stats.txt')


#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == '35s:NLUC:YFP' or prom == 'NRP:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker' or prom == '4x[bZIP3-random]:NLUC:YFP' or prom == 'ANAC032_ablated_ARFs':
        pass
    #if 35s calibrator in promoter name, skip promoter
    elif "_35s:LucF_calibrator" in prom:
        pass
    else: 
          
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        TF_order = ['+TGA1:GR_10uM_DEX+DMSO','+TGA1:GR_EtOH+DMSO','No TF_10uM_DEX+DMSO','No TF_EtOH+DMSO','+TGA1:GR_overnight_10uM_DEX+DMSO','+TGA1:GR_overnight_EtOH+DMSO','No TF_overnight_10uM_DEX+DMSO','No TF_overnight_EtOH+DMSO']
        # TF_order = ['+TGA1:GR_10uM_DEX+35uM_CHX','+TGA1:GR_35uM_CHX+EtOH','+TGA1:GR_10uM_DEX+DMSO','+TGA1:GR_EtOH+DMSO','No TF_10uM_DEX+35uM_CHX','No TF_35uM_CHX+EtOH','No TF_10uM_DEX+DMSO','No TF_EtOH+DMSO','+TGA1:GR_overnight_10uM_DEX+35uM_CHX','+TGA1:GR_overnight_35uM_CHX+EtOH',' +TGA1:GR_overnight_10uM_DEX+DMSO','+TGA1:GR_overnight_EtOH+DMSO','No TF_overnight_10uM_DEX+35uM_CHX','No TF_overnight_35uM_CHX+EtOH','No TF_overnight_10uM_DEX+DMSO','No TF_overnight_EtOH+DMSO']#'+TGA1:GR_overnight_10uM_DEX+35uM_CHX','+TGA1:GR_overnight_35uM_CHX+EtOH',' +TGA1:GR_overnight_10uM_DEX+DMSO','+TGA1:GR_overnight_EtOH+DMSO','No TF_overnight_10uM_DEX+35uM_CHX','No TF_overnight_35uM_CHX+EtOH','No     TF_overnight_10uM_DEX+DMSO','No TF_overnight_EtOH+DMSO'

        #new_TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33','','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF18_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA','+ARF18+IAA33_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        #'No TF/YFP','+No TF/YFP_1μM_NAA',
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        if len(TFs) <= 1:
            pass
        else:
            #create order and box pairs based on the length of TFs
            order = []
            box_pairs = []   
            for x in range (0, (length_tf)):
                order.append(TFs[x])
                if TFs[x] == "'+TGA1:GR_EtOH+DMSO'" or TFs[x] == "No TF_EtOH+DMSO" or TFs[x] == "+TGA1:GR_overnight_EtOH+DMSO" or TFs[x] == "No TF_overnight_EtOH+DMSO":
                    pass
                #if DEX condition, use DEX control
                elif "+TGA1:GR_10uM_DEX+DMSO" in TFs[x]:
                    box_pairs.append(('+TGA1:GR_EtOH+DMSO',TFs[x]))
                elif "No TF_10uM_DEX+DMSO" in TFs[x]:
                    box_pairs.append(('No TF_EtOH+DMSO',TFs[x]))
                elif "+TGA1:GR_overnight_10uM_DEX+DMSO" in TFs[x]:
                    box_pairs.append(('+TGA1:GR_overnight_EtOH+DMSO',TFs[x]))
                elif "No TF_overnight_10uM_DEX+DMSO" in TFs[x]:
                    box_pairs.append(('No TF_overnight_EtOH+DMSO',TFs[x]))
           
            #make box pairs dict with box pair and p value
            box_pairs_all_pvalues = {}
            #make dict containing the TF and p value compared to its control (either No TF with auxin or no auxin No TF)
            TFs_pvalues = {}
            for pair in box_pairs:
                #create series objects
                TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
                TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']

            #equal variance = false so do Welch's T-test
                results = stats.ttest_ind(TF1, TF2, equal_var=False)
                #append pvalue to dict
                box_pairs_all_pvalues[pair] = results.pvalue
                TFs_pvalues[pair[1]] = results.pvalue

            # #filter dict by significance and put in a new dictionary
            box_pairs_significant = {}
            for k,v in box_pairs_all_pvalues.items():
                if v <0.05:
                    box_pairs_significant[k] = v

            def convert_pvalue_to_asterisks(pvalue):
                if pvalue <= 0.001:
                    return "***"
                elif pvalue <= 0.01:
                    return "**"
                elif pvalue <= 0.05:
                    return "*"
                return "ns"

        if len(TFs) == 2:
            pass
            
        elif len(TFs) < 2:
            pass
        else:
            print(prom)
            print(TFs)
            if prom == 'NIR1':
                plt.figure(figsize=(length_tf,12))

            else:
                plt.figure(figsize=(length_tf*0.8,6))

            fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, errcolor="black", edgecolor="black",ci=68,   errwidth=1,capsize=0.4,dodge=True, color='lightgrey')#facecolor=(1,1,1,1)
            change_width(fig, bar_width)
            sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df, order=order,color='black',dodge=True)

            annotator = Annotator(fig, box_pairs_significant, data=df, x='TF_added', y='corrected_luminescence',order=order)
            annotator.configure(test='t-test_welch', text_format='star',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]])#loc='inside'
            # annotator.apply_and_annotate()
            ax, test_results = annotator.apply_and_annotate()
            #get means of TF_added corrected_luminescence
            means = df.groupby(['TF_added'])['corrected_luminescence'].mean()
            #turn into df
            means_df = pd.DataFrame(means)
            #reset index
            means_df.reset_index(inplace=True)
            # print(means_df)
            # for pair in box_pairs_significant:
           


            with open(f'../../../../data/plots/luminescence/{date}/compare_DEX/stats.txt', 'a') as f:                            
                for res in test_results:
                     #get TF and No TF means
                    group1=res.data.group1
                    group2=res.data.group2
                    group1_mean1 = means_df[means_df.TF_added == group1]['corrected_luminescence'].values[0]
                    group2_mean2 = means_df[means_df.TF_added == group2]['corrected_luminescence'].values[0]
                    #get standard deviation
                    std = df.groupby(['TF_added'])['corrected_luminescence'].std()
                    #turn into df
                    std_df = pd.DataFrame(std)
                    #reset index
                    std_df.reset_index(inplace=True)
                    #get tf and no tf standard deviation
                    std1 = std_df[std_df.TF_added == group1]['corrected_luminescence'].values[0]
                    std2 = std_df[std_df.TF_added == group2]['corrected_luminescence'].values[0]
                    # print(res.pvalue)pvalue
                    print(vars(res.data))
                    # print(f'group1={res.data.group1}')
                    # print(f'group2={res.data.group2}')
                    f.write(f'{str(prom)},{group1},{group2},{str(res.data)},t={res.data.stat_value}, P={res.data.pvalue}\nmean of {group1} = {group1_mean1}\nmean of {group2} = {group2_mean2}\nstd of {group1} = {std1}\nstd of {group2} = {std2}\n\n')
    # change axes labels
            # f'../../../../data/plots/luminescence/{date}/compare_DEX/scatter{prom}_DEX_plate1.pdf'
                
                #fig = px.violin(df, x='TF_added',
            #                         y='corrected_luminescence', box=True,                       
            #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                # stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # # label box pairs        
                # #box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]
                # # make empty list of p_values
                # p_values = []
                # # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                # #    print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
            #add stats
            #print(box_pairs)
            #if no significant values, don't add stats annotation

            


            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     pass
                # #add a gap between no auxin and auxin conditions
                # #first identify No TF_1μM_NAA X position
                # middle = order.index("No TF_1μM_NAA")
                # #then modify x locations with a gap before the auxin no tf position

                # x_locations = list(range(0,middle))+list(range(middle+1,len(order)+1))
                # print(x_locations)
                # plt.xticks(x_locations,order)
                
                #plt.bar_label(box_pairs_all_pvalues.values())
                #get x length
                # xlength=len(fig.patches)
                # #print(f'xlength={xlength}')
                # #add patterned hatching to the bars length_tf
                # #hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                # #also add asterisks for p values
                # #make empty variable to show when No TF_1μM_NAA has been iterated over
                # auxin_control_picked = False
                # for x in range (0, (xlength)):
                #     current_TF = order[x]
                #     if current_TF == "No TF" or current_TF == '':                
                #         pass
                #     elif current_TF == "No TF_1μM_NAA":
                #         auxin_control_picked = True                    
                #     # hatch = next(hatches)
                #         fig.patches[x].set_facecolor('grey')
                #     else:
                #         pvalue = TFs_pvalues[current_TF]

                        
                #     # pvalue = list(box_pairs_all_pvalues.values())[x]
                #         #key=list(box_pairs_all_pvalues.keys())[x][1]
                #         p = fig.patches[x]
                #         fig.annotate(convert_pvalue_to_asterisks(pvalue),
                #         (p.get_x() + p.get_width() / 2., p.get_height()),
                #         ha = 'center', va = 'center',
                #         size=fontsize,
                #         xytext = (0, 10), 
                #         textcoords = 'offset points')
                #         #add patterned hatching to the bars length_tf
                #         if auxin_control_picked == True:
                            
                #             p.set_facecolor('grey')
                
                # hatches = itertools.cycle(['/','//','+','\\','*','o','O','.'])
                # for i, bar in enumerate(fig.patches):
                #     print(f'i={i},bar={bar}')
                #     if i % length_tf == 0:
                #         hatch = next(hatches)
                #     bar.set_hatch(hatch)
                # y_position = df['corrected_luminescence'].max()
                # for k, v in box_pairs_all_pvalues.items():
                #     plt.text(x=k[1], y=y_position, s=convert_pvalue_to_asterisks(v))
                # #annotator = Annotator(fig, pairs=list(box_pairs), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                # annotator = Annotator(fig, pairs=list(box_pairs_significant.keys()), data=df, x='TF_added', y='corrected_luminescence',order=order,)
                #annotator.set_pvalues(list(box_pairs))
            #annotator.set_pvalues(list(box_pairs_significant.values()))
                #annotator.configure(test='Mann-Whitney',verbose=2,text_format='star', loc='inside',)#loc='inside'
                #annotator.apply_and_annotate()
            #annotator.annotate()


            #     #if no significant values, don't add stats annotation
            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     add_stat_annotation(
            #         fig,
            #         data=df,
            #         x='TF_added',
            #         y='corrected_luminescence',
            #         order=order,
            #         box_pairs=list(box_pairs_significant.keys()),
            #         text_format="star",
            #         loc="outside",
            #         verbose=2,
            #         perform_stat_test=False,
            #         pvalues=list(box_pairs_significant.values()),
            #         #test_short_name="Dunn",
            #     )
            #         #change name of promoters

        #add custom legend
        # handles = []
        # labels = []
        # no_auxin = mpatches.Patch(facecolor='lightgrey', hatch='',edgecolor='black',linewidth=2)
        # auxin = mpatches.Patch(facecolor='grey', hatch='',edgecolor='black',linewidth=2)
        # no_auxin_label = "No NAA"
        # auxin_label = "1 µM NAA"
        # handles.append(no_auxin)
        # handles.append(auxin)
        # labels.append(no_auxin_label)
        # labels.append(auxin_label)
        # fig.legend(handles=handles,labels=labels,ncol=1,bbox_to_anchor=(0.1,0.85), loc='lower left',fontsize=fontsize*0.7)
        
        # new_labels = []        
        # for TF in order:
        #     if '_1μM_NAA' in TF:
        #         TFs_orig_renamed = TF[:len(TF)-8]
        #         new_labels.append(TFs_orig_renamed)
        #     else:
        #         new_labels.append(TF)
                
        #fig.set_xticklabels(new_labels)
        # change axes labels
        plt.ylabel('Normalised expression (a.u.)')
        #add title
        plt.title(prom, y=1,size=fontsize)
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/compare_DEX/scatter{prom}_DEX_plate1.pdf',
            format="pdf",
            bbox_inches="tight",transparent=True)

        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/compare_DEX/scatter{prom}_DEX_plate1.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# ANAC032
# ['+TGA1:GR_10uM_DEX+DMSO', '+TGA1:GR_EtOH+DMSO', 'No TF_10uM_DEX+DMSO', 'No TF_EtOH+DMSO']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: p <= 1.00e-03
#
# +TGA1:GR_10uM_DEX+DMSO vs. +TGA1:GR_EtOH+DMSO: Welch's t-test independent samples, P_val:1.760e-02 t=4.502e+00
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/Annotator.py:550: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.draw()
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:328: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:333: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 4.5018754724331185, 'pvalue': 0.017601617913448202, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': '+TGA1:GR_10uM_DEX+DMSO', 'group2': '+TGA1:GR_EtOH+DMSO'}
# ANAC032_ablated_TGA1_all_sites
# ['+TGA1:GR_10uM_DEX+DMSO', '+TGA1:GR_EtOH+DMSO', 'No TF_10uM_DEX+DMSO', 'No TF_EtOH+DMSO']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: p <= 1.00e-03
#
# +TGA1:GR_10uM_DEX+DMSO vs. +TGA1:GR_EtOH+DMSO: Welch's t-test independent samples, P_val:4.208e-04 t=1.951e+01
# No TF_10uM_DEX+DMSO vs. No TF_EtOH+DMSO: Welch's t-test independent samples, P_val:1.030e-02 t=6.723e+00
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/Annotator.py:550: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.draw()
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:328: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:333: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 19.505657099085894, 'pvalue': 0.00042078389442013397, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': '+TGA1:GR_10uM_DEX+DMSO', 'group2': '+TGA1:GR_EtOH+DMSO'}
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 6.72335015784555, 'pvalue': 0.010301129126801109, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': 'No TF_10uM_DEX+DMSO', 'group2': 'No TF_EtOH+DMSO'}
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# ARF18
# ['+TGA1:GR_10uM_DEX+DMSO', '+TGA1:GR_EtOH+DMSO', 'No TF_10uM_DEX+DMSO', 'No TF_EtOH+DMSO']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: p <= 1.00e-03
#
# +TGA1:GR_10uM_DEX+DMSO vs. +TGA1:GR_EtOH+DMSO: Welch's t-test independent samples, P_val:2.544e-04 t=-2.564e+01
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/Annotator.py:550: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.draw()
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:328: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:333: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# No TF_10uM_DEX+DMSO vs. No TF_EtOH+DMSO: Welch's t-test independent samples, P_val:5.999e-03 t=5.325e+00
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': -25.638072341105048, 'pvalue': 0.00025439329499780207, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': '+TGA1:GR_10uM_DEX+DMSO', 'group2': '+TGA1:GR_EtOH+DMSO'}
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 5.324972640083559, 'pvalue': 0.005999173535926384, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': 'No TF_10uM_DEX+DMSO', 'group2': 'No TF_EtOH+DMSO'}
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# NIR1
# ['+TGA1:GR_10uM_DEX+DMSO', '+TGA1:GR_EtOH+DMSO', 'No TF_10uM_DEX+DMSO', 'No TF_EtOH+DMSO', '+TGA1:GR_overnight_10uM_DEX+DMSO', '+TGA1:GR_overnight_EtOH+DMSO', 'No TF_overnight_10uM_DEX+DMSO', 'No TF_overnight_EtOH+DMSO']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: p <= 1.00e-03
#
# +TGA1:GR_10uM_DEX+DMSO vs. +TGA1:GR_EtOH+DMSO: Welch's t-test independent samples, P_val:3.762e-04 t=1.884e+01
# No TF_10uM_DEX+DMSO vs. No TF_EtOH+DMSO: Welch's t-test independent samples, P_val:1.950e-03 t=1.104e+01
# +TGA1:GR_overnight_10uM_DEX+DMSO vs. +TGA1:GR_overnight_EtOH+DMSO: Welch's t-test independent samples, P_val:5.750e-05 t=8.995e+01
# No TF_overnight_10uM_DEX+DMSO vs. No TF_overnight_EtOH+DMSO: Welch's t-test independent samples, P_val:1.676e-03 t=7.689e+00
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 18.843537158641425, 'pvalue': 0.0003761829878006063, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': '+TGA1:GR_10uM_DEX+DMSO', 'group2': '+TGA1:GR_EtOH+DMSO'}
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 11.040486601763781, 'pvalue': 0.00194968837302933, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': 'No TF_10uM_DEX+DMSO', 'group2': 'No TF_EtOH+DMSO'}
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 89.95263445657764, 'pvalue': 5.749999329957688e-05, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': '+TGA1:GR_overnight_10uM_DEX+DMSO', 'group2': '+TGA1:GR_overnight_EtOH+DMSO'}
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 7.689327606396711, 'pvalue': 0.0016755589119537239, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': 'No TF_overnight_10uM_DEX+DMSO', 'group2': 'No TF_overnight_EtOH+DMSO'}
# NLP7
# ['+TGA1:GR_10uM_DEX+DMSO', '+TGA1:GR_EtOH+DMSO', 'No TF_10uM_DEX+DMSO', 'No TF_EtOH+DMSO']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: p <= 1.00e-03
#
# +TGA1:GR_10uM_DEX+DMSO vs. +TGA1:GR_EtOH+DMSO: Welch's t-test independent samples, P_val:2.170e-03 t=-8.286e+00
# No TF_10uM_DEX+DMSO vs. No TF_EtOH+DMSO: Welch's t-test independent samples, P_val:3.882e-02 t=3.114e+00
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/Annotator.py:550: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.draw()
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:328: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:333: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': -8.286133684488977, 'pvalue': 0.0021702145739344162, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': '+TGA1:GR_10uM_DEX+DMSO', 'group2': '+TGA1:GR_EtOH+DMSO'}
# {'test_description': "Welch's t-test independent samples", 'test_short_name': 't-test_welch', 'stat_str': 't', 'stat_value': 3.113841073700503, 'pvalue': 0.038816316827970626, '_corrected_significance': None, '_correction_method': None, 'alpha': 0.05, 'group1': 'No TF_10uM_DEX+DMSO', 'group2': 'No TF_EtOH+DMSO'}
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/ipykernel_launcher.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#ARF plots compare NAA
#make ARF plots
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
#set white bar colour
#sns.set_style('ticks')
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
fontsize = 18.4
rcParams['font.size'] = fontsize
#for getting the microsoft font Arial working, please follow this guide: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
#allow font to be edited later in pdf editor
rcParams ['pdf.fonttype'] = 42
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
#define bar width
bar_width = 0.4
#set width of bars
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        # we change the bar width
        patch.set_width(new_value)
        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'NOS' or prom == 'minimal_STAP4' or prom == 'ARF18' or prom == 'ANR1' or prom == 'ANAC032' or prom =='NIR1' or prom == 'NLP6' or prom == '35s:NLUC:YFP' or prom == 'NRP:NLUC:YFP' or prom == '35s:NLUC:YFP_nomarker' or prom == '4x[bZIP3-random]:NLUC:YFP':
        pass
    #if 35s calibrator in promoter name, skip promoter
    elif "_35s:LucF_calibrator" in prom:
        pass
    else:        
          
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        #"+ARF9+IAA33", "+ARF18+IAA33", "+ARF18+ARF9+IAA33"
        TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33']
        #new_TF_order = ['No TF','+ARF9','+ARF18','+ARF18+ARF9','+ARF9+IAA33','+ARF18+IAA33','+ARF18+ARF9+IAA33','No TF_1μM_NAA','+ARF9_1μM_NAA','+ARF18_1μM_NAA','+ARF18+ARF9_1μM_NAA','+ARF9+IAA33_1μM_NAA','+ARF18+IAA33_1μM_NAA','+ARF18+ARF9+IAA33_1μM_NAA']
        #'No TF/YFP','+No TF/YFP_1μM_NAA',
        #sort based on custom order
        # TFs_notrenamed = []
        # for i in range(len(TF_order)):
        #     if TF_order[i] in TFs_orig:
        #         TFs_notrenamed+=[TF_order[i]]
        #rename x values
        #TFs_orig = df.TF_added.unique()
       
        #Change TF names to +TF
        df_renamed = df.copy()
        for TF in TFs_orig:
            if '_1μM_NAA' in TF:
                TFs_orig_renamed = TF[:len(TF)-8]
                df_renamed.TF_added.replace(TF,TFs_orig_renamed, inplace=True)

        TFs_renamed =  df_renamed.TF_added.unique()
        print(f'TFs_orig_renamed={TFs_renamed}prom={prom}')

        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_renamed:
                TFs+=[TF_order[i]]
        
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        if length_tf <=2:
            pass
        else:

            #create order and box pairs based on the length of TFs
            order = []
            box_pairs = []   
            for x in range (0, (length_tf)):
                
                order.append(TFs[x])
                box_pairs.append([(TFs[x],'1uM_auxin'),(TFs[x],'nitrogen')])
            print(box_pairs)
            

            #do the same again for the TFs with auxin before they were renamed
            
            # box_pairs_not_renamed = []
            # for TF in TFs_renamed:
            #     box_pairs_not_renamed.append((TF,f'{TF}_1μM_NAA'))
        
            
            #add every combination of box pairs of length 2
            #box_pairs=list(combinations(order, 2))~
            #make box pairs dict with box pair and p value
        # box_pairs_all_pvalues = {}
            #make dict containing the TF and p value compared to its control (either No TF with auxin or no auxin No TF)
            # TFs_pvalues = {}
            # for pair in box_pairs_not_renamed:
            #     #create series objects
            #     TF1 = df_renamed.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
            #     TF2 = df_renamed.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
            # # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
            # # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
            # #equal variance = false so do Welch's T-test
            #     results = stats.ttest_ind(TF1, TF2, equal_var=False)
            #     #append pvalue to dict
            #     box_pairs_all_pvalues[pair] = results.pvalue
            #     #TFs_pvalues[pair[1]] = results.pvalue
            # # box_pairs_significant.append(pair)
            # p_values.append(results.pvalue)
            #print(f'all pvalues={box_pairs_all_pvalues}')

            # #filter dict by significance and put in a new dictionary
            # box_pairs_significant = {}
            # for k,v in box_pairs_all_pvalues.items():
            #     if v <0.05:
            #         box_pairs_significant[k] = v

            # def convert_pvalue_to_asterisks(pvalue):
            #     if pvalue <= 0.001:
            #         return "***"
            #     elif pvalue <= 0.01:
            #         return "**"
            #     elif pvalue <= 0.05:
            #         return "*"
            #     return "ns"
            #print(df.columns)
            #'well', 'content', 'fluc_luminescence', 'nluc_luminescence', 'well_row',
        #    'well_col', 'name', 'condition', 'nluc/fluc', 'date', 'Promoter',
        #    'TF_added', 'Well_calibrator', 'Plate_number',
        #    'corrected_luminescence'
            #add a blank data point in between non-auxin and auxin conditions

            #new_df = pd.concat([df[df.condition == 'nitrogen'], pd.DataFrame({'well':[''],'content':[''],'fluc_luminescence':[0],'nluc_luminescence':[0], 'well_row':[''],'well_col':[0], 'name':[''], 'condition':['nitrogen'], 'nluc/fluc':[0], 'date':[''], 'Promoter':[prom],'TF_added':[''], 'Well_calibrator':[''], 'Plate_number':[0],'corrected_luminescence':[0]}, df[df.condition == '1uM_auxin'])])

        
            
            # if len(TFs) is 3:
            #     order = [TFs[0],TFs[1],TFs[2]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[1],TFs[2])]
            # elif len(TFs) is 4:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]),(TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]  
            # elif len(TFs) is 5:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[3],TFs[4])]
            # elif len(TFs) is 6:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[4],TFs[5])]
            # elif len(TFs) is 7:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[5],TFs[6])]
            # elif len(TFs) is 8:
            #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6],TFs[7]]
            #     # label box pairs
            #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]),(TFs[0],TFs[7]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[1],TFs[7]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[2],TFs[7]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[3],TFs[7]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[4],TFs[7]),(TFs[5],TFs[6]),(TFs[5],TFs[7]),(TFs[6],TFs[7])]
                


            if len(TFs) == 2:
                #plt.figure()
                plt.figure(figsize=((length_tf-(length_tf//2)),7))
                #order_new = [TFs[0],TFs[1]]
                
                fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df_renamed, hue='condition',hue_order=['nitrogen','1uM_auxin'], order=order, linewidth=2, errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4, dodge=True,palette=['lightgrey','grey'])#facecolor=(1,1,1,1)
                
                # #add patterned hatching to the bars length_tf
                # hatches = itertools.cycle(['','/','//','+','\\','*','o','O','.'])
                # for i, bar in enumerate(fig.patches):
                #     if i % length_tf == 0:
                #         hatch = next(hatches)
                #     bar.set_hatch(hatch)
                
                #get handles and labels
                handles = fig.legend_.legendHandles
                labels = [text.get_text() for text in fig.legend_.texts]
                sns.swarmplot(x='TF_added', y='corrected_luminescence',data=df_renamed,hue='condition',hue_order=['nitrogen','1uM_auxin'],color='black', order=order,dodge=True)#,
                #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, color=".25", order=order_new)
                change_width(fig, bar_width)

                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                #stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # label box pairs        
                #box_pairs = [(TFs[0],TFs[1])]
                
                # make empty list of p_values
            # p_values = []
                # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                #     print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
                # add_stat_annotation(
                #     fig,
                #     data=df,
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     order=order_new,
                #     box_pairs=list(box_pairs_significant.keys()),
                #     text_format="star",
                #     loc="outside",
                #     verbose=2,
                #     perform_stat_test=False,
                #     pvalues=list(box_pairs_significant.values()),
                #     #test='Mann-Whitney',
                # )
                # # change axes labels
                # plt.ylabel('Normalised expression (a.u.)')
                # #add title
                # plt.title(prom)
                # #make xticks diagonal
                # plt.xticks(rotation=45, ha='right')
                # #plt.xlabel(x_label)
                # # tight layout
                # plt.tight_layout()
                # # save figure
                # plt.savefig(
                #     f'../../../../data/plots/luminescence/{date}/scatter{prom}_plate1.pdf',
                #     format="pdf",
                #     bbox_inches="tight",
            # )
            elif len(TFs) < 2:
                pass
            else:
                print(prom)
                print(TFs)
                plt.figure(figsize=((length_tf//2)+2,7))
                # fig = sns.catplot(
                #     x='TF_added',
                #     y='corrected_luminescence',
                #     data=df,
                #     kind='violin',
                #     order=order,            
                #     cut=0,
                #     legend=False,
                #     #color=new_color
                # )
                fig = sns.barplot(x='TF_added', y='corrected_luminescence',hue='condition',hue_order=['nitrogen','1uM_auxin'], data=df_renamed, order=order, linewidth=2,  errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,dodge=True,palette=['lightgrey','grey'])#,facecolor=(1,1,1,1)
                
                # #add patterned hatching to the bars length_tf
                # hatches = itertools.cycle(['','/','//','+','\\','*','o','O','.'])
                # for i, bar in enumerate(fig.patches):
                #     if i % length_tf == 0:
                #         hatch = next(hatches)
                #     bar.set_hatch(hatch)
                
                # #get handles and labels
                # handles = fig.legend_.legendHandles
                # labels = [text.get_text() for text in fig.legend_.texts]
                sns.swarmplot(x='TF_added', y='corrected_luminescence',hue='condition',hue_order=['nitrogen','1uM_auxin'],data=df_renamed,color='black', order=order,dodge=True,)#,
                change_width(fig, bar_width)
                #fig = px.violin(df, x='TF_added',
                #                         y='corrected_luminescence', box=True,                       
                #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

                #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
                #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
                #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
                #hide legend
                #fig.layout.update(showlegend=False)
                # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
                # stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
                # # label box pairs        
                # #box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]
                # # make empty list of p_values
                # p_values = []
                # # populate the list of p_values according to the box_pairs
                # for pair in box_pairs:
                # #    print(pair)
                #     # select p value for each pair
                #     p = stat.loc[pair[0], pair[1]]
                #     p_values.append(p)

                # add stats annotation to the plot
            #add stats
            #print(box_pairs)
            #if no significant values, don't add stats annotation

            


            # if len(box_pairs_significant.values()) < 1:
            #     pass
            # else:
            #     pass
            #     # #add a gap between no auxin and auxin conditions
            #     # #first identify No TF_1μM_NAA X position
            #     # middle = order.index("No TF_1μM_NAA")
            #     # #then modify x locations with a gap before the auxin no tf position

                # x_locations = list(range(0,middle))+list(range(middle+1,len(order)+1))
                # print(x_locations)
                # plt.xticks(x_locations,order)
                
                #plt.bar_label(box_pairs_all_pvalues.values())
                #get x length
                # xlength=len(fig.patches)
                # print(f'xlength={xlength}')
                # print(box_pairs_all_pvalues)
                # for x in range (0, (xlength)):
                #     current_TF = order[x]    

                #     pvalue = TFs_pvalues[current_TF]                   
                #     # pvalue = list(box_pairs_all_pvalues.values())[x]
                #         #key=list(box_pairs_all_pvalues.keys())[x][1]
                #     p = fig.patches[x]
                #     fig.annotate(convert_pvalue_to_asterisks(pvalue),
                #     (p.get_x() + p.get_width() / 2., p.get_height()),
                #     ha = 'center', va = 'center',
                #     size=15,
                #     xytext = (0, 10), 
                #     textcoords = 'offset points')
                
                # y_position = df['corrected_luminescence'].max()
                # for k, v in box_pairs_all_pvalues.items():
                #     plt.text(x=k[1], y=y_position, s=convert_pvalue_to_asterisks(v))
        annotator = Annotator(fig, pairs=list(box_pairs), data=df_renamed, x='TF_added', y='corrected_luminescence',order=order,hue='condition')
        #annotator = Annotator(fig, pairs=list(box_pairs_significant.keys()), data=df, x='TF_added', y='corrected_luminescence',order=orderhue='condition')
        #annotator.set_pvalues(list(box_pairs),data=df, x='TF_added', y='corrected_luminescence',order=order,hue='condition')
        #annotator.set_pvalues(list(box_pairs_significant.values()))
        #annotator.configure(test='Mann-Whitney',verbose=2,text_format='star', loc='inside',).apply_and_annotate()#loc='inside'
        annotator.configure(test='t-test_welch',verbose=2,text_format='star', loc='inside',pvalue_thresholds=[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]]).apply_and_annotate()

            #annotator.annotate()


            #if no significant values, don't add stats annotation
        # if len(box_pairs_significant.values()) < 1:
        #     pass
        # else:
        #     add_stat_annotation(
        #         fig,
        #         data=df,
        #         x='TF_added',
        #         y='corrected_luminescence',
        #         order=order,
        #         box_pairs=list(box_pairs_significant.keys()),
        #         text_format="star",
        #         loc="outside",
        #         verbose=2,
        #         perform_stat_test=False,
        #         pvalues=list(box_pairs_significant.values()),
        #         #test_short_name="Dunn",
        #     )
        
        #plot legend, excluding legend from swarm plot
        h,l = fig.get_legend_handles_labels()
        #change name of label
        l[3] = "1 µM NAA"
        #l[2] = "20 mM KNO\u2083 + 20 mM NH\u2083NO\u2083"   
        l[2] = "No NAA"     
        plt.legend(h[2:4],l[2:4],bbox_to_anchor=(0.3,0.9), loc='best',fontsize=14)
        # #get legend location
        # p = legend_obj.get_window_extent()
        # #transform coordinates
        # output_coords = fig.transLimits.transform((0,p.y1))
        # print(output_coords)
        # new_y_coord=output_coords[0]
        # print(new_y_coord)
        #print(f'legendloc={p.p1[1]}')
        #plt.legend()
        # change axes labels
        plt.ylabel('Normalised expression (a.u.)')
        #add title above legend
        plt.title(prom, y=1.1,size=fontsize)
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/compare_auxin/scatter{prom}_ARFs_NAAcompare_plate1.pdf',
            format="pdf",
            bbox_inches="tight",transparent=True)
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/compare_auxin/scatter{prom}_ARFs_NAAcompare_plate1.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# TFs_orig_renamed=['No TF' '+ARF9+IAA33' '+ARF18+IAA33' '+ARF18+ARF9+IAA33']prom=ANAC032_ablated_ARFs
# [[('No TF', '1uM_auxin'), ('No TF', 'nitrogen')], [('+ARF9+IAA33', '1uM_auxin'), ('+ARF9+IAA33', 'nitrogen')], [('+ARF18+IAA33', '1uM_auxin'), ('+ARF18+IAA33', 'nitrogen')], [('+ARF18+ARF9+IAA33', '1uM_auxin'), ('+ARF18+ARF9+IAA33', 'nitrogen')]]
# ANAC032_ablated_ARFs
# ['No TF', '+ARF9+IAA33', '+ARF18+IAA33', '+ARF18+ARF9+IAA33']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: p <= 1.00e-03
#
# +ARF9+IAA33_1uM_auxin vs. +ARF9+IAA33_nitrogen: Welch's t-test independent samples, P_val:7.545e-04 t=1.526e+01
# No TF_1uM_auxin vs. No TF_nitrogen: Welch's t-test independent samples, P_val:2.444e-03 t=1.187e+01
# +ARF18+IAA33_1uM_auxin vs. +ARF18+IAA33_nitrogen: Welch's t-test independent samples, P_val:4.363e-03 t=6.017e+00
# +ARF18+ARF9+IAA33_1uM_auxin vs. +ARF18+ARF9+IAA33_nitrogen: Welch's t-test independent samples, P_val:2.827e-04 t=1.194e+01
# TFs_orig_renamed=['No TF_EtOH+DMSO' 'No TF_35uM_CHX+EtOH' 'No TF_10uM_DEX+DMSO'
#  'No TF_10uM_DEX+35uM_CHX' '+TGA1:GR_EtOH+DMSO' '+TGA1:GR_35uM_CHX+EtOH'
#  '+TGA1:GR_10uM_DEX+DMSO' '+TGA1:GR_10uM_DEX+35uM_CHX']prom=ANAC032_ablated_TGA1_all_sites
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-450-d018c0e948a3> in <module>
#     362                 # for k, v in box_pairs_all_pvalues.items():
#     363                 #     plt.text(x=k[1], y=y_position, s=convert_pvalue_to_asterisks(v))
# --> 364         annotator = Annotator(fig, pairs=list(box_pairs), data=df_renamed, x='TF_added', y='corrected_luminescence',order=order,hue='condition')
#     365         #annotator = Annotator(fig, pairs=list(box_pairs_significant.keys()), data=df, x='TF_added', y='corrected_luminescence',order=orderhue='condition')
#     366         #annotator.set_pvalues(list(box_pairs),data=df, x='TF_added', y='corrected_luminescence',order=order,hue='condition')
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/Annotator.py in __init__(self, ax, pairs, plot, data, x, y, hue, order, hue_order, engine, verbose, **plot_params)
#     106             self._plotter = self._get_plotter(engine, ax, pairs, plot, data,
#     107                                               x, y, hue, order, hue_order,
# --> 108                                               verbose=verbose, **plot_params)
#     109
#     110         self._test = None
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/Annotator.py in _get_plotter(engine, *args, **kwargs)
#     772         if engine_plotter is None:
#     773             raise NotImplementedError(f"{engine} engine not implemented.")
# --> 774         return engine_plotter(*args, **kwargs)
#     775
#     776     def _get_xy_params_horizontal(self, group_coord_1, group_coord_2,
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/_Plotter.py in __init__(self, ax, pairs, plot, data, x, y, hue, order, hue_order, verbose, **plot_params)
#      81
#      82         _Plotter.__init__(self, ax, pairs, data, x, y, hue, order, hue_order,
# ---> 83                           verbose, **plot_params)
#      84
#      85         self.check_plot_is_implemented(plot)
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/_Plotter.py in __init__(self, ax, pairs, data, x, y, hue, order, hue_order, verbose, **plot_params)
#      25         check_not_none("pairs", pairs)
#      26         group_coord = y if plot_params.get("orient") == "h" else x
# ---> 27         check_order_in_data(data, group_coord, order)
#      28         check_pairs_in_data(pairs, data, group_coord, hue, hue_order)
#      29         self.pairs = pairs
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/statannotations/utils.py in check_order_in_data(data, x, order)
#      61
#      62     if unmatched_in_order:
# ---> 63         raise ValueError(f"Missing x value(s) "
#      64                          f"`{render_collection(unmatched_in_order)}` in {x} "
#      65                          f"(specified in `order`)")
#
# ValueError: Missing x value(s) `"+ARF9+IAA33", "+ARF18+IAA33", "No TF", "+ARF18+ARF9+IAA33"` in TF_added (specified in `order`)

# %%
#layout = go.Layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)' )
#make graphs for each promoter
#color_discrete_map = {'red': 'red', 'blue': 'blue', 'orange': 'orange', 'purple':'purple','green':'green','yellow':'yellow','brown':'brown','black':'black'}
#plots for promoters with more than 2 Tf categories
#prom == 'minimal_STAP4'
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
rcParams['font.size'] = 16
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'minimal_STAP4':
        pass
    elif prom == 'ARF18':
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        if prom == 'ARF18':
            TF_order = ['No TF/YFP','+No TF/YFP_1μM_NAA','No TF','No TF_1μM_NAA','+ANAC032','+ANR1','+ARF18','+ARF18_1μM_NAA','+ARF18+IAA33','+ARF18+IAA33_1μM_NAA','+ARF9','+ARF9_1μM_NAA','+ARF9+IAA33','+ARF9+IAA33_1μM_NAA','+ARF18+ARF9','+ARF18+ARF9_1μM_NAA','+ARF18+ARF9+IAA33','+ARF18+ARF9+IAA33_1μM_NAA','+dCas9_activator1','+dCas9_activator2','+dCas9_activator3','+dCpf1_repressor1','+dCpf1_repressor2','+dCpf1_repressor3','+bZIP3','+DREB26','+HHO2','+NLP6','+NLP7','+TGA1','+NLP7+bZIP3','+NLP7+TGA1','+UBQ10_dCas9_activator+guide1', '+UBQ10_dCas9_activator_123guides', '+guide1+UBQ10_dCas9_repressor_guide3+guide2','+UBQ10_dCpf1_repressor1','+UBQ10_dCpf1_repressor2', '+UBQ10_dCpf1_repressor3',  '+UBQ10_dCpf1_repressor123guides','+TAD-Suntag_noguide','+TAD-Suntag_guide1','+TAD-Suntag_guides1,2,3','+VP64-Suntag_noguide','+VP64-Suntag_guide1','+VP64-Suntag_guides1,2,3','+SRDX-dCpf1_noguide','+SRDX-dCpf1_guide1','+SRDX-dCpf1_guide2','+SRDX-dCpf1_guide3','+SRDX-dCpf1_guides1,2,3','+SRDX-dCpf1_guides1,2,4','+SRDX-Suntag_noguide','+SRDX-Suntag_123guides1,2,3']
           
        else:
            TF_order = ['No TF/YFP','+No TF/YFP_1μM_NAA','No TF','No TF_1μM_NAA','+ANAC032','+ANR1','+ARF18','+ARF18_1μM_NAA','+ARF18+IAA33','+ARF18+IAA33_1μM_NAA','+ARF9','+ARF9_1μM_NAA','+ARF9+IAA33','+ARF9+IAA33_1μM_NAA','+ARF18+ARF9','+ARF18+ARF9_1μM_NAA','+ARF18+ARF9+IAA33','+ARF18+ARF9+IAA33_1μM_NAA','+dCas9_activator1','+dCas9_activator2','+dCas9_activator3','+dCpf1_repressor1','+dCpf1_repressor2','+dCpf1_repressor3','+bZIP3','+DREB26','+HHO2','+NLP6','+NLP7','+TGA1','+NLP7+bZIP3','+NLP7+TGA1','No TF nor YFP',  '+guide1+UBQ10_dCas9_repressor_guide3+guide2', '+UBQ10_dCpf1_repressor3', '+UBQ10_dCpf1_repressor2', '+UBQ10_dCpf1_repressor123guides', '+UBQ10_dCas9_activator_123guides','+UBQ10_dCas9_activator+guide1','+UBQ10_dCpf1_repressor1']



        
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        #create order and box pairs based on the length of TFs
        order = []
        box_pairs = [] 
        for x in range (0, (length_tf)):
            order.append(TFs[x])
            # if TFs[x] == "No TF":
            #     pass
            # else:
            #     box_pairs.append(('No TF',TFs[x]))
        box_pairs.append(('No TF',TFs[x]))
        #add every combination of box pairs of length 2
        #box_pairs=list(combinations(order, 2))~
        box_pairs_all_pvalues = {}
        for pair in box_pairs:
            #create series objects
            TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
            TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
        # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
        # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
        #equal variance = false so do Welch's T-test
            results = stats.ttest_ind(TF1, TF2, equal_var=False)
            #append pvalue to dict
            box_pairs_all_pvalues[pair] = results.pvalue
        # box_pairs_significant.append(pair)
        # p_values.append(results.pvalue)
        print(f'all pvalues={box_pairs_all_pvalues}')

        # #filter dict by significance and put in a new dictionary
        box_pairs_significant = {}
        for k,v in box_pairs_all_pvalues.items():
            if v <0.05:
                box_pairs_significant[k] = v
                

        
        # if len(TFs) is 3:
        #     order = [TFs[0],TFs[1],TFs[2]]
        #     # label box pairs
        #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[1],TFs[2])]
        # elif len(TFs) is 4:
        #     order = [TFs[0],TFs[1],TFs[2],TFs[3]]
        #     # label box pairs
        #     box_pairs = [(TFs[0],TFs[1]),(TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]  
        # elif len(TFs) is 5:
        #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4]]
        #     # label box pairs
        #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[3],TFs[4])]
        # elif len(TFs) is 6:
        #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5]]
        #     # label box pairs
        #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[4],TFs[5])]
        # elif len(TFs) is 7:
        #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6]]
        #     # label box pairs
        #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[5],TFs[6])]
        # elif len(TFs) is 8:
        #     order = [TFs[0],TFs[1],TFs[2],TFs[3],TFs[4],TFs[5],TFs[6],TFs[7]]
        #     # label box pairs
        #     box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]),(TFs[0],TFs[4]),(TFs[0],TFs[5]),(TFs[0],TFs[6]),(TFs[0],TFs[7]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[1],TFs[4]),(TFs[1],TFs[5]),(TFs[1],TFs[6]),(TFs[1],TFs[7]),(TFs[2],TFs[3]),(TFs[2],TFs[4]),(TFs[2],TFs[5]),(TFs[2],TFs[6]),(TFs[2],TFs[7]),(TFs[3],TFs[4]),(TFs[3],TFs[5]), (TFs[3],TFs[6]),(TFs[3],TFs[7]),(TFs[4],TFs[5]),(TFs[4],TFs[6]),(TFs[4],TFs[7]),(TFs[5],TFs[6]),(TFs[5],TFs[7]),(TFs[6],TFs[7])]
            


        if len(TFs) == 2:
            #plt.figure()
            plt.figure(figsize=((length_tf-(length_tf//2)+2),6))
            order_new = [TFs[0],TFs[1]]
            fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, facecolor=(1,1,1,1), errcolor=".2", edgecolor=".2", ci=68, errwidth=1,capsize=0.4)
            sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, order=order,color='black')
            #fig = sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, color=".25", order=order_new)


            # fig = sns.catplot(
            #     x='TF_added',
            #     y='corrected_luminescence',
            #     data=df,
            #     kind='violin',
            #     order=order,            
            #     cut=0,
            #     legend=False,
            #     #color=new_color
            # )
            
            #fig = px.violin(df, x='TF_added',
            #                         y='corrected_luminescence', box=True,                       
            #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

            #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
            #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
            #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
            #hide legend
            #fig.layout.update(showlegend=False)
            # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
            #stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
            # label box pairs        
            #box_pairs = [(TFs[0],TFs[1])]
            
            # make empty list of p_values
           # p_values = []
            # populate the list of p_values according to the box_pairs
            # for pair in box_pairs:
            #     print(pair)
            #     # select p value for each pair
            #     p = stat.loc[pair[0], pair[1]]
            #     p_values.append(p)

            # add stats annotation to the plot
            # add_stat_annotation(
            #     fig,
            #     data=df,
            #     x='TF_added',
            #     y='corrected_luminescence',
            #     order=order_new,
            #     box_pairs=list(box_pairs_significant.keys()),
            #     text_format="star",
            #     loc="outside",
            #     verbose=2,
            #     perform_stat_test=False,
            #     pvalues=list(box_pairs_significant.values()),
            #     #test='Mann-Whitney',
            # )
            # # change axes labels
            # plt.ylabel('Normalised expression (a.u.)')
            # #add title
            # plt.title(prom)
            # #make xticks diagonal
            # plt.xticks(rotation=45, ha='right')
            # #plt.xlabel(x_label)
            # # tight layout
            # plt.tight_layout()
            # # save figure
            # plt.savefig(
            #     f'../../../../data/plots/luminescence/{date}/scatter{prom}_plate1.pdf',
            #     format="pdf",
            #     bbox_inches="tight",
           # )
        elif len(TFs) < 1:
            pass
        else:
            print(prom)
            print(TFs)
            plt.figure(figsize=((length_tf-(length_tf//2)+1),6))
            # fig = sns.catplot(
            #     x='TF_added',
            #     y='corrected_luminescence',
            #     data=df,
            #     kind='violin',
            #     order=order,            
            #     cut=0,
            #     legend=False,
            #     #color=new_color
            # )
            fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=TFs, linewidth=2, facecolor=(1,1,1,1), errcolor=".2", edgecolor=".2", ci=68, errwidth=1,capsize=0.4)
            sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, order=TFs,color='black')
            
            #fig = px.violin(df, x='TF_added',
            #                         y='corrected_luminescence', box=True,                       
            #                      color='TF_added', color_discrete_map=new_color,violinmode='overlay',order=order) #points="all"

            #fig.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)', title=prom,autosize=True)
            #fig.update_xaxes(showline=True, linewidth=1, linecolor='black',ticks="outside")
            #fig.update_yaxes(showline=True, linewidth=1, linecolor='black',ticks="outside", title_text='Mean luminescence (a.u.)')
            #hide legend
            #fig.layout.update(showlegend=False)
            # add significance if necessary - dunn's posthocs with multiple Bonferroni correction
            # stat = dunn_posthoc_test(df, 'corrected_luminescence', 'TF_added')
            # # label box pairs        
            # #box_pairs = [(TFs[0],TFs[1]), (TFs[0],TFs[2]),(TFs[0],TFs[3]), (TFs[1],TFs[2]),(TFs[1],TFs[3]),(TFs[2],TFs[3])]
            # # make empty list of p_values
            # p_values = []
            # # populate the list of p_values according to the box_pairs
            # for pair in box_pairs:
            # #    print(pair)
            #     # select p value for each pair
            #     p = stat.loc[pair[0], pair[1]]
            #     p_values.append(p)

            # add stats annotation to the plot


            #if no significant values, don't add stats annotation
        # if len(box_pairs_significant.values()) < 1:
        #     pass
        # else:
        #     add_stat_annotation(
        #         fig,
        #         data=df,
        #         x='TF_added',
        #         y='corrected_luminescence',
        #         order=order,
        #         box_pairs=list(box_pairs_significant.keys()),
        #         text_format="star",
        #         loc="outside",
        #         verbose=2,
        #         perform_stat_test=False,
        #         pvalues=list(box_pairs_significant.values()),
        #         #test_short_name="Dunn",
        #     )

        # change axes labels
        plt.ylabel('Normalised expression (a.u.)')
        #add title
        plt.title(prom, y=1.4,)
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}.pdf',
            format="pdf",
            bbox_inches="tight",)
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}//scatter{prom}.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()

# %%
f'../../../../data/plots/luminescence/{date}/stats.txt'
#delete the stats file if it exists
stats_file = f'../../../../data/plots/luminescence/{date}/stats.txt'
if os.path.exists(stats_file):
    os.remove(stats_file)

# %%
#synthetic activators
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
rcParams['font.size'] = 16
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'minimal_STAP4':
        pass
    elif prom == 'ARF18':
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        if prom == 'ARF18':
            TF_order = ['No TF/YFP','+No TF/YFP_1μM_NAA','No TF','No TF_1μM_NAA','+ANAC032','+ANR1','+ARF18','+ARF18_1μM_NAA','+ARF18+IAA33','+ARF18+IAA33_1μM_NAA','+ARF9','+ARF9_1μM_NAA','+ARF9+IAA33','+ARF9+IAA33_1μM_NAA','+ARF18+ARF9','+ARF18+ARF9_1μM_NAA','+ARF18+ARF9+IAA33','+ARF18+ARF9+IAA33_1μM_NAA','+dCas9_activator1','+dCas9_activator2','+dCas9_activator3','+UBQ10_dCas9_activator+guide1', '+UBQ10_dCas9_activator_123guides', '+guide1+UBQ10_dCas9_repressor_guide3+guide2','+TAD-Suntag_noguide','+TAD-Suntag_guide1','+TAD-Suntag_guides1,2,3','+VP64-Suntag_noguide','+VP64-Suntag_guide1','+VP64-Suntag_guides1,2,3',]
           
        # else:
        #     TF_order = ['No TF/YFP','+No TF/YFP_1μM_NAA','No TF','No TF_1μM_NAA','+ANAC032','+ANR1','+ARF18','+ARF18_1μM_NAA','+ARF18+IAA33','+ARF18+IAA33_1μM_NAA','+ARF9','+ARF9_1μM_NAA','+ARF9+IAA33','+ARF9+IAA33_1μM_NAA','+ARF18+ARF9','+ARF18+ARF9_1μM_NAA','+ARF18+ARF9+IAA33','+ARF18+ARF9+IAA33_1μM_NAA','+dCas9_activator1','+dCas9_activator2','+dCas9_activator3','+dCpf1_repressor1','+dCpf1_repressor2','+dCpf1_repressor3','+bZIP3','+DREB26','+HHO2','+NLP6','+NLP7','+TGA1','+NLP7+bZIP3','+NLP7+TGA1','No TF nor YFP',  '+guide1+UBQ10_dCas9_repressor_guide3+guide2', '+UBQ10_dCpf1_repressor3', '+UBQ10_dCpf1_repressor2', '+UBQ10_dCpf1_repressor123guides', '+UBQ10_dCas9_activator_123guides','+UBQ10_dCas9_activator+guide1','+UBQ10_dCpf1_repressor1']



        
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        #create order and box pairs based on the length of TFs
        order = []
        box_pairs = [] 
        for x in range (0, (length_tf)):
            order.append(TFs[x])
            if TFs[x] == "+TAD-Suntag_noguide" and TFs[x] == "+VP64-Suntag_noguide":
                pass
            #if TFs[x] contains TAD
            elif "+TAD-Suntag" in TFs[x]:            
                box_pairs.append(('+TAD-Suntag_noguide',TFs[x]))
            elif "+VP64-Suntag" in TFs[x]:            
                box_pairs.append(('+VP64-Suntag_noguide',TFs[x]))
        #append No TF pairs with no guide controls
        box_pairs.append(('+TAD-Suntag_noguide', 'No TF'))
        box_pairs.append(('+VP64-Suntag_noguide', 'No TF'))
        
        #add every combination of box pairs of length 2
        #box_pairs=list(combinations(order, 2))~
        # box_pairs_all_pvalues = {}
        # for pair in box_pairs:
        #     #create series objects
        #     TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
        #     TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
        # # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
        # # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
        # #equal variance = false so do Welch's T-test
        #     results = stats.ttest_ind(TF1, TF2, equal_var=False)
        #     #append pvalue to dict
        #     box_pairs_all_pvalues[pair] = results.pvalue
        # box_pairs_significant.append(pair)
        # p_values.append(results.pvalue)
        # print/(f'all pvalues={box_pairs_all_pvalues}')

        # #filter dict by significance and put in a new dictionary
        # box_pairs_significant = {}
        # for k,v in box_pairs_all_pvalues.items():
        #     if v <0.05:
        #         box_pairs_significant[k] = v
                

        # if len(TFs) == 2:
        #     #plt.figure()
        #     plt.figure(figsize=((length_tf-(length_tf//2)+2),6))
        #     order_new = [TFs[0],TFs[1]]
        #     fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, facecolor=(1,1,1,1), errcolor=".2", edgecolor=".2", ci=68, errwidth=1,capsize=0.4)
        #     sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, order=order,color='black')

          
        if len(TFs) < 1:
            pass
        else:
            print(prom)
            print(TFs)
            plt.figure(figsize=((length_tf-(length_tf//2)+1),6))

            fig_args = {'x':'TF_added', 'y':'corrected_luminescence','data':df, 'order':order, 'dodge':True,}#'ax':ax
            configuration = {'test':'t-test_welch', 'text_format':'star', 'pvalue_thresholds':[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]]}#"pairs":list(box_pairs_significant.keys()),"pvalues":list(box_pairs_significant.values()), 'loc':'inside'
        

            # )
            # fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=TFs, linewidth=2, facecolor=(1,1,1,1), errcolor=".2", edgecolor=".2", ci=68, errwidth=1,capsize=0.4)
            # sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, order=TFs,color='black')


            fig = sns.barplot(**fig_args, linewidth=2,  errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,color='lightgrey')#facecolor=(1,1,1,1),
            #fig.set_aspect(0.5)color='#BFBFBF'
            sns.swarmplot(**fig_args,color='black')

                #add stats
            annotator = Annotator(fig, box_pairs, **fig_args,verbose=False, show_non_significant=False)
            annotator.configure(**configuration)#loc='inside'
            fig, test_results = annotator.apply_and_annotate()
            with open(f'../../../../data/plots/luminescence/{date}/stats.txt', 'a') as f:                            
                for res in test_results:
                    # print(dir(res))
                    # print(dir(res.data.adjust))
                    # 'formatted_output', 'formatter', 'is_custom', 'print_labels_and_content', 'structs', 'text'
                    # print(res.formatted_output)
                    # print(res.formatter)
                    # print(res.is_custom)
                    # print(res.print_labels_and_content)
                    # print(res.structs)
                    # print(res.text)
                    # print(dir(res.data))
                    # print(res.pvalue)pvalue
                    # print(vars(res.data))
                    f.write(f'{str(prom)},{str(res.data.group1)},{str(res.data.group2)},{str(res.data)},t={res.data.stat_value}, P={res.data.pvalue}\n{res.structs} \n\n') 
                    #mean of no TF = {no_tf_mean}\nmean of TF = {tf_mean}\nstd of no TF = {no_tf_std}\nstd of TF = {tf_std}

            

        # change axes labels
        plt.ylabel('Normalised luminescence (a.u.)')
        plt.xlabel('Coexpressed protein')
        #add title
        plt.title(prom, y=1.4,)   

        
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')
        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_activators.pdf',
            format="pdf",
            bbox_inches="tight",)
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_activators.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# ARF18
# ['No TF', '+TAD-Suntag_noguide', '+TAD-Suntag_guide1', '+TAD-Suntag_guides1,2,3', '+VP64-Suntag_noguide', '+VP64-Suntag_guide1', '+VP64-Suntag_guides1,2,3']

# %%
#synthetic repressors
#set matplotlib default parameters
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 2
rcParams['axes.linewidth'] = 2
#rcParams['lines.linewidth'] = 2
#remove top and right lines
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
#font size
rcParams['font.size'] = 16
#make svg text editable
rcParams['svg.fonttype'] = 'none'
#align y-axis top most tick with end of axis
rcParams['axes.autolimit_mode'] = 'round_numbers'
#set margins to ensure any error bars fit
rcParams['axes.xmargin'] = 0.2
rcParams['axes.ymargin'] = 0.2
for prom in prom_names_plate1:
    if prom == 'NOS_calibrator' or prom == 'NOS_calibrator_35s:LucF_calibrator' or prom == 'STAP4' or prom == 'minimal_STAP4':
        pass
    elif prom == 'ARF18':
        df = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == prom].sort_values("TF_added", ascending=False)
        #df2 = luminescence_raw_df_plate1[luminescence_raw_df_plate1.Promoter == 'STAP4'].sort_values("TF_added", ascending=False)
        #change name of TF added in df2 to minimal_stap4        
        #df2['TF_added'] = 'pSTAP4 no TF'
        #df = pd.merge(df1,df2, how='outer').sort_values("TF_added", ascending=False)        
        TFs_orig =  df.TF_added.unique()
        if prom == 'ARF18':
            # TF_order = ['No TF/YFP','+No TF/YFP_1μM_NAA','No TF','No TF_1μM_NAA','+ANAC032','+ANR1','+ARF18','+ARF18_1μM_NAA','+ARF18+IAA33','+ARF18+IAA33_1μM_NAA','+ARF9','+ARF9_1μM_NAA','+ARF9+IAA33','+ARF9+IAA33_1μM_NAA','+ARF18+ARF9','+ARF18+ARF9_1μM_NAA','+ARF18+ARF9+IAA33','+ARF18+ARF9+IAA33_1μM_NAA','+dCas9_activator1','+dCas9_activator2','+dCas9_activator3','+UBQ10_dCas9_activator+guide1', '+UBQ10_dCas9_activator_123guides', '+guide1+UBQ10_dCas9_repressor_guide3+guide2','+TAD-Suntag_noguide','+TAD-Suntag_guide1','+TAD-Suntag_guides1,2,3','+VP64-Suntag_noguide','+VP64-Suntag_guide1','+VP64-Suntag_guides1,2,3',]
            TF_order = ['No TF','+SRDX-dCpf1_noguide','+SRDX-dCpf1_guide1','+SRDX-dCpf1_guide2','+SRDX-dCpf1_guide3','+SRDX-dCpf1_guides1,2,3','+SRDX-dCpf1_guides1,2,4','+SRDX-Suntag_noguide','+SRDX-Suntag_123guides1,2,3']
           
        # else:
        #     TF_order = ['No TF/YFP','+No TF/YFP_1μM_NAA','No TF','No TF_1μM_NAA','+ANAC032','+ANR1','+ARF18','+ARF18_1μM_NAA','+ARF18+IAA33','+ARF18+IAA33_1μM_NAA','+ARF9','+ARF9_1μM_NAA','+ARF9+IAA33','+ARF9+IAA33_1μM_NAA','+ARF18+ARF9','+ARF18+ARF9_1μM_NAA','+ARF18+ARF9+IAA33','+ARF18+ARF9+IAA33_1μM_NAA','+dCas9_activator1','+dCas9_activator2','+dCas9_activator3','+dCpf1_repressor1','+dCpf1_repressor2','+dCpf1_repressor3','+bZIP3','+DREB26','+HHO2','+NLP6','+NLP7','+TGA1','+NLP7+bZIP3','+NLP7+TGA1','No TF nor YFP',  '+guide1+UBQ10_dCas9_repressor_guide3+guide2', '+UBQ10_dCpf1_repressor3', '+UBQ10_dCpf1_repressor2', '+UBQ10_dCpf1_repressor123guides', '+UBQ10_dCas9_activator_123guides','+UBQ10_dCas9_activator+guide1','+UBQ10_dCpf1_repressor1']



        
        #sort based on custom order
        TFs = []
        for i in range(len(TF_order)):
            if TF_order[i] in TFs_orig:
                TFs+=[TF_order[i]]
        #print(df)
        #get length of number of TFs
        length_tf = len(TFs)
        #create order and box pairs based on the length of TFs
        order = []
        box_pairs = [] 
        for x in range (0, (length_tf)):
            order.append(TFs[x])
            if TFs[x] == "+SRDX-dCpf1_noguide" and TFs[x] == "+SRDX-Suntag_noguide":
                pass
            #if TFs[x] contains TAD
            elif "+SRDX-dCpf1" in TFs[x]:            
                box_pairs.append(('+SRDX-dCpf1_noguide',TFs[x]))
            elif "+SRDX-Suntag" in TFs[x]:            
                box_pairs.append(('+SRDX-Suntag_noguide',TFs[x]))

        #Append No TF and gno guide control pairs
        box_pairs.append(('+SRDX-dCpf1_noguide', 'No TF'))
        box_pairs.append(('+SRDX-Suntag_noguide', 'No TF'))

        #add every combination of box pairs of length 2
        #box_pairs=list(combinations(order, 2))~
        # box_pairs_all_pvalues = {}
        # for pair in box_pairs:
        #     #create series objects
        #     TF1 = df.query(f'TF_added == "{pair[0]}"')['corrected_luminescence']
        #     TF2 = df.query(f'TF_added == "{pair[1]}"')['corrected_luminescence']
        # # probe1 = df.loc[df['probe'] == pair[0], corrected_luminescence]
        # # probe2 = df.loc[df['probe'] == pair[1], corrected_luminescence]
        # #equal variance = false so do Welch's T-test
        #     results = stats.ttest_ind(TF1, TF2, equal_var=False)
        #     #append pvalue to dict
        #     box_pairs_all_pvalues[pair] = results.pvalue
        # box_pairs_significant.append(pair)
        # p_values.append(results.pvalue)
        # print/(f'all pvalues={box_pairs_all_pvalues}')

        # #filter dict by significance and put in a new dictionary
        # box_pairs_significant = {}
        # for k,v in box_pairs_all_pvalues.items():
        #     if v <0.05:
        #         box_pairs_significant[k] = v
                

        # if len(TFs) == 2:
        #     #plt.figure()
        #     plt.figure(figsize=((length_tf-(length_tf//2)+2),6))
        #     order_new = [TFs[0],TFs[1]]
        #     fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=order, linewidth=2, facecolor=(1,1,1,1), errcolor=".2", edgecolor=".2", ci=68, errwidth=1,capsize=0.4)
        #     sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, order=order,color='black')

          
        if len(TFs) < 1:
            pass
        else:
            print(prom)
            print(TFs)
            plt.figure(figsize=((length_tf-(length_tf//2)+1),8))

            fig_args = {'x':'TF_added', 'y':'corrected_luminescence','data':df, 'order':order, 'dodge':True,}#'ax':ax
            configuration = {'test':'t-test_welch', 'text_format':'star', 'pvalue_thresholds':[[1e-3, "***"],[1e-2, "**"],[0.05, "*"],[1, "ns"]]}#"pairs":list(box_pairs_significant.keys()),"pvalues":list(box_pairs_significant.values()), 'loc':'inside'
        

            # )
            # fig = sns.barplot(x='TF_added', y='corrected_luminescence', data=df, order=TFs, linewidth=2, facecolor=(1,1,1,1), errcolor=".2", edgecolor=".2", ci=68, errwidth=1,capsize=0.4)
            # sns.swarmplot(x='TF_added', y='corrected_luminescence', data=df, order=TFs,color='black')


            fig = sns.barplot(**fig_args, linewidth=2,  errcolor="black", edgecolor="black", ci=68, errwidth=1,capsize=0.4,color='lightgrey')#facecolor=(1,1,1,1),
            #fig.set_aspect(0.5)color='#BFBFBF'
            sns.swarmplot(**fig_args,color='black')

                #add stats
            annotator = Annotator(fig, box_pairs, **fig_args,verbose=False, show_non_significant=False)
            annotator.configure(**configuration)#loc='inside'
            fig, test_results = annotator.apply_and_annotate()
            with open(f'../../../../data/plots/luminescence/{date}/stats.txt', 'a') as f:                            
                for res in test_results:
                    # print(dir(res))
                    # print(dir(res.data.adjust))
                    # 'formatted_output', 'formatter', 'is_custom', 'print_labels_and_content', 'structs', 'text'
                    # print(res.formatted_output)
                    # print(res.formatter)
                    # print(res.is_custom)
                    # print(res.print_labels_and_content)
                    # print(res.structs)
                    # print(res.text)
                    # print(dir(res.data))
                    # print(res.pvalue)pvalue
                    # print(vars(res.data))
                    f.write(f'{str(prom)},{str(res.data.group1)},{str(res.data.group2)},{str(res.data)},t={res.data.stat_value}, P={res.data.pvalue}\n{res.structs} \n\n') 
                    #mean of no TF = {no_tf_mean}\nmean of TF = {tf_mean}\nstd of no TF = {no_tf_std}\nstd of TF = {tf_std}

            

        # change axes labels
        plt.ylabel('Normalised luminescence (a.u.)')
        plt.xlabel('Coexpressed protein')
        #add title
        # plt.title(prom, y=1.4,)   

        #rename x axis labels, remove + from start of each label
        labels = [item.get_text() for item in fig.get_xticklabels()]
        labels = [item.replace('+', '') for item in labels]
        #if label is +SRDX-dCpf1_noguide, replace with dCas12a:3xSRDX no guide
        labels = [item.replace('SRDX-dCpf1_noguide', 'dCas12a:3xSRDX no guide') for item in labels]
        labels = [item.replace('SRDX-dCpf1', 'dCas12a:3xSRDX') for item in labels]
        labels = [item.replace('SRDX-Suntag', 'Suntag 3xSRDX') for item in labels]
        labels = [item.replace('123', ' ') for item in labels]
        labels = [item.replace('_', ' ') for item in labels]
        #replace labels
        fig.set_xticklabels(labels)



        
        #make xticks diagonal
        plt.xticks(rotation=45, ha='right')

        #plt.xlabel(x_label)
        # tight layout
        plt.tight_layout()
        # save figure
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_repressors.pdf',
            format="pdf",
            bbox_inches="tight",)
        plt.savefig(
            f'../../../../data/plots/luminescence/{date}/scatter{prom}_repressors.svg',
            format="svg",
            bbox_inches="tight",transparent=True)
 
            


            #write to file static image and interactive one
        # fig.write_image(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.pdf', width=500, height=350, scale=5)
        #  fig.write_html(f'../../../../data/plots/luminescence/{finaldate}/violin{prom}.html')
        #  fig.show()
# Out:
# ARF18
# ['No TF', '+SRDX-dCpf1_noguide', '+SRDX-dCpf1_guide1', '+SRDX-dCpf1_guide2', '+SRDX-dCpf1_guide3', '+SRDX-dCpf1_guides1,2,3', '+SRDX-dCpf1_guides1,2,4', '+SRDX-Suntag_noguide', '+SRDX-Suntag_123guides1,2,3']

# %% [markdown]
# ### test normality

# %%
#returns test statistic, p-value
for name1 in prom_names_plate1:
    for name in names_plate1:
        print(name1,'{}: {}'.format(name, stats.shapiro(luminescence_raw_df_plate1['nluc/fluc'][luminescence_raw_df_plate1.TF_added == name])))
# Out:
# NOS +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NOS +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NOS +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NOS +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NOS +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NOS +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NOS +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NOS +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NOS +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NOS +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NOS No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NOS +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NOS No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NOS +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NOS +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NOS +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NOS +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NOS +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NOS +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NOS +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NOS +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NOS +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NOS +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NOS +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NOS +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NOS +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NOS +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NOS +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NOS +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NOS +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# ANAC032 +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# ANAC032 +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# ANAC032 +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# ANAC032 +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# ANAC032 +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# ANAC032 +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# ANAC032 +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# ANAC032 +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# ANAC032 +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# ANAC032 +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# ANAC032 No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# ANAC032 +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# ANAC032 No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# ANAC032 +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# ANAC032 +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# ANAC032 +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# ANAC032 +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# ANAC032 +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# ANAC032 +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# ANAC032 +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# ANAC032 +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# ANAC032 +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# ANAC032 +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# ANAC032 +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# ANAC032 +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# ANAC032 +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# ANAC032 +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# ANAC032 +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# ANAC032 +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# ANAC032 +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# ANR1 +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# ANR1 +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# ANR1 +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# ANR1 +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# ANR1 +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# ANR1 +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# ANR1 +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# ANR1 +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# ANR1 +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# ANR1 +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# ANR1 No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# ANR1 +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# ANR1 No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# ANR1 +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# ANR1 +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# ANR1 +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# ANR1 +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# ANR1 +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# ANR1 +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# ANR1 +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# ANR1 +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# ANR1 +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# ANR1 +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# ANR1 +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# ANR1 +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# ANR1 +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# ANR1 +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# ANR1 +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# ANR1 +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# ANR1 +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# ARF18 +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# ARF18 +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# ARF18 +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# ARF18 +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# ARF18 +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# ARF18 +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# ARF18 +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# ARF18 +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# ARF18 +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# ARF18 +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# ARF18 No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# ARF18 +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# ARF18 No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# ARF18 +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# ARF18 +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# ARF18 +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# ARF18 +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# ARF18 +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# ARF18 +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# ARF18 +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# ARF18 +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# ARF18 +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# ARF18 +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# ARF18 +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# ARF18 +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# ARF18 +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# ARF18 +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# ARF18 +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# ARF18 +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# ARF18 +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# DREB26 +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# DREB26 +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# DREB26 +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# DREB26 +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# DREB26 +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# DREB26 +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# DREB26 +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# DREB26 +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# DREB26 +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# DREB26 +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# DREB26 No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# DREB26 +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# DREB26 No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# DREB26 +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# DREB26 +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# DREB26 +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# DREB26 +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# DREB26 +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# DREB26 +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# DREB26 +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# DREB26 +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# DREB26 +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# DREB26 +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# DREB26 +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# DREB26 +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# DREB26 +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# DREB26 +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# DREB26 +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# DREB26 +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# DREB26 +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# NIR1 +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NIR1 +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NIR1 +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NIR1 +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NIR1 +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NIR1 +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NIR1 +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NIR1 +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NIR1 +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NIR1 +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NIR1 No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NIR1 +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NIR1 No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NIR1 +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NIR1 +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NIR1 +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NIR1 +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NIR1 +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NIR1 +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NIR1 +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NIR1 +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NIR1 +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NIR1 +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NIR1 +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NIR1 +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NIR1 +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NIR1 +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NIR1 +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NIR1 +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NIR1 +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# NLP6 +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NLP6 +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NLP6 +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NLP6 +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NLP6 +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NLP6 +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NLP6 +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NLP6 +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NLP6 +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NLP6 +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NLP6 No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NLP6 +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NLP6 No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NLP6 +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NLP6 +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NLP6 +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NLP6 +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NLP6 +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NLP6 +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NLP6 +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NLP6 +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NLP6 +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NLP6 +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NLP6 +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NLP6 +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NLP6 +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NLP6 +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NLP6 +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NLP6 +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NLP6 +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# NLP7 +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NLP7 +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NLP7 +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NLP7 +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NLP7 +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NLP7 +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NLP7 +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NLP7 +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NLP7 +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NLP7 +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NLP7 No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NLP7 +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NLP7 No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NLP7 +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NLP7 +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NLP7 +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NLP7 +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NLP7 +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NLP7 +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NLP7 +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NLP7 +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NLP7 +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NLP7 +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NLP7 +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NLP7 +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NLP7 +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NLP7 +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NLP7 +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NLP7 +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NLP7 +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# NOS_calibrator_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NOS_calibrator_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NOS_calibrator_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NOS_calibrator_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NOS_calibrator_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NOS_calibrator_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NOS_calibrator_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NOS_calibrator_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NOS_calibrator_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NOS_calibrator_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NOS_calibrator_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NOS_calibrator_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NOS_calibrator_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NOS_calibrator_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NOS_calibrator_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NOS_calibrator_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NOS_calibrator_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NOS_calibrator_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NOS_calibrator_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NOS_calibrator_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NOS_calibrator_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NOS_calibrator_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NOS_calibrator_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NOS_calibrator_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NOS_calibrator_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NOS_calibrator_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NOS_calibrator_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NOS_calibrator_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NOS_calibrator_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NOS_calibrator_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# 35s_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# 35s_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# 35s_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# 35s_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# 35s_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# 35s_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# 35s_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# 35s_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# 35s_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# 35s_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# 35s_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# 35s_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# 35s_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# 35s_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# 35s_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# 35s_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# 35s_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# 35s_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# 35s_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# 35s_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# 35s_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# 35s_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# 35s_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# 35s_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# 35s_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# 35s_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# 35s_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# 35s_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# 35s_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# 35s_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# ANAC032_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# ANAC032_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# ANAC032_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# ANAC032_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# ANAC032_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# ANAC032_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# ANAC032_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# ANAC032_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# ANAC032_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# ANAC032_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# ANAC032_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# ANAC032_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# ANAC032_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# ANAC032_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# ANAC032_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# ANAC032_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# ANAC032_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# ANAC032_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# ANAC032_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# ANAC032_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# ANAC032_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# ANAC032_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# ANAC032_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# ANAC032_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# ANAC032_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# ANAC032_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# ANAC032_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# ANAC032_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# ANAC032_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# ANAC032_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# ANR1_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# ANR1_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# ANR1_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# ANR1_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# ANR1_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# ANR1_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# ANR1_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# ANR1_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# ANR1_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# ANR1_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# ANR1_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# ANR1_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# ANR1_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# ANR1_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# ANR1_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# ANR1_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# ANR1_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# ANR1_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# ANR1_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# ANR1_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# ANR1_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# ANR1_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# ANR1_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# ANR1_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# ANR1_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# ANR1_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# ANR1_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# ANR1_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# ANR1_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# ANR1_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# ARF18_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# ARF18_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# ARF18_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# ARF18_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# ARF18_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# ARF18_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# ARF18_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# ARF18_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# ARF18_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# ARF18_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# ARF18_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# ARF18_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# ARF18_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# ARF18_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# ARF18_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# ARF18_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# ARF18_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# ARF18_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# ARF18_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# ARF18_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# ARF18_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# ARF18_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# ARF18_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# ARF18_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# ARF18_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# ARF18_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# ARF18_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# ARF18_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# ARF18_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# ARF18_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# DREB26_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# DREB26_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# DREB26_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# DREB26_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# DREB26_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# DREB26_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# DREB26_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# DREB26_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# DREB26_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# DREB26_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# DREB26_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# DREB26_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# DREB26_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# DREB26_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# DREB26_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# DREB26_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# DREB26_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# DREB26_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# DREB26_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# DREB26_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# DREB26_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# DREB26_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# DREB26_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# DREB26_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# DREB26_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# DREB26_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# DREB26_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# DREB26_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# DREB26_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# DREB26_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# NIR1_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NIR1_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NIR1_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NIR1_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NIR1_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NIR1_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NIR1_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NIR1_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NIR1_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NIR1_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NIR1_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NIR1_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NIR1_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NIR1_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NIR1_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NIR1_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NIR1_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NIR1_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NIR1_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NIR1_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NIR1_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NIR1_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NIR1_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NIR1_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NIR1_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NIR1_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NIR1_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NIR1_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NIR1_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NIR1_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# NLP6_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NLP6_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NLP6_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NLP6_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NLP6_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NLP6_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NLP6_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NLP6_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NLP6_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NLP6_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NLP6_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NLP6_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NLP6_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NLP6_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NLP6_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NLP6_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NLP6_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NLP6_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NLP6_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NLP6_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NLP6_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NLP6_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NLP6_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NLP6_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NLP6_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NLP6_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NLP6_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NLP6_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NLP6_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NLP6_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)
# NLP7_35s:LucF_calibrator +No TF_1μM_NAA: ShapiroResult(statistic=0.6021087169647217, pvalue=3.555633287799509e-10)
# NLP7_35s:LucF_calibrator +ARF18+IAA33_1μM_NAA: ShapiroResult(statistic=0.5674434304237366, pvalue=2.729845505200501e-07)
# NLP7_35s:LucF_calibrator +ANAC032: ShapiroResult(statistic=0.6649079918861389, pvalue=8.30073787483343e-08)
# NLP7_35s:LucF_calibrator +NLP6: ShapiroResult(statistic=0.5025386214256287, pvalue=1.581822520191345e-11)
# NLP7_35s:LucF_calibrator +ARF9: ShapiroResult(statistic=0.633334755897522, pvalue=4.5249385038914625e-06)
# NLP7_35s:LucF_calibrator +ARF9_1μM_NAA: ShapiroResult(statistic=0.6098078489303589, pvalue=2.5041554181370884e-06)
# NLP7_35s:LucF_calibrator +NLP7: ShapiroResult(statistic=0.5536598563194275, pvalue=7.369764520870348e-11)
# NLP7_35s:LucF_calibrator +ARF18: ShapiroResult(statistic=0.5843394994735718, pvalue=4.150164727434458e-07)
# NLP7_35s:LucF_calibrator +ARF18_1μM_NAA: ShapiroResult(statistic=0.5886361002922058, pvalue=4.624382086149126e-07)
# NLP7_35s:LucF_calibrator +No TF/YFP_1μM_NAA: ShapiroResult(statistic=0.5478658080101013, pvalue=6.153911408235402e-11)
# NLP7_35s:LucF_calibrator No TF/YFP: ShapiroResult(statistic=0.5933141708374023, pvalue=8.104313119032536e-13)
# NLP7_35s:LucF_calibrator +ARF18+IAA33: ShapiroResult(statistic=0.5709260702133179, pvalue=2.973536084027728e-07)
# NLP7_35s:LucF_calibrator No TF: ShapiroResult(statistic=0.613648533821106, pvalue=5.27107413272887e-10)
# NLP7_35s:LucF_calibrator +ANR1: ShapiroResult(statistic=0.6080490350723267, pvalue=2.397850721536088e-06)
# NLP7_35s:LucF_calibrator +ARF18+ARF9: ShapiroResult(statistic=0.4848639965057373, pvalue=1.479487679034719e-07)
# NLP7_35s:LucF_calibrator +bZIP3: ShapiroResult(statistic=0.7509964108467102, pvalue=0.00012790891923941672)
# NLP7_35s:LucF_calibrator +HHO2: ShapiroResult(statistic=0.5388205051422119, pvalue=4.734674803330563e-07)
# NLP7_35s:LucF_calibrator +ARF18+ARF9_1μM_NAA: ShapiroResult(statistic=0.4889041781425476, pvalue=1.6097443733542605e-07)
# NLP7_35s:LucF_calibrator +DREB26: ShapiroResult(statistic=0.6438871622085571, pvalue=5.9427852647786494e-06)
# NLP7_35s:LucF_calibrator +TGA1: ShapiroResult(statistic=0.6925461292266846, pvalue=2.2262738639255986e-05)
# NLP7_35s:LucF_calibrator +dCpf1_repressor2: ShapiroResult(statistic=0.8182703256607056, pvalue=0.1589047759771347)
# NLP7_35s:LucF_calibrator +dCpf1_repressor1: ShapiroResult(statistic=0.8736295700073242, pvalue=0.30589085817337036)
# NLP7_35s:LucF_calibrator +dCas9_activator3: ShapiroResult(statistic=0.9091004133224487, pvalue=0.41508370637893677)
# NLP7_35s:LucF_calibrator +dCpf1_repressor3: ShapiroResult(statistic=0.7903698086738586, pvalue=0.09170892834663391)
# NLP7_35s:LucF_calibrator +dCas9_activator1: ShapiroResult(statistic=0.9907715320587158, pvalue=0.8162454962730408)
# NLP7_35s:LucF_calibrator +dCas9_activator2: ShapiroResult(statistic=0.856108546257019, pvalue=0.256925493478775)
# NLP7_35s:LucF_calibrator +ARF18+ARF9+IAA33: ShapiroResult(statistic=0.832230269908905, pvalue=0.04730046167969704)
# NLP7_35s:LucF_calibrator +ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7841020822525024, pvalue=0.013426046818494797)
# NLP7_35s:LucF_calibrator +ARF9+IAA33: ShapiroResult(statistic=0.8314694762229919, pvalue=0.046381331980228424)
# NLP7_35s:LucF_calibrator +ARF18+ARF9+IAA33_1μM_NAA: ShapiroResult(statistic=0.7817862033843994, pvalue=0.012627759948372841)

# %% [markdown]
# #### not normal

# %%
#test variance
stats.levene(luminescence_raw_df['nluc/fluc'][luminescence_raw_df.TF_added == names[0]], 
               luminescence_raw_df['nluc/fluc'][luminescence_raw_df.TF_added == names[1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-202-11d1476bac47> in <module>
#       1 #test variance
# ----> 2 stats.levene(luminescence_raw_df['nluc/fluc'][luminescence_raw_df.TF_added == names[0]],
#       3                luminescence_raw_df['nluc/fluc'][luminescence_raw_df.TF_added == names[1]])
#
# NameError: name 'luminescence_raw_df' is not defined

# %%
test = luminescence_raw_df.groupby('Promoter')

# %%
test

# %% [markdown]
# # one-way ANOVA: scipy.stats.kruskal

# %%
for name in names:
    print(name)
# Out:
# No TF
# +ARF9
# +HHO2
# +ANR1
# +bZIP3
# +TGA1
# +ARF18+ARF9
# +ARF18
# +ANAC032
# +NLP7
# +DREB26
# +NLP6

# %%
#luminescence anova
for promoter, value in test:
    if promoter == 'ANAC032':
        print(promoter)     
        print(stats.f_oneway(value['corrected_luminescence'][value.TF_added == 'None'],
                value['corrected_luminescence'][value.TF_added == 'DREB26'],
                value['corrected_luminescence'][value.TF_added == 'ARF18'],
                value['corrected_luminescence'][value.TF_added == 'DREB26+ARF18']))
    if promoter == 'ANR1':
        print(promoter)     
        print(stats.f_oneway(value['corrected_luminescence'][value.TF_added == 'None'],
                value['corrected_luminescence'][value.TF_added == 'ANR1'],
                value['corrected_luminescence'][value.TF_added == 'NLP7'],
                value['corrected_luminescence'][value.TF_added == 'ARF18'],
                value['corrected_luminescence'][value.TF_added == 'DREB26']))
    if promoter == 'ARF18':
        print(promoter)     
        print(stats.f_oneway(value['corrected_luminescence'][value.TF_added == 'None'],
                value['corrected_luminescence'][value.TF_added == 'NLP7'],
                value['corrected_luminescence'][value.TF_added == 'DREB26']))
    if promoter == 'NLP6':
        print(promoter)     
        print(stats.f_oneway(value['corrected_luminescence'][value.TF_added == 'None'],
                value['corrected_luminescence'][value.TF_added == 'ANR1'],                
                value['corrected_luminescence'][value.TF_added == 'ARF18'],
                value['corrected_luminescence'][value.TF_added == 'DREB26']))
    if promoter == 'DREB26':
        print(promoter)     
        print(stats.f_oneway(value['corrected_luminescence'][value.TF_added == 'None'],                
                value['corrected_luminescence'][value.TF_added == 'ARF18'],
               ))
    if promoter == 'NLP7':
        print(promoter)     
        print(stats.f_oneway(value['corrected_luminescence'][value.TF_added == 'None'],
                value['corrected_luminescence'][value.TF_added == 'ANR1'],
                value['corrected_luminescence'][value.TF_added == 'NLP7'],                
                value['corrected_luminescence'][value.TF_added == 'DREB26'],
                value['corrected_luminescence'][value.TF_added == 'ANAC032'],))
    
    if promoter == 'NIR1':
            
            print(promoter)     
            print(stats.f_oneway(value['corrected_luminescence'][value.TF_added == 'None'],
                value['corrected_luminescence'][value.TF_added == 'NLP6+NLP7'],
                value['corrected_luminescence'][value.TF_added == 'NLP7'],                
                value['corrected_luminescence'][value.TF_added == 'DREB26'],
                value['corrected_luminescence'][value.TF_added == 'NLP6+NLP7+DREB26'],
                value['corrected_luminescence'][value.TF_added == 'NLP6']))
# Out:
# ANAC032
# F_onewayResult(statistic=nan, pvalue=nan)
# ANR1
# F_onewayResult(statistic=nan, pvalue=nan)
# ARF18
# F_onewayResult(statistic=nan, pvalue=nan)
# DREB26
# F_onewayResult(statistic=nan, pvalue=nan)
# NIR1
# F_onewayResult(statistic=nan, pvalue=nan)
# NLP6
# F_onewayResult(statistic=nan, pvalue=nan)
# NLP7
# F_onewayResult(statistic=nan, pvalue=nan)
# /home/witham/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/scipy/stats/stats.py:3612: F_onewayBadInputSizesWarning: at least one input has length 0
#   warnings.warn(F_onewayBadInputSizesWarning('at least one input '

# %%
df = luminescence_raw_df
#First rerun NIR1 it as a GLM
NIR1 = df[df.Promoter == 'NIR1']  
results = ols('corrected_luminescence ~ C(TF_added)', data=NIR1).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     corrected_luminescence   R-squared:                       1.000
# Model:                                OLS   Adj. R-squared:                  1.000
# Method:                     Least Squares   F-statistic:                 1.865e+04
# Date:                    Mon, 02 Aug 2021   Prob (F-statistic):           2.91e-59
# Time:                            15:43:24   Log-Likelihood:                -32.491
# No. Observations:                      45   AIC:                             88.98
# Df Residuals:                          33   BIC:                             110.7
# Df Model:                              11
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      6.7245      0.336     20.023      0.000       6.041       7.408
# C(TF_added)[T.+ANR1]          -0.9453      0.475     -1.990      0.055      -1.912       0.021
# C(TF_added)[T.+ARF18]         -5.5688      0.411    -13.539      0.000      -6.406      -4.732
# C(TF_added)[T.+ARF18+ARF9]    -5.3439      0.411    -12.993      0.000      -6.181      -4.507
# C(TF_added)[T.+ARF9]          -4.6423      0.411    -11.287      0.000      -5.479      -3.806
# C(TF_added)[T.+DREB26]        -2.4859      0.475     -5.234      0.000      -3.452      -1.520
# C(TF_added)[T.+HHO2]          -3.3290      0.475     -7.009      0.000      -4.295      -2.363
# C(TF_added)[T.+NLP6]          51.5304      0.475    108.500      0.000      50.564      52.497
# C(TF_added)[T.+NLP7]         148.5001      0.475    312.675      0.000     147.534     149.466
# C(TF_added)[T.+TGA1]           2.2719      0.475      4.784      0.000       1.306       3.238
# C(TF_added)[T.+bZIP3]          0.7928      0.475      1.669      0.105      -0.173       1.759
# C(TF_added)[T.No TF]          -2.3599      0.475     -4.969      0.000      -3.326      -1.394
# ==============================================================================
# Omnibus:                       52.636   Durbin-Watson:                   1.761
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              560.059
# Skew:                           2.459   Prob(JB):                    2.43e-122
# Kurtosis:                      19.568   Cond. No.                         14.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# #make anova table for NIR1
# aov_table = sm.stats.anova_lm(results, typ=2)
# aov_table

# %%
# #pairwise tukey posthoc test for NIR1

    
# mc = MultiComparison(NIR1['corrected_luminescence'], NIR1['TF_added'])
# mc_results = mc.tukeyhsd()
# print(mc_results)

# %%
rp.summary_cont(NIR1['corrected_luminescence'].groupby(NIR1['TF_added']))
# Out:
#              N        Mean        SD        SE   95% Conf.    Interval
# TF_added
# +ANAC032     3    6.724485  0.023889  0.013793    6.691376    6.757594
# +ANR1        3    5.779182  0.026019  0.015022    5.743122    5.815242
# +ARF18       6    1.155667  0.057076  0.023301    1.105638    1.205697
# +ARF18+ARF9  6    1.380576  0.151005  0.061647    1.248215    1.512937
# +ARF9        6    2.082164  0.081723  0.033363    2.010530    2.153797
# +DREB26      3    4.238549  0.044260  0.025553    4.177208    4.299890
# +HHO2        3    3.395499  0.054186  0.031284    3.320401    3.470596
# +NLP6        3   58.254933  0.322122  0.185977   57.808494   58.701372
# +NLP7        3  155.224614  2.281168  1.317033  152.063076  158.386152
# +TGA1        3    8.996354  0.229067  0.132252    8.678883    9.313825
# +bZIP3       3    7.517250  0.322356  0.186112    7.070488    7.964013
# No TF        3    4.364634  0.175563  0.101361    4.121316    4.607953

# %%
ANR1 = df[df.Promoter == 'ANR1']
rp.summary_cont(ANR1['corrected_luminescence'].groupby(ANR1['TF_added']))
# Out:
#              N       Mean        SD        SE  95% Conf.   Interval
# TF_added
# +ANAC032     3  15.083662  0.344479  0.198885  14.606239  15.561086
# +ANR1        3   9.594051  0.196969  0.113720   9.321065   9.867036
# +ARF18       6   3.382318  0.729296  0.297734   2.743062   4.021574
# +ARF18+ARF9  6   3.770632  0.431280  0.176069   3.392599   4.148666
# +ARF9        6   3.275840  0.127926  0.052225   3.163708   3.387972
# +DREB26      3  19.188573  0.481732  0.278128  18.520927  19.856219
# +HHO2        3  11.415834  0.268452  0.154991  11.043779  11.787889
# +NLP6        3  10.353489  0.269201  0.155423   9.980396  10.726582
# +NLP7        3   7.897732  0.168792  0.097452   7.663798   8.131666
# +TGA1        3  28.778331  0.923838  0.533378  27.497956  30.058705
# +bZIP3       3  19.706415  0.529456  0.305681  18.972628  20.440203
# No TF        3  18.839955  0.196102  0.113220  18.568171  19.111738

# %%
for promoter, value in test:
    print('\033[1m' +promoter + '\033[0m')
    print(kruskal(data=df[df.Promoter == promoter], dv='corrected_luminescence', between='TF_added'))
    print('')
# Out:
# NOS
#            Source  ddof1    H  p-unc
# Kruskal  TF_added      0  0.0    NaN
#
# STAP4
#            Source  ddof1    H  p-unc
# Kruskal  TF_added      0  0.0    NaN
#
# 35s
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-87-9d096edacee5> in <module>
#       1 for promoter, value in test:
#       2     print('\033' +promoter + '\033')
# ----> 3     print(kruskal(data=df[df.Promoter == promoter], dv='corrected_luminescence', between='TF_added'))
#       4     print('')
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.7/site-packages/pingouin/nonparametric.py in kruskal(data, dv, between, detailed)
#     523
#     524     # Calculate chi-square statistic (H)
# --> 525     H = (12 / (n * (n + 1)) * np.sum(sum_rk_grp**2 / n_per_grp)) - 3 * (n + 1)
#     526
#     527     # Correct for ties
#
# ZeroDivisionError: division by zero

# %%
#run Dunn's post-hoc test
#ANR1
sp.posthoc_dunn(df[df.Promoter == 'ANR1'], val_col='corrected_luminescence', group_col='TF_added', p_adjust='bonferroni')
# Out:
#             ANR1     ARF18    DREB26      NLP7      None
# ANR1   -1.000000  1.000000  0.071163  1.000000  1.000000
# ARF18   1.000000 -1.000000  1.000000  0.454646  1.000000
# DREB26  0.071163  1.000000 -1.000000  0.003175  1.000000
# NLP7    1.000000  0.454646  0.003175 -1.000000  0.535796
# None    1.000000  1.000000  1.000000  0.535796 -1.000000

# %%
#NIR1 post-hoc test
sp.posthoc_dunn(df[df.Promoter == 'NIR1'], val_col='corrected_luminescence', group_col='TF_added', p_adjust='bonferroni')
# Out:
#                     DREB26      NLP6  NLP6+NLP7  NLP6+NLP7+DREB26      NLP7  \
# DREB26           -1.000000  0.537726   0.021630          0.052771  0.017535
# NLP6              0.537726 -1.000000   1.000000          1.000000  1.000000
# NLP6+NLP7         0.021630  1.000000  -1.000000          1.000000  1.000000
# NLP6+NLP7+DREB26  0.052771  1.000000   1.000000         -1.000000  1.000000
# NLP7              0.017535  1.000000   1.000000          1.000000 -1.000000
# None              1.000000  1.000000   0.070083          0.206551  0.094729
#
#                       None
# DREB26            1.000000
# NLP6              1.000000
# NLP6+NLP7         0.070083
# NLP6+NLP7+DREB26  0.206551
# NLP7              0.094729
# None             -1.000000
