# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import argparse

# %%
# parser = argparse.ArgumentParser(description='TFBS_enrichment_plots')
# parser.add_argument('file_names', type=str, help='Name of folder and filenames for the promoters extracted')
# parser.add_argument('gat_TFBS_constitutive_output', type=str, help='Location of constitutive promoter gat analysis output')
# parser.add_argument('gat_TFBS_variable_output', type=str, help='Location of variable promoter gat analysis output')
# parser.add_argument('output_prefix', type=str, help='Output prefix to add to plot file name')

# args = parser.parse_args()

# %%
file_names = 'non-overlapping_includingbidirectional_all_genes_newannotation'
gat_TFBS_constitutive_output_openchrom = f'../../data/output/{file_names}/TFBS_enrichment/gat_analysis/gat_promoters_5UTR_Czechowski_TFBS_openchrom_constitutive.out'
gat_TFBS_variable_output_openchrom = f'../../data/output/{file_names}/TFBS_enrichment/gat_analysis/gat_promoters_5UTR_Czechowski_TFBS_openchrom_variable.out'
gat_TFBS_constitutive_output = f'../../data/output/{file_names}/TFBS_enrichment/gat_analysis/gat_promoters_5UTR_Czechowski_TFBS_constitutive.out'
gat_TFBS_variable_output = f'../../data/output/{file_names}/TFBS_enrichment/gat_analysis/gat_promoters_5UTR_Czechowski_TFBS_variable.out'
output_prefix = 'Czechowski_promoters_5UTR'

# %%
def create_plot(gat_TFBS_constitutive_output,gat_TFBS_variable_output):
    """import and process the raw outputs after running gat (Genomic association tester). Then create barplot of constitutive and variable gene TATA enrichment"""
    #import gat output files as dfs
    constitutive = pd.read_table(gat_TFBS_constitutive_output, sep='\t', header=0)
    variable = pd.read_table(gat_TFBS_variable_output, sep='\t', header=0)
    #filter qvalue under 0.05
    constitutive = constitutive[constitutive.qvalue < 0.05]
    variable = variable[variable.qvalue < 0.05]
    
    return constitutive, variable
    #merge dfs
    merged = pd.concat([constitutive,variable], ignore_index=True)
    #set style to ticks
    sns.set(style="ticks", color_codes=True)
    #bar chart, 95% confidence intervals
    plot = sns.barplot(x="annotation", y="l2fold", data=merged)
    plot.axhline(0, color='black')
    plt.xlabel("Gene type")
    plt.ylabel("Log2-fold enrichment over background").get_figure().savefig(f'../../data/output/{file_names}/TFBS_enrichment/plots/{output_prefix}_log2fold.pdf', format='pdf')

# %%
#Create barplot
constitutive_openchrom,variable_openchrom = create_plot(gat_TFBS_constitutive_output_openchrom,gat_TFBS_variable_output_openchrom)

# %%
constitutive_openchrom
# Out:
#          track    annotation  observed  expected  CI95low  CI95high   stddev  \
# 32  MYBRELATED  constitutive       694   368.318    235.0     495.0  81.0770
# 33         SRS  constitutive       264   134.581     60.0     209.0  45.7858
#
#       fold  l2fold  pvalue  ...  annotation_nsegments  annotation_size  \
# 32  1.8818  0.9121   0.001  ...                   100           102457
# 33  1.9546  0.9668   0.001  ...                   100           102457
#
#     annotation_density  overlap_nsegments  overlap_size  overlap_density  \
# 32              33.936                 19           694         0.229870
# 33              33.936                  4           264         0.087443
#
#     percent_overlap_nsegments_track  percent_overlap_size_track  \
# 32                          63.3333                     73.6730
# 33                          66.6667                     83.2808
#
#     percent_overlap_nsegments_annotation  percent_overlap_size_annotation
# 32                                  19.0                           0.6774
# 33                                   4.0                           0.2577
#
# [2 rows x 24 columns]

# %%
variable_openchrom
# Out:
#          track annotation  observed  expected  CI95low  CI95high    stddev  \
# 0     TRIHELIX   variable         0    71.821     31.0     113.0   25.8766
# 6   MYBRELATED   variable        89   287.746    171.0     406.0   71.3861
# 8          HMG   variable       170   341.143    226.0     456.0   67.7101
# 9     AP2EREBP   variable       374   631.579    450.0     821.0  108.8689
# 15      BBRBPC   variable      3713  5188.039   4620.0    5770.0  357.2078
# 16     ABI3VP1   variable      2341  3206.710   2796.0    3616.0  247.2935
# 17         REM   variable      1516  2054.451   1766.0    2327.0  167.5910
# 18          ND   variable      1722  2253.314   1929.0    2574.0  199.8619
#
#       fold  l2fold  pvalue  ...  annotation_nsegments  annotation_size  \
# 0   0.0137 -6.1863   0.002  ...                   100           106131
# 6   0.3117 -1.6818   0.001  ...                   100           106131
# 8   0.4998 -1.0006   0.005  ...                   100           106131
# 9   0.5928 -0.7544   0.006  ...                   100           106131
# 15  0.7157 -0.4825   0.001  ...                   100           106131
# 16  0.7301 -0.4538   0.001  ...                   100           106131
# 17  0.7380 -0.4382   0.001  ...                   100           106131
# 18  0.7643 -0.3878   0.002  ...                   100           106131
#
#     annotation_density  overlap_nsegments  overlap_size  overlap_density  \
# 0               35.153                  0             0         0.000000
# 6               35.153                  4            89         0.029479
# 8               35.153                  8           170         0.056308
# 9               35.153                 14           374         0.123880
# 15              35.153                 94          3713         1.229800
# 16              35.153                 77          2341         0.775390
# 17              35.153                 68          1516         0.502130
# 18              35.153                 56          1722         0.570370
#
#     percent_overlap_nsegments_track  percent_overlap_size_track  \
# 0                            0.0000                      0.0000
# 6                           13.3333                      9.4480
# 8                           18.1818                     18.3387
# 9                           22.2222                     21.8586
# 15                          22.9268                     24.9161
# 16                          26.8293                     26.0516
# 17                          26.0536                     25.9678
# 18                          24.3478                     27.5256
#
#     percent_overlap_nsegments_annotation  percent_overlap_size_annotation
# 0                                    0.0                           0.0000
# 6                                    4.0                           0.0839
# 8                                    8.0                           0.1602
# 9                                   14.0                           0.3524
# 15                                  94.0                           3.4985
# 16                                  77.0                           2.2058
# 17                                  68.0                           1.4284
# 18                                  56.0                           1.6225
#
# [8 rows x 24 columns]

# %%
constitutive,variable = create_plot(gat_TFBS_constitutive_output,gat_TFBS_variable_output)

# %%
#significant qvalue <0.05
constitutive
# Out:
#          track    annotation  observed  expected  CI95low  CI95high    stddev  \
# 6      C2C2DOF  constitutive      3908  4977.391   4470.0    5471.0  302.3284
# 7           ND  constitutive      3001  3642.419   3219.0    4041.0  253.1463
# 8       BBRBPC  constitutive      7494  8947.620   8215.0    9697.0  449.5885
# 9      ABI3VP1  constitutive      5751  6720.897   6142.0    7295.0  356.9986
# 10         REM  constitutive      3819  4432.821   4047.0    4829.0  244.0204
# 28    AP2EREBP  constitutive      1408  1037.619    798.0    1270.0  140.9923
# 30         HMG  constitutive       830   601.523    450.0     737.0   86.1160
# 32  MYBRELATED  constitutive       929   572.304    413.0     731.0   96.3821
# 33         SRS  constitutive       312   170.271     90.0     256.0   50.3633
# 34         ARF  constitutive       168    90.269     42.0     147.0   30.6073
# 35       E2FDP  constitutive       222   112.209     47.0     176.0   38.5066
#
#       fold  l2fold  pvalue  ...  annotation_nsegments  annotation_size  \
# 6   0.7852 -0.3489   0.001  ...                   100           102457
# 7   0.8240 -0.2794   0.004  ...                   100           102457
# 8   0.8376 -0.2557   0.001  ...                   100           102457
# 9   0.8557 -0.2248   0.002  ...                   100           102457
# 10  0.8616 -0.2150   0.004  ...                   100           102457
# 28  1.3566  0.4400   0.006  ...                   100           102457
# 30  1.3792  0.4638   0.005  ...                   100           102457
# 32  1.6222  0.6979   0.001  ...                   100           102457
# 33  1.8275  0.8699   0.003  ...                   100           102457
# 34  1.8517  0.8888   0.012  ...                   100           102457
# 35  1.9698  0.9781   0.001  ...                   100           102457
#
#     annotation_density  overlap_nsegments  overlap_size  overlap_density  \
# 6               33.936                125          3908         1.294400
# 7               33.936                120          3001         0.994000
# 8               33.936                223          7494         2.482200
# 9               33.936                189          5751         1.904900
# 10              33.936                171          3819         1.264900
# 28              33.936                 44          1408         0.466360
# 30              33.936                 34           830         0.274920
# 32              33.936                 28           929         0.307710
# 33              33.936                  5           312         0.103340
# 34              33.936                  8           168         0.055646
# 35              33.936                  9           222         0.073532
#
#     percent_overlap_nsegments_track  percent_overlap_size_track  \
# 6                           25.5624                     26.0273
# 7                           29.8507                     27.6768
# 8                           30.7586                     28.3263
# 9                           29.2570                     28.5494
# 10                          28.9831                     28.7575
# 28                          47.8261                     49.0934
# 30                          46.5753                     51.1084
# 32                          54.9020                     63.3697
# 33                          62.5000                     78.9873
# 34                          88.8889                     88.8889
# 35                          81.8182                     86.3813
#
#     percent_overlap_nsegments_annotation  percent_overlap_size_annotation
# 6                                  125.0                           3.8143
# 7                                  120.0                           2.9290
# 8                                  223.0                           7.3143
# 9                                  189.0                           5.6131
# 10                                 171.0                           3.7274
# 28                                  44.0                           1.3742
# 30                                  34.0                           0.8101
# 32                                  28.0                           0.9067
# 33                                   5.0                           0.3045
# 34                                   8.0                           0.1640
# 35                                   9.0                           0.2167
#
# [11 rows x 24 columns]

# %%
#significant qvalue <0.05
variable
# Out:
#          track annotation  observed  expected  CI95low  CI95high    stddev  \
# 6   MYBRELATED   variable       215   456.660    313.0     612.0   90.3898
# 35     C2C2DOF   variable      6313  5353.948   4804.0    5896.0  325.4405
#
#       fold  l2fold  pvalue  ...  annotation_nsegments  annotation_size  \
# 6   0.4720 -1.0832   0.002  ...                   100           106131
# 35  1.1791  0.2377   0.001  ...                   100           106131
#
#     annotation_density  overlap_nsegments  overlap_size  overlap_density  \
# 6               35.153                  9           215         0.071213
# 35              35.153                204          6313         2.091000
#
#     percent_overlap_nsegments_track  percent_overlap_size_track  \
# 6                           17.6471                     14.6658
# 35                          41.7178                     42.0446
#
#     percent_overlap_nsegments_annotation  percent_overlap_size_annotation
# 6                                    9.0                           0.2026
# 35                                 204.0                           5.9483
#
# [2 rows x 24 columns]
