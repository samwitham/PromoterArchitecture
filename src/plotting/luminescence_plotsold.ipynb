# %%
import pandas as pd
import numpy as np
import skbio
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.formula.api import ols
import researchpy as rp

# %%
luminescence_means = "../../data/luminescence/to_be_sorted/24.11.19/output_means.csv"
luminescence_raw = "../../data/luminescence/to_be_sorted/24.11.19/output_raw.csv"

# %%
luminescence_means_df = pd.read_csv(luminescence_means, header=0)
luminescence_raw_df = pd.read_csv(luminescence_raw, header=0)

# %%
luminescence_means_df
# Out:
#        name             condition  mean_luminescence  standard_error      date
# 0     25+72  nitrate_2hrs_morning           2.790261        2.193078  24.11.19
# 1     25+72          nitrate_free           0.550167        0.222781  24.11.19
# 2     25+72     nitrate_overnight           1.590474        0.172189  24.11.19
# 3     35+72  nitrate_2hrs_morning          52.739306       11.566316  24.11.19
# 4     35+72          nitrate_free          39.059989        4.871612  24.11.19
# 5     35+72     nitrate_overnight          34.324808        5.507199  24.11.19
# 6     36+72  nitrate_2hrs_morning           7.455392        6.533360  24.11.19
# 7     36+72          nitrate_free           2.743449        0.756559  24.11.19
# 8     36+72     nitrate_overnight          14.478988        8.061074  24.11.19
# 9   71 + 72  nitrate_2hrs_morning          81.671569        7.348306  24.11.19
# 10  71 + 72          nitrate_free          68.784400       24.850146  24.11.19
# 11  71 + 72     nitrate_overnight          36.256734        5.234907  24.11.19
# 12    92+72  nitrate_2hrs_morning           1.129762        0.589476  24.11.19
# 13    92+72          nitrate_free           0.769348        0.207741  24.11.19
# 14    92+72     nitrate_overnight           1.949657        0.163949  24.11.19

# %%
luminescence_raw_df
# Out:
#    well_row  well_col     content  fluc_luminescence  nluc_luminescence  \
# 0         A         1   Sample X1           394917.0         46763438.0
# 1         A         2   Sample X6           125696.0          5237032.0
# 2         A         3  Sample X11            64547.0          2986951.0
# 3         A         4  Sample X16            95437.0          8127891.0
# 4         A         5  Sample X21           118307.0         10918281.0
# 5         A         6  Sample X26            71519.0          4831968.0
# 6         A         7  Sample X31            84739.0          2670521.0
# 7         A         8  Sample X36           114046.0          3483421.0
# 8         A         9  Sample X41            74478.0          3478982.0
# 9         B         1   Sample X2           188045.0            51186.0
# 10        B         2   Sample X7            54247.0            21025.0
# 11        B         3  Sample X12            10562.0            10464.0
# 12        B         4  Sample X17             1557.0            11159.0
# 13        B         5  Sample X22           199925.0            70566.0
# 14        B         6  Sample X27            52264.0            44468.0
# 15        B         7  Sample X32            13767.0            25550.0
# 16        B         8  Sample X37            34475.0            43705.0
# 17        B         9  Sample X42            24333.0            40096.0
# 18        C         1   Sample X3            68597.0          2847399.0
# 19        C         2   Sample X8            22917.0          1054237.0
# 20        C         3  Sample X13            44724.0          1326893.0
# 21        C         4  Sample X18              812.0            57796.0
# 22        C         5  Sample X23            57708.0          3209636.0
# 23        C         6  Sample X28            27942.0           877994.0
# 24        C         7  Sample X33            12652.0           346951.0
# 25        C         8  Sample X38            19284.0           585122.0
# 26        C         9  Sample X43              974.0            44034.0
# 27        D         1   Sample X4            27937.0            48749.0
# 28        D         2   Sample X9             6657.0            28141.0
# 29        D         3  Sample X14            12646.0            28556.0
# 30        D         5  Sample X24            46827.0            43176.0
# 31        D         6  Sample X29              978.0            13681.0
# 32        D         7  Sample X34             1396.0            15886.0
# 33        D         8  Sample X39              549.0            16322.0
# 34        D         9  Sample X44             5742.0            13361.0
# 35        E         1   Sample X5           192462.0           228020.0
# 36        E         2  Sample X10            10905.0             6200.0
# 37        E         3  Sample X15            32752.0            18169.0
# 38        E         4  Sample X20            69812.0            32044.0
# 39        E         5  Sample X25             1483.0             3418.0
# 40        E         6  Sample X30             6590.0             4122.0
# 41        E         7  Sample X35             1274.0             2101.0
# 42        E         8  Sample X40            28247.0            62525.0
# 43        E         9  Sample X45             5558.0            11040.0
#
#        name             condition   nluc/fluc      date
# 0   71 + 72          nitrate_free  118.413332  24.11.19
# 1   71 + 72          nitrate_free   41.664269  24.11.19
# 2   71 + 72          nitrate_free   46.275598  24.11.19
# 3   71 + 72  nitrate_2hrs_morning   85.164988  24.11.19
# 4   71 + 72  nitrate_2hrs_morning   92.287701  24.11.19
# 5   71 + 72  nitrate_2hrs_morning   67.562018  24.11.19
# 6   71 + 72     nitrate_overnight   31.514663  24.11.19
# 7   71 + 72     nitrate_overnight   30.544000  24.11.19
# 8   71 + 72     nitrate_overnight   46.711539  24.11.19
# 9     25+72          nitrate_free    0.272201  24.11.19
# 10    25+72          nitrate_free    0.387579  24.11.19
# 11    25+72          nitrate_free    0.990721  24.11.19
# 12    25+72  nitrate_2hrs_morning    7.166988  24.11.19
# 13    25+72  nitrate_2hrs_morning    0.352962  24.11.19
# 14    25+72  nitrate_2hrs_morning    0.850834  24.11.19
# 15    25+72     nitrate_overnight    1.855887  24.11.19
# 16    25+72     nitrate_overnight    1.267730  24.11.19
# 17    25+72     nitrate_overnight    1.647803  24.11.19
# 18    35+72          nitrate_free   41.509089  24.11.19
# 19    35+72          nitrate_free   46.002400  24.11.19
# 20    35+72          nitrate_free   29.668478  24.11.19
# 21    35+72  nitrate_2hrs_morning   71.177340  24.11.19
# 22    35+72  nitrate_2hrs_morning   55.618562  24.11.19
# 23    35+72  nitrate_2hrs_morning   31.422017  24.11.19
# 24    35+72     nitrate_overnight   27.422621  24.11.19
# 25    35+72     nitrate_overnight   30.342356  24.11.19
# 26    35+72     nitrate_overnight   45.209446  24.11.19
# 27    36+72          nitrate_free    1.744962  24.11.19
# 28    36+72          nitrate_free    4.227280  24.11.19
# 29    36+72          nitrate_free    2.258105  24.11.19
# 30    36+72  nitrate_2hrs_morning    0.922032  24.11.19
# 31    36+72  nitrate_2hrs_morning   13.988753  24.11.19
# 32    36+72     nitrate_overnight   11.379656  24.11.19
# 33    36+72     nitrate_overnight   29.730419  24.11.19
# 34    36+72     nitrate_overnight    2.326890  24.11.19
# 35    92+72          nitrate_free    1.184753  24.11.19
# 36    92+72          nitrate_free    0.568547  24.11.19
# 37    92+72          nitrate_free    0.554745  24.11.19
# 38    92+72  nitrate_2hrs_morning    0.459004  24.11.19
# 39    92+72  nitrate_2hrs_morning    2.304788  24.11.19
# 40    92+72  nitrate_2hrs_morning    0.625493  24.11.19
# 41    92+72     nitrate_overnight    1.649137  24.11.19
# 42    92+72     nitrate_overnight    2.213509  24.11.19
# 43    92+72     nitrate_overnight    1.986326  24.11.19

# %%
#add promoter names column
luminescence_raw_df['Promoter'] = luminescence_raw_df.name

# %%
luminescence_raw_df.loc[luminescence_raw_df.name == '71 + 72', 'Promoter'] = 'UBQ10'
luminescence_raw_df.loc[luminescence_raw_df.name == '25+72', 'Promoter'] = 'NIR1'
luminescence_raw_df.loc[luminescence_raw_df.name == '35+72', 'Promoter'] = 'NOS'
luminescence_raw_df.loc[luminescence_raw_df.name == '36+72', 'Promoter'] = 'STAP4'
luminescence_raw_df.loc[luminescence_raw_df.name == '92+72', 'Promoter'] = 'NRP'

# %%
luminescence_raw_df
# Out:
#    well_row  well_col     content  fluc_luminescence  nluc_luminescence  \
# 0         A         1   Sample X1           394917.0         46763438.0
# 1         A         2   Sample X6           125696.0          5237032.0
# 2         A         3  Sample X11            64547.0          2986951.0
# 3         A         4  Sample X16            95437.0          8127891.0
# 4         A         5  Sample X21           118307.0         10918281.0
# 5         A         6  Sample X26            71519.0          4831968.0
# 6         A         7  Sample X31            84739.0          2670521.0
# 7         A         8  Sample X36           114046.0          3483421.0
# 8         A         9  Sample X41            74478.0          3478982.0
# 9         B         1   Sample X2           188045.0            51186.0
# 10        B         2   Sample X7            54247.0            21025.0
# 11        B         3  Sample X12            10562.0            10464.0
# 12        B         4  Sample X17             1557.0            11159.0
# 13        B         5  Sample X22           199925.0            70566.0
# 14        B         6  Sample X27            52264.0            44468.0
# 15        B         7  Sample X32            13767.0            25550.0
# 16        B         8  Sample X37            34475.0            43705.0
# 17        B         9  Sample X42            24333.0            40096.0
# 18        C         1   Sample X3            68597.0          2847399.0
# 19        C         2   Sample X8            22917.0          1054237.0
# 20        C         3  Sample X13            44724.0          1326893.0
# 21        C         4  Sample X18              812.0            57796.0
# 22        C         5  Sample X23            57708.0          3209636.0
# 23        C         6  Sample X28            27942.0           877994.0
# 24        C         7  Sample X33            12652.0           346951.0
# 25        C         8  Sample X38            19284.0           585122.0
# 26        C         9  Sample X43              974.0            44034.0
# 27        D         1   Sample X4            27937.0            48749.0
# 28        D         2   Sample X9             6657.0            28141.0
# 29        D         3  Sample X14            12646.0            28556.0
# 30        D         5  Sample X24            46827.0            43176.0
# 31        D         6  Sample X29              978.0            13681.0
# 32        D         7  Sample X34             1396.0            15886.0
# 33        D         8  Sample X39              549.0            16322.0
# 34        D         9  Sample X44             5742.0            13361.0
# 35        E         1   Sample X5           192462.0           228020.0
# 36        E         2  Sample X10            10905.0             6200.0
# 37        E         3  Sample X15            32752.0            18169.0
# 38        E         4  Sample X20            69812.0            32044.0
# 39        E         5  Sample X25             1483.0             3418.0
# 40        E         6  Sample X30             6590.0             4122.0
# 41        E         7  Sample X35             1274.0             2101.0
# 42        E         8  Sample X40            28247.0            62525.0
# 43        E         9  Sample X45             5558.0            11040.0
#
#        name             condition   nluc/fluc      date Promoter
# 0   71 + 72          nitrate_free  118.413332  24.11.19    UBQ10
# 1   71 + 72          nitrate_free   41.664269  24.11.19    UBQ10
# 2   71 + 72          nitrate_free   46.275598  24.11.19    UBQ10
# 3   71 + 72  nitrate_2hrs_morning   85.164988  24.11.19    UBQ10
# 4   71 + 72  nitrate_2hrs_morning   92.287701  24.11.19    UBQ10
# 5   71 + 72  nitrate_2hrs_morning   67.562018  24.11.19    UBQ10
# 6   71 + 72     nitrate_overnight   31.514663  24.11.19    UBQ10
# 7   71 + 72     nitrate_overnight   30.544000  24.11.19    UBQ10
# 8   71 + 72     nitrate_overnight   46.711539  24.11.19    UBQ10
# 9     25+72          nitrate_free    0.272201  24.11.19     NIR1
# 10    25+72          nitrate_free    0.387579  24.11.19     NIR1
# 11    25+72          nitrate_free    0.990721  24.11.19     NIR1
# 12    25+72  nitrate_2hrs_morning    7.166988  24.11.19     NIR1
# 13    25+72  nitrate_2hrs_morning    0.352962  24.11.19     NIR1
# 14    25+72  nitrate_2hrs_morning    0.850834  24.11.19     NIR1
# 15    25+72     nitrate_overnight    1.855887  24.11.19     NIR1
# 16    25+72     nitrate_overnight    1.267730  24.11.19     NIR1
# 17    25+72     nitrate_overnight    1.647803  24.11.19     NIR1
# 18    35+72          nitrate_free   41.509089  24.11.19      NOS
# 19    35+72          nitrate_free   46.002400  24.11.19      NOS
# 20    35+72          nitrate_free   29.668478  24.11.19      NOS
# 21    35+72  nitrate_2hrs_morning   71.177340  24.11.19      NOS
# 22    35+72  nitrate_2hrs_morning   55.618562  24.11.19      NOS
# 23    35+72  nitrate_2hrs_morning   31.422017  24.11.19      NOS
# 24    35+72     nitrate_overnight   27.422621  24.11.19      NOS
# 25    35+72     nitrate_overnight   30.342356  24.11.19      NOS
# 26    35+72     nitrate_overnight   45.209446  24.11.19      NOS
# 27    36+72          nitrate_free    1.744962  24.11.19    STAP4
# 28    36+72          nitrate_free    4.227280  24.11.19    STAP4
# 29    36+72          nitrate_free    2.258105  24.11.19    STAP4
# 30    36+72  nitrate_2hrs_morning    0.922032  24.11.19    STAP4
# 31    36+72  nitrate_2hrs_morning   13.988753  24.11.19    STAP4
# 32    36+72     nitrate_overnight   11.379656  24.11.19    STAP4
# 33    36+72     nitrate_overnight   29.730419  24.11.19    STAP4
# 34    36+72     nitrate_overnight    2.326890  24.11.19    STAP4
# 35    92+72          nitrate_free    1.184753  24.11.19      NRP
# 36    92+72          nitrate_free    0.568547  24.11.19      NRP
# 37    92+72          nitrate_free    0.554745  24.11.19      NRP
# 38    92+72  nitrate_2hrs_morning    0.459004  24.11.19      NRP
# 39    92+72  nitrate_2hrs_morning    2.304788  24.11.19      NRP
# 40    92+72  nitrate_2hrs_morning    0.625493  24.11.19      NRP
# 41    92+72     nitrate_overnight    1.649137  24.11.19      NRP
# 42    92+72     nitrate_overnight    2.213509  24.11.19      NRP
# 43    92+72     nitrate_overnight    1.986326  24.11.19      NRP

# %%
#set style to ticks
sns.set(style="ticks", color_codes=True)

# %%
plot = sns.catplot(x="Promoter", y="nluc/fluc", data=luminescence_raw_df, hue='condition', kind='violin')
#plot points
ax = sns.swarmplot(x="Promoter", y="nluc/fluc", data=luminescence_raw_df, color=".25").get_figure().savefig('../../data/plots/luminescence/24.11.19/luminescence_violin.pdf', format='pdf')

# %%
#bar chart, 95% confidence intervals
plot = sns.barplot(x="Promoter", y="nluc/fluc", hue="condition", data=luminescence_raw_df)
plt.ylabel("Mean_luminescence")
# Out:
# Text(0, 0.5, 'Mean_luminescence')

# %%
#plot raw UBQ10
plot = sns.barplot(x="Promoter", y="fluc_luminescence", hue="condition", data=luminescence_raw_df[luminescence_raw_df.Promoter == 'UBQ10'])
plt.ylabel("Mean_luminescence")
# Out:
# Text(0, 0.5, 'Mean_luminescence')

# %% [markdown]
# ### get names of each condition for later

# %%
pd.Categorical(luminescence_raw_df.condition)
names = luminescence_raw_df.condition.unique()
for name in names:
    print(name)
# Out:
# nitrate_free
# nitrate_2hrs_morning
# nitrate_overnight

# %%
#get list of promoters
pd.Categorical(luminescence_raw_df.Promoter)
prom_names = luminescence_raw_df.Promoter.unique()
for name in prom_names:
    print(name)
# Out:
# UBQ10
# NIR1
# NOS
# STAP4
# NRP

# %% [markdown]
# ### test normality

# %%
#returns test statistic, p-value
for name1 in prom_names:
    for name in names:
        print('{}: {}'.format(name, stats.shapiro(luminescence_raw_df['nluc/fluc'][luminescence_raw_df.condition == name])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-eb4682e6216a> in <module>
#       2 for name1 in prom_names:
#       3     for name in names:
# ----> 4         print('{}: {}'.format(name, stats.shapiro(luminescence_raw_df['nluc/fluc'][luminescence_raw_df.condition == name])))
#
# ~/opt/anaconda3/envs/PromoterArchitecturePipeline/lib/python3.6/site-packages/scipy/stats/morestats.py in shapiro(x)
#    1647     N = len(x)
#    1648     if N < 3:
# -> 1649         raise ValueError("Data must be at least length 3.")
#    1650
#    1651     a = zeros(N, 'f')
#
# ValueError: Data must be at least length 3.

# %% [markdown]
# #### not normal

# %%
#test variance
stats.levene(luminescence_raw_df['nluc/fluc'][luminescence_raw_df.condition == names[0]], 
               luminescence_raw_df['nluc/fluc'][luminescence_raw_df.condition == names[1]], 
               luminescence_raw_df['nluc/fluc'][luminescence_raw_df.condition == names[2]])
# Out:
# LeveneResult(statistic=nan, pvalue=nan)

# %%
test = luminescence_raw_df.groupby('Promoter')['nluc/fluc'].apply

# %%
test
# Out:
# <bound method SeriesGroupBy.apply of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7fc8486a1160>>
