# %%
df_old = '/home/witham/Documents/pipeline_new/PromoterArchitecture/data/output/non-overlapping_includingbidirectional_all_genes_newannotation/genes/promoters_5UTR_schmid_non-specific_tissuespecific_random (copy).txt'
df_new = '/home/witham/Documents/pipeline_new/PromoterArchitecture/data/output/non-overlapping_includingbidirectional_all_genes_newannotation/genes/promoters_5UTR_schmid_non-specific_tissuespecific_random.txt'

# %%
import pandas as pd

# %%
df1 = pd.read_table(df_old, sep='\t')
cols = ['AGI','type']
df1.columns = cols

df2 = pd.read_table(df_new, sep='\t')
df2.columns = cols

# %%
df1.sort_values(by=['type','AGI'],ascending=False)
# Out:
#            AGI             type
# 163  AT5G62490  tissue_specific
# 192  AT5G55750  tissue_specific
# 143  AT5G53810  tissue_specific
# 124  AT5G48000  tissue_specific
# 183  AT5G47450  tissue_specific
# ..         ...              ...
# 205  AT1G15200          control
# 223  AT1G14460          control
# 247  AT1G05470          control
# 209  AT1G04390          control
# 288  AT1G01600          control
#
# [299 rows x 2 columns]

# %%
df2.sort_values(by=['type','AGI'],ascending=False)
# Out:
#            AGI             type
# 166  AT5G61710  tissue_specific
# 116  AT5G56640  tissue_specific
# 198  AT5G55980  tissue_specific
# 114  AT5G53810  tissue_specific
# 112  AT5G52160  tissue_specific
# ..         ...              ...
# 199  AT1G15530          control
# 219  AT1G15130          control
# 251  AT1G14890          control
# 287  AT1G08810          control
# 275  AT1G05340          control
#
# [299 rows x 2 columns]
